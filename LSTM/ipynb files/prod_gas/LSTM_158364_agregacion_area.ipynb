# %% [markdown]
# #Partiendo de la limpieza de datos realizada previamente, se utiliza LSTM para predecir la producción de pozos de petroleo.
#
# ###Pozos a predecir:
# 158364, 160211, 160332, 160789, 160810, 160814, 161451, 162200, 162405, 162955, 163237, 163942

# %%
import math
import itertools
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import LSTM, Dense
from keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
pd.set_option('display.max_columns', None)

idpozo = 158364
model_save_path_50trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-50trials.h5"
image_save_path_50trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-50trials.png"
image_save_path_three_lastmonths_50trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}three_lastmonths-50trials.png"


model_save_path_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-100trials.h5"
image_save_path_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-100trials.png"
image_save_path_three_lastmonths_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}three_lastmonths-100trials.png"

model_save_path_mse_mae_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-mse_mae-100trials.h5"
image_save_path_mse_mae_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-mse_mae_100-trials.png"
image_save_path_three_lastmonths_mse_mae_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}three_lastmonths_mse_mae-100trials.png"

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

dataset = pd.read_csv("/content/drive/MyDrive/Trabajo profesional/Code/data/prod_norm_2024-05-27_03:42:59.csv", index_col=0)

dataset = dataset[dataset['anio'] >= 2014]

# Seleccionar características relevantes
features = ['prod_pet', 'prod_gas', 'anio', 'mes', 'idpozo', 'prod_agua', 'tef', 'coordenadax', 'coordenaday', 'cota', 'areayacimiento']

# Filtrar características
data = dataset[features]

# Creacion de una nueva columna 'date' combinando 'anio' y 'mes' para representar la fecha
data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')

data.drop(['mes', 'anio'], axis=1, inplace=True)

# Conversion de la columna 'date' a "datetime type"
data['date'] = pd.to_datetime(data['date'])

# Definicion de un dia de referencia inicial (Es la primera fecha desde la que se filtro previamente).
reference_date = pd.Timestamp('2014-01-01')

# Calculo del numero de meses desde la referencia para cada date.
data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1

data.drop(['date'], axis=1, inplace=True)

# Agrupar por 'areayacimiento' y 'date_numeric' para calcular el promedio de 'prod_gas'
grouped = data.groupby(['areayacimiento', 'date_numeric'])['prod_gas'].mean().reset_index()

# Renombrar la columna 'prod_gas' a 'prom_prod_gas'
grouped = grouped.rename(columns={'prod_gas': 'prom_prod_gas'})

# Unir el promedio calculado con el DataFrame original
data = pd.merge(data, grouped, on=['areayacimiento', 'date_numeric'])

filtered_data_one_id = data[data['idpozo'] == idpozo]

filtered_data_one_id.drop(['idpozo'], axis=1, inplace=True)
filtered_data_one_id.drop(['areayacimiento'], axis=1, inplace=True)
# Out:
# Mounted at /content/drive
# <ipython-input-1-d87e36ee14fa>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')
# <ipython-input-1-d87e36ee14fa>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['mes', 'anio'], axis=1, inplace=True)
# <ipython-input-1-d87e36ee14fa>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['date'])
# <ipython-input-1-d87e36ee14fa>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1
# <ipython-input-1-d87e36ee14fa>:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['date'], axis=1, inplace=True)
# <ipython-input-1-d87e36ee14fa>:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data_one_id.drop(['idpozo'], axis=1, inplace=True)
# <ipython-input-1-d87e36ee14fa>:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data_one_id.drop(['areayacimiento'], axis=1, inplace=True)

# %%
filtered_data_one_id.head()
# Out:
#        prod_pet  prod_gas  prod_agua    tef  coordenadax  coordenaday    cota  \
# 22295  1793.305    469.41     439.56  29.96   -68.717131   -38.370635  520.96
# 23275  3070.740    685.92     991.75  30.73   -68.717131   -38.370635  520.96
# 24264  4157.410    996.36    1387.16  30.00   -68.717131   -38.370635  520.96
# 25281  4339.880   1052.52     652.70  30.88   -68.717131   -38.370635  520.96
# 26311  3592.575    833.34     520.78  30.96   -68.717131   -38.370635  520.96
#
#        date_numeric  prom_prod_gas
# 22295            45     106.860000
# 23275            46     117.128955
# 24264            47     119.416963
# 25281            48     122.174764
# 26311            49     110.817095

# %%
# 50 Trials - mse only

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'prom_prod_gas', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_gas']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
#X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)
# Calcular el índice de corte para los últimos 3 valores (121, 122 y 123)
test_size = 3
split_index = len(X_sequences) - test_size

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test = X_sequences[:split_index], X_sequences[split_index:]
y_train, y_test = y_adjusted[:split_index], y_adjusted[split_index:]


# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, el error cuadrático medio)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    return mse

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=50, trials=trials)

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

model.save(model_save_path_50trials)

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_gas')
plt.title('Actual versus Predicho "prod_gas"')
plt.legend()
plt.savefig(image_save_path_50trials)
plt.show()

# Predecir "prod_gas" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [121, 122, 123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'prom_prod_gas': [filtered_data_one_id['prom_prod_gas'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_gas:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 321ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 252ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 160ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 158ms/step
#
#   8%|▊         | 4/50 [00:58<09:44, 12.72s/trial, best loss: 626.9399945591036]
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7cd4e01f0c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
#  10%|█         | 5/50 [01:11<09:40, 12.90s/trial, best loss: 626.9399945591036]
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7cd4e03d0d30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 201ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 163ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 235ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 163ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 260ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 166ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 163ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 163ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 165ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 158ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 165ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 204ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 272ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 247ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 166ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 164ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 248ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 234ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 186ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 195ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 171ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 262ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 162ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 178ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 100%|██████████| 50/50 [10:02<00:00, 12.05s/trial, best loss: 139.2138621635397]
# Mejor tamaño de lote: 64
# Mejor cantidad de épocas: 100
# Epoch 1/100
# 2/2 [==============================] - 2s 252ms/step - loss: 0.1484 - val_loss: 0.0028
# Epoch 2/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1320 - val_loss: 4.4529e-04
# Epoch 3/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1182 - val_loss: 9.0968e-04
# Epoch 4/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1054 - val_loss: 0.0041
# Epoch 5/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0952 - val_loss: 0.0096
# Epoch 6/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0861 - val_loss: 0.0171
# Epoch 7/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0790 - val_loss: 0.0259
# Epoch 8/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0728 - val_loss: 0.0345
# Epoch 9/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0684 - val_loss: 0.0428
# Epoch 10/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0650 - val_loss: 0.0493
# Epoch 11/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0621 - val_loss: 0.0536
# Epoch 12/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0593 - val_loss: 0.0570
# Epoch 13/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0574 - val_loss: 0.0583
# Epoch 14/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0551 - val_loss: 0.0572
# Epoch 15/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0531 - val_loss: 0.0569
# Epoch 16/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0513 - val_loss: 0.0564
# Epoch 17/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0498 - val_loss: 0.0526
# Epoch 18/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0481 - val_loss: 0.0455
# Epoch 19/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0460 - val_loss: 0.0353
# Epoch 20/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0442 - val_loss: 0.0252
# Epoch 21/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0426 - val_loss: 0.0170
# Epoch 22/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0419 - val_loss: 0.0114
# Epoch 23/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0412 - val_loss: 0.0086
# Epoch 24/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0405 - val_loss: 0.0081
# Epoch 25/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0392 - val_loss: 0.0106
# Epoch 26/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0380 - val_loss: 0.0150
# Epoch 27/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0379 - val_loss: 0.0181
# Epoch 28/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0379 - val_loss: 0.0163
# Epoch 29/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0374 - val_loss: 0.0114
# Epoch 30/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0368 - val_loss: 0.0066
# Epoch 31/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0365 - val_loss: 0.0033
# Epoch 32/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0368 - val_loss: 0.0025
# Epoch 33/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0366 - val_loss: 0.0029
# Epoch 34/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0362 - val_loss: 0.0040
# Epoch 35/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0357 - val_loss: 0.0073
# Epoch 36/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0357 - val_loss: 0.0117
# Epoch 37/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0366 - val_loss: 0.0149
# Epoch 38/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0371 - val_loss: 0.0150
# Epoch 39/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0370 - val_loss: 0.0129
# Epoch 40/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0364 - val_loss: 0.0094
# Epoch 41/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0355 - val_loss: 0.0072
# Epoch 42/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0349 - val_loss: 0.0055
# Epoch 43/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0349 - val_loss: 0.0037
# Epoch 44/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0349 - val_loss: 0.0030
# Epoch 45/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0350 - val_loss: 0.0027
# Epoch 46/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0350 - val_loss: 0.0024
# Epoch 47/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0351 - val_loss: 0.0025
# Epoch 48/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0347 - val_loss: 0.0046
# Epoch 49/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0343 - val_loss: 0.0094
# Epoch 50/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0348 - val_loss: 0.0133
# Epoch 51/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0355 - val_loss: 0.0149
# Epoch 52/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0359 - val_loss: 0.0142
# Epoch 53/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0357 - val_loss: 0.0110
# Epoch 54/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0350 - val_loss: 0.0081
# Epoch 55/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0342 - val_loss: 0.0062
# Epoch 56/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0338 - val_loss: 0.0043
# Epoch 57/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0335 - val_loss: 0.0029
# Epoch 58/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0334 - val_loss: 0.0019
# Epoch 59/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0333 - val_loss: 0.0011
# Epoch 60/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0334 - val_loss: 5.5458e-04
# Epoch 61/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0335 - val_loss: 2.5066e-04
# Epoch 62/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0337 - val_loss: 1.1888e-04
# Epoch 63/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0338 - val_loss: 1.4983e-04
# Epoch 64/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0334 - val_loss: 4.3266e-04
# Epoch 65/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0329 - val_loss: 9.4400e-04
# Epoch 66/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0325 - val_loss: 0.0017
# Epoch 67/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0324 - val_loss: 0.0026
# Epoch 68/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0327 - val_loss: 0.0031
# Epoch 69/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0330 - val_loss: 0.0026
# Epoch 70/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0329 - val_loss: 0.0015
# Epoch 71/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0325 - val_loss: 8.8045e-04
# Epoch 72/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0322 - val_loss: 3.3660e-04
# Epoch 73/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0320 - val_loss: 8.0822e-05
# Epoch 74/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0323 - val_loss: 2.0187e-04
# Epoch 75/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0323 - val_loss: 1.5089e-04
# Epoch 76/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0321 - val_loss: 9.6413e-05
# Epoch 77/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0316 - val_loss: 8.1103e-04
# Epoch 78/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0318 - val_loss: 0.0023
# Epoch 79/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0325 - val_loss: 0.0027
# Epoch 80/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0325 - val_loss: 0.0017
# Epoch 81/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0318 - val_loss: 4.4535e-04
# Epoch 82/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0312 - val_loss: 1.0400e-04
# Epoch 83/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0315 - val_loss: 6.5240e-04
# Epoch 84/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0324 - val_loss: 0.0011
# Epoch 85/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0327 - val_loss: 6.5569e-04
# Epoch 86/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0321 - val_loss: 1.7721e-04
# Epoch 87/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0312 - val_loss: 9.9920e-05
# Epoch 88/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0309 - val_loss: 3.7559e-04
# Epoch 89/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0311 - val_loss: 5.2532e-04
# Epoch 90/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0313 - val_loss: 4.9412e-04
# Epoch 91/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0314 - val_loss: 7.5914e-04
# Epoch 92/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0316 - val_loss: 0.0013
# Epoch 93/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0320 - val_loss: 9.5811e-04
# Epoch 94/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0311 - val_loss: 1.5107e-04
# Epoch 95/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0305 - val_loss: 1.9259e-04
# Epoch 96/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0308 - val_loss: 3.5059e-04
# Epoch 97/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0311 - val_loss: 3.1818e-04
# Epoch 98/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0312 - val_loss: 2.5300e-04
# Epoch 99/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0313 - val_loss: 1.4675e-04
# Epoch 100/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0311 - val_loss: 9.6479e-05
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 169ms/step
# Error Cuadrático Medio: 127.72595865795502
# Error Absoluto Medio: 10.611528015136713
# 1/1 [==============================] - 0s 19ms/step
# Predicciones para valores futuros de prod_gas: [187.59627 210.58333 211.86996 206.39322 200.92943 195.50027 190.07007
#  184.63889]

# %%
import matplotlib.pyplot as plt

# Filtrar los datos de prueba para los valores de date_numeric 121, 122 y 123
test_data = filtered_data_one_id[filtered_data_one_id['date_numeric'].isin([121, 122, 123])]

# Extraer la columna de 'prod_gas' para los valores de date_numeric 121, 122 y 123
real_values = test_data['prod_gas'].values

# Obtener las predicciones para los valores de date_numeric 121, 122 y 123
# Aquí 'predictions' se supone que contiene las predicciones de los valores futuros
predicted_values = predictions[:3].flatten()

# Imprimir los valores reales de prod_gas para date_numeric 121, 122 y 123
print("Valores reales de prod_gas para date_numeric 121, 122 y 123:", real_values)

# Imprimir los valores predichos de prod_gas para date_numeric 121, 122 y 123
print("Valores predichos de prod_gas para date_numeric 121, 122 y 123:", predicted_values)

# Graficar los valores reales vs los valores predichos
plt.figure(figsize=(10, 5))
plt.plot([121, 122, 123], real_values, label='Actual', marker='o')
plt.plot([121, 122, 123], predicted_values, label='Predicho', marker='x')
plt.xlabel('date_numeric')
plt.ylabel('prod_gas')
plt.title('Actual versus Predicho "prod_gas"')
plt.legend()
plt.savefig(image_save_path_three_lastmonths_50trials)
plt.show()
# Out:
# Valores reales de prod_gas para date_numeric 121, 122 y 123: [ 86.37 138.98 134.81]
# Valores predichos de prod_gas para date_numeric 121, 122 y 123: [187.59627 210.58333 211.86996]

# %%
# Load the existing CSV file

csv_results_file_path = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_MSE_50_trials.csv"
df = pd.read_csv(csv_results_file_path)

# Determine the current maximum index in the DataFrame
#max_index = df.index.max()

# Create a DataFrame with the new data, ensuring the indices are sequential from the current maximum index
#new_indices = [max_index + 1, max_index + 2, max_index + 3]

# Create a DataFrame with the new data
new_data = {
    'fecha': ['2024-01-01', '2024-02-01', '2024-03-01'],
    'idpozo': [idpozo, idpozo, idpozo],
    'prod_gas':predicted_values
}

new_df = pd.DataFrame(new_data)
combined_df = pd.concat([df, new_df], ignore_index=True)
combined_df.to_csv(csv_results_file_path, index=False)

#new_df = pd.DataFrame(new_data, index=new_indices)
#combined_df = pd.concat([df, new_df])
#combined_df.to_csv(csv_results_file_path, index=True, index_label='')

print(f'Nuevo valor agregado al csv {csv_results_file_path}')
# Out:
# Nuevo valor agregado al csv /content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_MSE_50_trials.csv

# %%
#Funcion objetivo mse y mae - 100 trials

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials
import tensorflow as tf

# Establecer una semilla aleatoria para reproducibilidad
np.random.seed(42)
tf.random.set_seed(42)

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'prom_prod_gas', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_gas']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
#X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)
# Calcular el índice de corte para los últimos 3 valores (121, 122 y 123)
test_size = 3
split_index = len(X_sequences) - test_size

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test = X_sequences[:split_index], X_sequences[split_index:]
y_train, y_test = y_adjusted[:split_index], y_adjusted[split_index:]

# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, la combinación de MSE y MAE)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)

    # Calcular el MSE y MAE
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

    # Combinar MSE y MAE en una única métrica
    combined_metric = 0.5 * mse + 0.5 * mae
    return combined_metric

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=100, trials=trials)  # Aumentar max_evals

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

model.save(model_save_path_mse_mae_100trials)

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_gas')
plt.title('Actual versus Predicho "prod_gas"')
plt.legend()
plt.savefig(image_save_path_mse_mae_100trials)
plt.show()

# Predecir "prod_gas" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [121, 122, 123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'prom_prod_gas': [filtered_data_one_id['prom_prod_gas'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_gas:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 162ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 198ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 165ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 248ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 255ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 162ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 218ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 165ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 165ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 289ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 186ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 161ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 166ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 248ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 166ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 165ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 164ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 171ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 166ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 164ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 251ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 166ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 159ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 166ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 164ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 178ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 164ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 2s 2s/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 267ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 171ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 164ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 252ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 163ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 243ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 162ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 164ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 164ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 249ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 161ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 289ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 227ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 160ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 166ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 163ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 249ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 160ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 160ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 100%|██████████| 100/100 [16:31<00:00,  9.91s/trial, best loss: 65.8836974632959]
# Mejor tamaño de lote: 128
# Mejor cantidad de épocas: 100
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1318 - val_loss: 0.0039
# Epoch 2/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1228 - val_loss: 0.0017
# Epoch 3/100
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1146 - val_loss: 5.6449e-04
# Epoch 4/100
# 1/1 [==============================] - 0s 73ms/step - loss: 0.1071 - val_loss: 3.9156e-04
# Epoch 5/100
# 1/1 [==============================] - 0s 84ms/step - loss: 0.1004 - val_loss: 0.0012
# Epoch 6/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0944 - val_loss: 0.0029
# Epoch 7/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0890 - val_loss: 0.0055
# Epoch 8/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0843 - val_loss: 0.0088
# Epoch 9/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0802 - val_loss: 0.0127
# Epoch 10/100
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0766 - val_loss: 0.0172
# Epoch 11/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0734 - val_loss: 0.0219
# Epoch 12/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0707 - val_loss: 0.0267
# Epoch 13/100
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0684 - val_loss: 0.0315
# Epoch 14/100
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0664 - val_loss: 0.0361
# Epoch 15/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0648 - val_loss: 0.0405
# Epoch 16/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0633 - val_loss: 0.0445
# Epoch 17/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0621 - val_loss: 0.0478
# Epoch 18/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0610 - val_loss: 0.0504
# Epoch 19/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0599 - val_loss: 0.0521
# Epoch 20/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0588 - val_loss: 0.0529
# Epoch 21/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0578 - val_loss: 0.0528
# Epoch 22/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0566 - val_loss: 0.0517
# Epoch 23/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0554 - val_loss: 0.0498
# Epoch 24/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0541 - val_loss: 0.0473
# Epoch 25/100
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0528 - val_loss: 0.0443
# Epoch 26/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0515 - val_loss: 0.0408
# Epoch 27/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0502 - val_loss: 0.0370
# Epoch 28/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0489 - val_loss: 0.0332
# Epoch 29/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0477 - val_loss: 0.0294
# Epoch 30/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0466 - val_loss: 0.0258
# Epoch 31/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0455 - val_loss: 0.0225
# Epoch 32/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0445 - val_loss: 0.0195
# Epoch 33/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0436 - val_loss: 0.0169
# Epoch 34/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0428 - val_loss: 0.0146
# Epoch 35/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0420 - val_loss: 0.0127
# Epoch 36/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0412 - val_loss: 0.0112
# Epoch 37/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0405 - val_loss: 0.0100
# Epoch 38/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0398 - val_loss: 0.0090
# Epoch 39/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0390 - val_loss: 0.0083
# Epoch 40/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0384 - val_loss: 0.0078
# Epoch 41/100
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0377 - val_loss: 0.0073
# Epoch 42/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0371 - val_loss: 0.0070
# Epoch 43/100
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0366 - val_loss: 0.0067
# Epoch 44/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0361 - val_loss: 0.0065
# Epoch 45/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0358 - val_loss: 0.0061
# Epoch 46/100
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0355 - val_loss: 0.0057
# Epoch 47/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0352 - val_loss: 0.0052
# Epoch 48/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0350 - val_loss: 0.0045
# Epoch 49/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0348 - val_loss: 0.0038
# Epoch 50/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0347 - val_loss: 0.0030
# Epoch 51/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0345 - val_loss: 0.0023
# Epoch 52/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0344 - val_loss: 0.0017
# Epoch 53/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0343 - val_loss: 0.0011
# Epoch 54/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0342 - val_loss: 7.6702e-04
# Epoch 55/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0341 - val_loss: 5.0953e-04
# Epoch 56/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0340 - val_loss: 3.4704e-04
# Epoch 57/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0340 - val_loss: 2.5362e-04
# Epoch 58/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0339 - val_loss: 2.0396e-04
# Epoch 59/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0338 - val_loss: 1.8100e-04
# Epoch 60/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0337 - val_loss: 1.7708e-04
# Epoch 61/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0336 - val_loss: 1.8607e-04
# Epoch 62/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0335 - val_loss: 2.0294e-04
# Epoch 63/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0334 - val_loss: 2.2054e-04
# Epoch 64/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0332 - val_loss: 2.3409e-04
# Epoch 65/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0331 - val_loss: 2.3896e-04
# Epoch 66/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0330 - val_loss: 2.3454e-04
# Epoch 67/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0329 - val_loss: 2.2074e-04
# Epoch 68/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0328 - val_loss: 2.0056e-04
# Epoch 69/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0327 - val_loss: 1.7886e-04
# Epoch 70/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0326 - val_loss: 1.5953e-04
# Epoch 71/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0326 - val_loss: 1.4418e-04
# Epoch 72/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0325 - val_loss: 1.3345e-04
# Epoch 73/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0324 - val_loss: 1.2699e-04
# Epoch 74/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0323 - val_loss: 1.2445e-04
# Epoch 75/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0322 - val_loss: 1.2451e-04
# Epoch 76/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0321 - val_loss: 1.2611e-04
# Epoch 77/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0321 - val_loss: 1.2831e-04
# Epoch 78/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0320 - val_loss: 1.2980e-04
# Epoch 79/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0319 - val_loss: 1.2938e-04
# Epoch 80/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0318 - val_loss: 1.2689e-04
# Epoch 81/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0317 - val_loss: 1.2428e-04
# Epoch 82/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0317 - val_loss: 1.2136e-04
# Epoch 83/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0316 - val_loss: 1.1865e-04
# Epoch 84/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0315 - val_loss: 1.1699e-04
# Epoch 85/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0314 - val_loss: 1.1772e-04
# Epoch 86/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0313 - val_loss: 1.2120e-04
# Epoch 87/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0313 - val_loss: 1.2834e-04
# Epoch 88/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0312 - val_loss: 1.3948e-04
# Epoch 89/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0311 - val_loss: 1.5367e-04
# Epoch 90/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0310 - val_loss: 1.7091e-04
# Epoch 91/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0310 - val_loss: 1.9000e-04
# Epoch 92/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0309 - val_loss: 2.1042e-04
# Epoch 93/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0308 - val_loss: 2.3326e-04
# Epoch 94/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0307 - val_loss: 2.5839e-04
# Epoch 95/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0307 - val_loss: 2.8635e-04
# Epoch 96/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0306 - val_loss: 3.1808e-04
# Epoch 97/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0305 - val_loss: 3.5287e-04
# Epoch 98/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0305 - val_loss: 3.9004e-04
# Epoch 99/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0304 - val_loss: 4.2802e-04
# Epoch 100/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0303 - val_loss: 4.6724e-04
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 162ms/step
# Error Cuadrático Medio: 618.5714179348614
# Error Absoluto Medio: 20.98661427815755
# 1/1 [==============================] - 0s 20ms/step
# Predicciones para valores futuros de prod_gas: [165.39572 185.81604 186.78064 180.65456 174.84424 169.0567  163.38152
#  157.86073]

# %%
import matplotlib.pyplot as plt

# Filtrar los datos de prueba para los valores de date_numeric 121, 122 y 123
test_data = filtered_data_one_id[filtered_data_one_id['date_numeric'].isin([121, 122, 123])]

# Extraer la columna de 'prod_gas' para los valores de date_numeric 121, 122 y 123
real_values = test_data['prod_gas'].values

# Obtener las predicciones para los valores de date_numeric 121, 122 y 123
# Aquí 'predictions' se supone que contiene las predicciones de los valores futuros
predicted_values = predictions[:3].flatten()

# Imprimir los valores reales de prod_gas para date_numeric 121, 122 y 123
print("Valores reales de prod_gas para date_numeric 121, 122 y 123:", real_values)

# Imprimir los valores predichos de prod_gas para date_numeric 121, 122 y 123
print("Valores predichos de prod_gas para date_numeric 121, 122 y 123:", predicted_values)

# Graficar los valores reales vs los valores predichos
plt.figure(figsize=(10, 5))
plt.plot([121, 122, 123], real_values, label='Actual', marker='o')
plt.plot([121, 122, 123], predicted_values, label='Predicho', marker='x')
plt.xlabel('date_numeric')
plt.ylabel('prod_gas')
plt.title('Actual versus Predicho "prod_gas"')
plt.legend()
plt.savefig(image_save_path_three_lastmonths_mse_mae_100trials)
plt.show()
# Out:
# Valores reales de prod_gas para date_numeric 121, 122 y 123: [ 86.37 138.98 134.81]
# Valores predichos de prod_gas para date_numeric 121, 122 y 123: [165.39572 185.81604 186.78064]

# %%
# Load the existing CSV file

csv_results_file_path = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_MSE_MAE_100_trials.csv"
df = pd.read_csv(csv_results_file_path)

# Determine the current maximum index in the DataFrame
#max_index = df.index.max()

# Create a DataFrame with the new data, ensuring the indices are sequential from the current maximum index
#new_indices = [max_index + 1, max_index + 2, max_index + 3]

# Create a DataFrame with the new data
new_data = {
    'fecha': ['2024-01-01', '2024-02-01', '2024-03-01'],
    'idpozo': [idpozo, idpozo, idpozo],
    'prod_gas':predicted_values
}

new_df = pd.DataFrame(new_data)
combined_df = pd.concat([df, new_df], ignore_index=True)
combined_df.to_csv(csv_results_file_path, index=False)

#new_df = pd.DataFrame(new_data, index=new_indices)
#combined_df = pd.concat([df, new_df])
#combined_df.to_csv(csv_results_file_path, index=True, index_label='')

print(f'Nuevo valor agregado al csv {csv_results_file_path}')
# Out:
# Nuevo valor agregado al csv /content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_MSE_MAE_100_trials.csv

# %%
# Con 100 Trials - mse only

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'prom_prod_gas', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_gas']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
#X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)
# Calcular el índice de corte para los últimos 3 valores (121, 122 y 123)
test_size = 3
split_index = len(X_sequences) - test_size

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test = X_sequences[:split_index], X_sequences[split_index:]
y_train, y_test = y_adjusted[:split_index], y_adjusted[split_index:]


# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, el error cuadrático medio)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    return mse

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=50, trials=trials)

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

model.save(model_save_path_100trials)

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_gas')
plt.title('Actual versus Predicho "prod_gas"')
plt.legend()
plt.savefig(image_save_path_100trials)
plt.show()

# Predecir "prod_gas" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [121, 122, 123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'prom_prod_gas': [filtered_data_one_id['prom_prod_gas'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_gas:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 281ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 166ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 159ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 163ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 162ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 160ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 235ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 274ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 178ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 230ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 165ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 246ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 171ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 162ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 161ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 230ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 178ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 166ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 164ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 279ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 178ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 171ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 232ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 164ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 100%|██████████| 50/50 [08:55<00:00, 10.71s/trial, best loss: 198.8211888439895]
# Mejor tamaño de lote: 64
# Mejor cantidad de épocas: 100
# Epoch 1/100
# 2/2 [==============================] - 2s 260ms/step - loss: 0.1339 - val_loss: 0.0030
# Epoch 2/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.1176 - val_loss: 4.6809e-04
# Epoch 3/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1038 - val_loss: 0.0011
# Epoch 4/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0920 - val_loss: 0.0044
# Epoch 5/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0812 - val_loss: 0.0101
# Epoch 6/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0733 - val_loss: 0.0182
# Epoch 7/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0679 - val_loss: 0.0281
# Epoch 8/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0632 - val_loss: 0.0379
# Epoch 9/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0603 - val_loss: 0.0474
# Epoch 10/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0588 - val_loss: 0.0546
# Epoch 11/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0573 - val_loss: 0.0572
# Epoch 12/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0562 - val_loss: 0.0560
# Epoch 13/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0542 - val_loss: 0.0531
# Epoch 14/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0524 - val_loss: 0.0492
# Epoch 15/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0505 - val_loss: 0.0430
# Epoch 16/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0483 - val_loss: 0.0359
# Epoch 17/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0462 - val_loss: 0.0280
# Epoch 18/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0440 - val_loss: 0.0200
# Epoch 19/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0426 - val_loss: 0.0133
# Epoch 20/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0417 - val_loss: 0.0083
# Epoch 21/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0417 - val_loss: 0.0057
# Epoch 22/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0411 - val_loss: 0.0051
# Epoch 23/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0402 - val_loss: 0.0048
# Epoch 24/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0392 - val_loss: 0.0052
# Epoch 25/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0382 - val_loss: 0.0063
# Epoch 26/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0373 - val_loss: 0.0069
# Epoch 27/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0365 - val_loss: 0.0071
# Epoch 28/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0361 - val_loss: 0.0069
# Epoch 29/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0356 - val_loss: 0.0066
# Epoch 30/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0353 - val_loss: 0.0063
# Epoch 31/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0350 - val_loss: 0.0051
# Epoch 32/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0348 - val_loss: 0.0043
# Epoch 33/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0346 - val_loss: 0.0038
# Epoch 34/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0344 - val_loss: 0.0030
# Epoch 35/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0343 - val_loss: 0.0030
# Epoch 36/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0340 - val_loss: 0.0037
# Epoch 37/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0341 - val_loss: 0.0042
# Epoch 38/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0343 - val_loss: 0.0037
# Epoch 39/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0341 - val_loss: 0.0026
# Epoch 40/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0337 - val_loss: 0.0018
# Epoch 41/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0335 - val_loss: 8.2881e-04
# Epoch 42/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0334 - val_loss: 2.2333e-04
# Epoch 43/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0337 - val_loss: 1.2287e-04
# Epoch 44/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0343 - val_loss: 1.2729e-04
# Epoch 45/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0341 - val_loss: 1.4094e-04
# Epoch 46/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0335 - val_loss: 3.0186e-04
# Epoch 47/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0331 - val_loss: 8.4705e-04
# Epoch 48/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0326 - val_loss: 0.0021
# Epoch 49/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0332 - val_loss: 0.0037
# Epoch 50/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0335 - val_loss: 0.0039
# Epoch 51/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0334 - val_loss: 0.0029
# Epoch 52/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0327 - val_loss: 0.0013
# Epoch 53/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0326 - val_loss: 4.2480e-04
# Epoch 54/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0325 - val_loss: 2.9220e-04
# Epoch 55/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0324 - val_loss: 4.5667e-04
# Epoch 56/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0323 - val_loss: 7.2474e-04
# Epoch 57/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0321 - val_loss: 8.1952e-04
# Epoch 58/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0320 - val_loss: 6.7709e-04
# Epoch 59/100
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0319 - val_loss: 5.0828e-04
# Epoch 60/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0319 - val_loss: 4.2863e-04
# Epoch 61/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0319 - val_loss: 3.7724e-04
# Epoch 62/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0318 - val_loss: 4.6099e-04
# Epoch 63/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0316 - val_loss: 8.7819e-04
# Epoch 64/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0316 - val_loss: 0.0014
# Epoch 65/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0317 - val_loss: 0.0014
# Epoch 66/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0315 - val_loss: 8.7425e-04
# Epoch 67/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0314 - val_loss: 3.8235e-04
# Epoch 68/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0314 - val_loss: 1.5779e-04
# Epoch 69/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0316 - val_loss: 1.1560e-04
# Epoch 70/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0318 - val_loss: 1.4473e-04
# Epoch 71/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0319 - val_loss: 1.5714e-04
# Epoch 72/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0319 - val_loss: 1.2516e-04
# Epoch 73/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0315 - val_loss: 1.2264e-04
# Epoch 74/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0313 - val_loss: 2.1223e-04
# Epoch 75/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0312 - val_loss: 2.2998e-04
# Epoch 76/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0310 - val_loss: 1.4270e-04
# Epoch 77/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0310 - val_loss: 1.1395e-04
# Epoch 78/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0310 - val_loss: 2.0397e-04
# Epoch 79/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0312 - val_loss: 3.2793e-04
# Epoch 80/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0311 - val_loss: 1.8539e-04
# Epoch 81/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0308 - val_loss: 1.5495e-04
# Epoch 82/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0308 - val_loss: 7.7401e-04
# Epoch 83/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0320 - val_loss: 0.0016
# Epoch 84/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0328 - val_loss: 0.0015
# Epoch 85/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0324 - val_loss: 7.7799e-04
# Epoch 86/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0311 - val_loss: 1.6010e-04
# Epoch 87/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0305 - val_loss: 2.8161e-04
# Epoch 88/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0306 - val_loss: 9.1563e-04
# Epoch 89/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0317 - val_loss: 0.0013
# Epoch 90/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0321 - val_loss: 0.0010
# Epoch 91/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0317 - val_loss: 6.1903e-04
# Epoch 92/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0311 - val_loss: 1.9707e-04
# Epoch 93/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0305 - val_loss: 1.3174e-04
# Epoch 94/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0302 - val_loss: 2.5083e-04
# Epoch 95/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0303 - val_loss: 3.2458e-04
# Epoch 96/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0302 - val_loss: 2.6772e-04
# Epoch 97/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0302 - val_loss: 2.7997e-04
# Epoch 98/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0302 - val_loss: 2.8647e-04
# Epoch 99/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0302 - val_loss: 2.7438e-04
# Epoch 100/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0300 - val_loss: 4.5102e-04
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 165ms/step
# Error Cuadrático Medio: 597.0929155365134
# Error Absoluto Medio: 21.086488037109376
# 1/1 [==============================] - 0s 20ms/step
# Predicciones para valores futuros de prod_gas: [203.7213  223.0778  223.64748 218.75069 213.86111 208.97884 204.28374
#  199.61354]

# %%
import matplotlib.pyplot as plt

# Filtrar los datos de prueba para los valores de date_numeric 121, 122 y 123
test_data = filtered_data_one_id[filtered_data_one_id['date_numeric'].isin([121, 122, 123])]

# Extraer la columna de 'prod_gas' para los valores de date_numeric 121, 122 y 123
real_values = test_data['prod_gas'].values

# Obtener las predicciones para los valores de date_numeric 121, 122 y 123
# Aquí 'predictions' se supone que contiene las predicciones de los valores futuros
predicted_values = predictions[:3].flatten()

# Imprimir los valores reales de prod_gas para date_numeric 121, 122 y 123
print("Valores reales de prod_gas para date_numeric 121, 122 y 123:", real_values)

# Imprimir los valores predichos de prod_gas para date_numeric 121, 122 y 123
print("Valores predichos de prod_gas para date_numeric 121, 122 y 123:", predicted_values)

# Graficar los valores reales vs los valores predichos
plt.figure(figsize=(10, 5))
plt.plot([121, 122, 123], real_values, label='Actual', marker='o')
plt.plot([121, 122, 123], predicted_values, label='Predicho', marker='x')
plt.xlabel('date_numeric')
plt.ylabel('prod_gas')
plt.title('Actual versus Predicho "prod_gas"')
plt.legend()
plt.savefig(image_save_path_three_lastmonths_100trials)
plt.show()
# Out:
# Valores reales de prod_gas para date_numeric 121, 122 y 123: [ 86.37 138.98 134.81]
# Valores predichos de prod_gas para date_numeric 121, 122 y 123: [203.7213  223.0778  223.64748]

# %%
# Load the existing CSV file

csv_results_file_path = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_MSE_100_trials.csv"
df = pd.read_csv(csv_results_file_path)

# Determine the current maximum index in the DataFrame
#max_index = df.index.max()

# Create a DataFrame with the new data, ensuring the indices are sequential from the current maximum index
#new_indices = [max_index + 1, max_index + 2, max_index + 3]

# Create a DataFrame with the new data
new_data = {
    'fecha': ['2024-01-01', '2024-02-01', '2024-03-01'],
    'idpozo': [idpozo, idpozo, idpozo],
    'prod_gas':predicted_values
}

new_df = pd.DataFrame(new_data)
combined_df = pd.concat([df, new_df], ignore_index=True)
combined_df.to_csv(csv_results_file_path, index=False)

#new_df = pd.DataFrame(new_data, index=new_indices)
#combined_df = pd.concat([df, new_df])
#combined_df.to_csv(csv_results_file_path, index=True, index_label='')

print(f'Nuevo valor agregado al csv {csv_results_file_path}')
# Out:
# Nuevo valor agregado al csv /content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_MSE_100_trials.csv
