# %% [markdown]
# #Partiendo de la limpieza de datos realizada previamente, se utiliza LSTM para predecir la producción de pozos de petroleo.
#
# ###Pozos a predecir:
# 158364, 160211, 160332, 160789, 160810, 160814, 161451, 162200, 162405, 162955, 163237, 163942

# %%
import math
import itertools
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import LSTM, Dense
from keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
pd.set_option('display.max_columns', None)

idpozo = 160332
model_save_path_50trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-50trials.h5"
image_save_path_50trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-50trials.png"
image_save_path_three_lastmonths_50trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}three_lastmonths-50trials.png"


model_save_path_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-100trials.h5"
image_save_path_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-100trials.png"
image_save_path_three_lastmonths_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}three_lastmonths-100trials.png"

model_save_path_mse_mae_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-mse_mae-100trials.h5"
image_save_path_mse_mae_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-mse_mae_100-trials.png"
image_save_path_three_lastmonths_mse_mae_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}three_lastmonths_mse_mae-100trials.png"

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

dataset = pd.read_csv("/content/drive/MyDrive/Trabajo profesional/Code/data/prod_norm_2024-05-27_03:42:59.csv", index_col=0)

dataset = dataset[dataset['anio'] >= 2014]

# Seleccionar características relevantes
features = ['prod_pet', 'prod_gas', 'anio', 'mes', 'idpozo', 'prod_agua', 'tef', 'coordenadax', 'coordenaday', 'cota', 'areayacimiento']

# Filtrar características
data = dataset[features]

# Creacion de una nueva columna 'date' combinando 'anio' y 'mes' para representar la fecha
data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')

data.drop(['mes', 'anio'], axis=1, inplace=True)

# Conversion de la columna 'date' a "datetime type"
data['date'] = pd.to_datetime(data['date'])

# Definicion de un dia de referencia inicial (Es la primera fecha desde la que se filtro previamente).
reference_date = pd.Timestamp('2014-01-01')

# Calculo del numero de meses desde la referencia para cada date.
data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1

data.drop(['date'], axis=1, inplace=True)

# Agrupar por 'areayacimiento' y 'date_numeric' para calcular el promedio de 'prod_gas'
grouped = data.groupby(['areayacimiento', 'date_numeric'])['prod_gas'].mean().reset_index()

# Renombrar la columna 'prod_gas' a 'prom_prod_gas'
grouped = grouped.rename(columns={'prod_gas': 'prom_prod_gas'})

# Unir el promedio calculado con el DataFrame original
data = pd.merge(data, grouped, on=['areayacimiento', 'date_numeric'])

filtered_data_one_id = data[data['idpozo'] == idpozo]

filtered_data_one_id.drop(['idpozo'], axis=1, inplace=True)
filtered_data_one_id.drop(['areayacimiento'], axis=1, inplace=True)
# Out:
# Mounted at /content/drive
# <ipython-input-1-b5bc80a22d10>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')
# <ipython-input-1-b5bc80a22d10>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['mes', 'anio'], axis=1, inplace=True)
# <ipython-input-1-b5bc80a22d10>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['date'])
# <ipython-input-1-b5bc80a22d10>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1
# <ipython-input-1-b5bc80a22d10>:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['date'], axis=1, inplace=True)
# <ipython-input-1-b5bc80a22d10>:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data_one_id.drop(['idpozo'], axis=1, inplace=True)
# <ipython-input-1-b5bc80a22d10>:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data_one_id.drop(['areayacimiento'], axis=1, inplace=True)

# %%
filtered_data_one_id.head()
# Out:
#        prod_pet  prod_gas  prod_agua    tef  coordenadax  coordenaday    cota  \
# 46238  2500.920    703.08     739.05  28.00   -68.683945   -38.619159  560.13
# 47585  3005.995    748.55     478.90  30.00   -68.683945   -38.619159  560.13
# 48946  2905.730    665.56     208.28  30.83   -68.683945   -38.619159  560.13
# 50326  3070.995    935.72     191.88  30.98   -68.683945   -38.619159  560.13
# 51736  3230.745    865.25     172.76  30.00   -68.683945   -38.619159  560.13
#
#        date_numeric  prom_prod_gas
# 46238            65         703.08
# 47585            66         748.55
# 48946            67         665.56
# 50326            68         935.72
# 51736            69         865.25

# %%
# 50 Trials - mse only

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'prom_prod_gas', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_gas']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
#X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)
# Calcular el índice de corte para los últimos 3 valores (121, 122 y 123)
test_size = 3
split_index = len(X_sequences) - test_size

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test = X_sequences[:split_index], X_sequences[split_index:]
y_train, y_test = y_adjusted[:split_index], y_adjusted[split_index:]


# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, el error cuadrático medio)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    return mse

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=50, trials=trials)

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

model.save(model_save_path_50trials)

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_gas')
plt.title('Actual versus Predicho "prod_gas"')
plt.legend()
plt.savefig(image_save_path_50trials)
plt.show()

# Predecir "prod_gas" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [121, 122, 123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'prom_prod_gas': [filtered_data_one_id['prom_prod_gas'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_gas:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 213ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 262ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
#   8%|▊         | 4/50 [00:41<07:27,  9.74s/trial, best loss: 18465.381362362958]
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7a1a7ff1b490> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
#  10%|█         | 5/50 [00:48<06:34,  8.76s/trial, best loss: 18465.381362362958]
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7a1a8121a7a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 268ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 163ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 1s 710ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 186ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 268ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 287ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 229ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 251ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 203ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 215ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 186ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 251ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 209ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 295ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 162ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 234ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 1s 518ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 248ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 199ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 100%|██████████| 50/50 [09:34<00:00, 11.50s/trial, best loss: 14888.486034075724]
# Mejor tamaño de lote: 64
# Mejor cantidad de épocas: 100
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1614 - val_loss: 0.0383
# Epoch 2/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1498 - val_loss: 0.0306
# Epoch 3/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1390 - val_loss: 0.0238
# Epoch 4/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1289 - val_loss: 0.0181
# Epoch 5/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1196 - val_loss: 0.0135
# Epoch 6/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1111 - val_loss: 0.0098
# Epoch 7/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.1034 - val_loss: 0.0069
# Epoch 8/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0963 - val_loss: 0.0048
# Epoch 9/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0899 - val_loss: 0.0034
# Epoch 10/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0841 - val_loss: 0.0025
# Epoch 11/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0790 - val_loss: 0.0022
# Epoch 12/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0744 - val_loss: 0.0021
# Epoch 13/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0705 - val_loss: 0.0024
# Epoch 14/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0671 - val_loss: 0.0028
# Epoch 15/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0643 - val_loss: 0.0033
# Epoch 16/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0619 - val_loss: 0.0038
# Epoch 17/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0597 - val_loss: 0.0042
# Epoch 18/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0579 - val_loss: 0.0045
# Epoch 19/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0562 - val_loss: 0.0045
# Epoch 20/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0545 - val_loss: 0.0043
# Epoch 21/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0529 - val_loss: 0.0040
# Epoch 22/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0513 - val_loss: 0.0035
# Epoch 23/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0496 - val_loss: 0.0030
# Epoch 24/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0477 - val_loss: 0.0025
# Epoch 25/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0458 - val_loss: 0.0021
# Epoch 26/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0439 - val_loss: 0.0020
# Epoch 27/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0419 - val_loss: 0.0022
# Epoch 28/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0400 - val_loss: 0.0028
# Epoch 29/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0381 - val_loss: 0.0039
# Epoch 30/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0363 - val_loss: 0.0054
# Epoch 31/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0346 - val_loss: 0.0074
# Epoch 32/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0330 - val_loss: 0.0099
# Epoch 33/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0317 - val_loss: 0.0128
# Epoch 34/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0304 - val_loss: 0.0160
# Epoch 35/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0293 - val_loss: 0.0195
# Epoch 36/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0282 - val_loss: 0.0231
# Epoch 37/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0273 - val_loss: 0.0268
# Epoch 38/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0264 - val_loss: 0.0304
# Epoch 39/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0255 - val_loss: 0.0340
# Epoch 40/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0247 - val_loss: 0.0373
# Epoch 41/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0239 - val_loss: 0.0404
# Epoch 42/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0231 - val_loss: 0.0433
# Epoch 43/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0224 - val_loss: 0.0458
# Epoch 44/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0218 - val_loss: 0.0482
# Epoch 45/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0212 - val_loss: 0.0503
# Epoch 46/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0208 - val_loss: 0.0523
# Epoch 47/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0205 - val_loss: 0.0543
# Epoch 48/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0203 - val_loss: 0.0564
# Epoch 49/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0202 - val_loss: 0.0586
# Epoch 50/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0200 - val_loss: 0.0609
# Epoch 51/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0199 - val_loss: 0.0633
# Epoch 52/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0198 - val_loss: 0.0658
# Epoch 53/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0196 - val_loss: 0.0682
# Epoch 54/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0195 - val_loss: 0.0706
# Epoch 55/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0193 - val_loss: 0.0726
# Epoch 56/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0191 - val_loss: 0.0744
# Epoch 57/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0190 - val_loss: 0.0758
# Epoch 58/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0188 - val_loss: 0.0765
# Epoch 59/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0187 - val_loss: 0.0766
# Epoch 60/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0185 - val_loss: 0.0760
# Epoch 61/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0184 - val_loss: 0.0748
# Epoch 62/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0182 - val_loss: 0.0731
# Epoch 63/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0180 - val_loss: 0.0712
# Epoch 64/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0177 - val_loss: 0.0689
# Epoch 65/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0175 - val_loss: 0.0664
# Epoch 66/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0173 - val_loss: 0.0640
# Epoch 67/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0170 - val_loss: 0.0617
# Epoch 68/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0168 - val_loss: 0.0596
# Epoch 69/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0166 - val_loss: 0.0578
# Epoch 70/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0164 - val_loss: 0.0563
# Epoch 71/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0162 - val_loss: 0.0550
# Epoch 72/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0160 - val_loss: 0.0540
# Epoch 73/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0157 - val_loss: 0.0530
# Epoch 74/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0155 - val_loss: 0.0521
# Epoch 75/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0153 - val_loss: 0.0510
# Epoch 76/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0152 - val_loss: 0.0498
# Epoch 77/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0150 - val_loss: 0.0485
# Epoch 78/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0148 - val_loss: 0.0472
# Epoch 79/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0146 - val_loss: 0.0458
# Epoch 80/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0144 - val_loss: 0.0445
# Epoch 81/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0142 - val_loss: 0.0434
# Epoch 82/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0140 - val_loss: 0.0425
# Epoch 83/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0138 - val_loss: 0.0420
# Epoch 84/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0136 - val_loss: 0.0419
# Epoch 85/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0134 - val_loss: 0.0421
# Epoch 86/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0132 - val_loss: 0.0426
# Epoch 87/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0130 - val_loss: 0.0432
# Epoch 88/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0127 - val_loss: 0.0438
# Epoch 89/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0125 - val_loss: 0.0445
# Epoch 90/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0123 - val_loss: 0.0451
# Epoch 91/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0121 - val_loss: 0.0455
# Epoch 92/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0119 - val_loss: 0.0457
# Epoch 93/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0117 - val_loss: 0.0457
# Epoch 94/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0115 - val_loss: 0.0454
# Epoch 95/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0112 - val_loss: 0.0450
# Epoch 96/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0110 - val_loss: 0.0445
# Epoch 97/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0108 - val_loss: 0.0440
# Epoch 98/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0106 - val_loss: 0.0435
# Epoch 99/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0104 - val_loss: 0.0430
# Epoch 100/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0102 - val_loss: 0.0426
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 294ms/step
# Error Cuadrático Medio: 17671.16465099416
# Error Absoluto Medio: 128.59964477539057
# 1/1 [==============================] - 0s 29ms/step
# Predicciones para valores futuros de prod_gas: [364.85773 363.53305 363.3593  361.6845  360.06717 358.52393 356.98972
#  355.46262]

# %%
import matplotlib.pyplot as plt

# Filtrar los datos de prueba para los valores de date_numeric 121, 122 y 123
test_data = filtered_data_one_id[filtered_data_one_id['date_numeric'].isin([121, 122, 123])]

# Extraer la columna de 'prod_gas' para los valores de date_numeric 121, 122 y 123
real_values = test_data['prod_gas'].values

# Obtener las predicciones para los valores de date_numeric 121, 122 y 123
# Aquí 'predictions' se supone que contiene las predicciones de los valores futuros
predicted_values = predictions[:3].flatten()

# Imprimir los valores reales de prod_gas para date_numeric 121, 122 y 123
print("Valores reales de prod_gas para date_numeric 121, 122 y 123:", real_values)

# Imprimir los valores predichos de prod_gas para date_numeric 121, 122 y 123
print("Valores predichos de prod_gas para date_numeric 121, 122 y 123:", predicted_values)

# Graficar los valores reales vs los valores predichos
plt.figure(figsize=(10, 5))
plt.plot([121, 122, 123], real_values, label='Actual', marker='o')
plt.plot([121, 122, 123], predicted_values, label='Predicho', marker='x')
plt.xlabel('date_numeric')
plt.ylabel('prod_gas')
plt.title('Actual versus Predicho "prod_gas"')
plt.legend()
plt.savefig(image_save_path_three_lastmonths_50trials)
plt.show()
# Out:
# Valores reales de prod_gas para date_numeric 121, 122 y 123: [480.8  520.66 453.15]
# Valores predichos de prod_gas para date_numeric 121, 122 y 123: [364.85773 363.53305 363.3593 ]

# %%
# Load the existing CSV file

csv_results_file_path = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_MSE_50_trials.csv"
df = pd.read_csv(csv_results_file_path)

# Determine the current maximum index in the DataFrame
#max_index = df.index.max()

# Create a DataFrame with the new data, ensuring the indices are sequential from the current maximum index
#new_indices = [max_index + 1, max_index + 2, max_index + 3]

# Create a DataFrame with the new data
new_data = {
    'fecha': ['2024-01-01', '2024-02-01', '2024-03-01'],
    'idpozo': [idpozo, idpozo, idpozo],
    'prod_gas':predicted_values
}

new_df = pd.DataFrame(new_data)
combined_df = pd.concat([df, new_df], ignore_index=True)
combined_df.to_csv(csv_results_file_path, index=False)

#new_df = pd.DataFrame(new_data, index=new_indices)
#combined_df = pd.concat([df, new_df])
#combined_df.to_csv(csv_results_file_path, index=True, index_label='')

print(f'Nuevo valor agregado al csv {csv_results_file_path}')
# Out:
# Nuevo valor agregado al csv /content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_MSE_50_trials.csv

# %%
#Funcion objetivo mse y mae - 100 trials

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials
import tensorflow as tf

# Establecer una semilla aleatoria para reproducibilidad
np.random.seed(42)
tf.random.set_seed(42)

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'prom_prod_gas', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_gas']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
#X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)
# Calcular el índice de corte para los últimos 3 valores (121, 122 y 123)
test_size = 3
split_index = len(X_sequences) - test_size

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test = X_sequences[:split_index], X_sequences[split_index:]
y_train, y_test = y_adjusted[:split_index], y_adjusted[split_index:]

# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, la combinación de MSE y MAE)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)

    # Calcular el MSE y MAE
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

    # Combinar MSE y MAE en una única métrica
    combined_metric = 0.5 * mse + 0.5 * mae
    return combined_metric

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=100, trials=trials)  # Aumentar max_evals

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

model.save(model_save_path_mse_mae_100trials)

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_gas')
plt.title('Actual versus Predicho "prod_gas"')
plt.legend()
plt.savefig(image_save_path_mse_mae_100trials)
plt.show()

# Predecir "prod_gas" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [121, 122, 123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'prom_prod_gas': [filtered_data_one_id['prom_prod_gas'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_gas:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 294ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 197ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 186ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 200ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 265ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 294ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 192ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 254ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 210ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 214ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 318ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 208ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 277ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 194ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 303ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 246ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 237ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 265ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 199ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 218ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 302ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 321ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 207ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 196ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 195ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 203ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 269ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 322ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 193ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 283ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 196ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 190ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 204ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 299ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 225ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 210ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 219ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 194ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 206ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 171ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 223ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 266ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 280ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 190ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 178ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 206ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 204ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 307ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 193ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 193ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 207ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 197ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 255ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 193ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 231ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 212ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 316ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 224ms/step
#
# 100%|██████████| 100/100 [19:18<00:00, 11.59s/trial, best loss: 7999.241667524256]
# Mejor tamaño de lote: 32
# Mejor cantidad de épocas: 100
# Epoch 1/100
# 2/2 [==============================] - 2s 340ms/step - loss: 0.1841 - val_loss: 0.0650
# Epoch 2/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1676 - val_loss: 0.0490
# Epoch 3/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1477 - val_loss: 0.0347
# Epoch 4/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1313 - val_loss: 0.0229
# Epoch 5/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1150 - val_loss: 0.0139
# Epoch 6/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1021 - val_loss: 0.0077
# Epoch 7/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0903 - val_loss: 0.0040
# Epoch 8/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0808 - val_loss: 0.0023
# Epoch 9/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0719 - val_loss: 0.0019
# Epoch 10/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0663 - val_loss: 0.0025
# Epoch 11/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0620 - val_loss: 0.0035
# Epoch 12/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0575 - val_loss: 0.0044
# Epoch 13/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0545 - val_loss: 0.0048
# Epoch 14/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0533 - val_loss: 0.0048
# Epoch 15/100
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0511 - val_loss: 0.0043
# Epoch 16/100
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0490 - val_loss: 0.0034
# Epoch 17/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0466 - val_loss: 0.0024
# Epoch 18/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0437 - val_loss: 0.0020
# Epoch 19/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0408 - val_loss: 0.0022
# Epoch 20/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0384 - val_loss: 0.0033
# Epoch 21/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0360 - val_loss: 0.0049
# Epoch 22/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0339 - val_loss: 0.0072
# Epoch 23/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0321 - val_loss: 0.0098
# Epoch 24/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0304 - val_loss: 0.0126
# Epoch 25/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0286 - val_loss: 0.0155
# Epoch 26/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0268 - val_loss: 0.0185
# Epoch 27/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0254 - val_loss: 0.0214
# Epoch 28/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0238 - val_loss: 0.0245
# Epoch 29/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0223 - val_loss: 0.0280
# Epoch 30/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0213 - val_loss: 0.0319
# Epoch 31/100
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0202 - val_loss: 0.0363
# Epoch 32/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0194 - val_loss: 0.0413
# Epoch 33/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0188 - val_loss: 0.0471
# Epoch 34/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0181 - val_loss: 0.0529
# Epoch 35/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0176 - val_loss: 0.0577
# Epoch 36/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0172 - val_loss: 0.0614
# Epoch 37/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0170 - val_loss: 0.0639
# Epoch 38/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0166 - val_loss: 0.0654
# Epoch 39/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0163 - val_loss: 0.0659
# Epoch 40/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0160 - val_loss: 0.0664
# Epoch 41/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0157 - val_loss: 0.0662
# Epoch 42/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0153 - val_loss: 0.0645
# Epoch 43/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0149 - val_loss: 0.0618
# Epoch 44/100
# 2/2 [==============================] - 0s 90ms/step - loss: 0.0147 - val_loss: 0.0595
# Epoch 45/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0142 - val_loss: 0.0586
# Epoch 46/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0137 - val_loss: 0.0573
# Epoch 47/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0134 - val_loss: 0.0552
# Epoch 48/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0129 - val_loss: 0.0521
# Epoch 49/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0126 - val_loss: 0.0493
# Epoch 50/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0124 - val_loss: 0.0477
# Epoch 51/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0119 - val_loss: 0.0458
# Epoch 52/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0115 - val_loss: 0.0439
# Epoch 53/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0112 - val_loss: 0.0428
# Epoch 54/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0109 - val_loss: 0.0426
# Epoch 55/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0105 - val_loss: 0.0436
# Epoch 56/100
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0101 - val_loss: 0.0442
# Epoch 57/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0099 - val_loss: 0.0434
# Epoch 58/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0095 - val_loss: 0.0434
# Epoch 59/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0091 - val_loss: 0.0413
# Epoch 60/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0088 - val_loss: 0.0390
# Epoch 61/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0085 - val_loss: 0.0376
# Epoch 62/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0083 - val_loss: 0.0375
# Epoch 63/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0079 - val_loss: 0.0391
# Epoch 64/100
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0077 - val_loss: 0.0410
# Epoch 65/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0074 - val_loss: 0.0415
# Epoch 66/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0072 - val_loss: 0.0399
# Epoch 67/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0069 - val_loss: 0.0382
# Epoch 68/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0068 - val_loss: 0.0363
# Epoch 69/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0066 - val_loss: 0.0360
# Epoch 70/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0064 - val_loss: 0.0372
# Epoch 71/100
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0061 - val_loss: 0.0391
# Epoch 72/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0060 - val_loss: 0.0399
# Epoch 73/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0059 - val_loss: 0.0387
# Epoch 74/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0057 - val_loss: 0.0383
# Epoch 75/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0056 - val_loss: 0.0378
# Epoch 76/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0054 - val_loss: 0.0389
# Epoch 77/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0053 - val_loss: 0.0392
# Epoch 78/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0052 - val_loss: 0.0384
# Epoch 79/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0051 - val_loss: 0.0379
# Epoch 80/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0050 - val_loss: 0.0384
# Epoch 81/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0050 - val_loss: 0.0406
# Epoch 82/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0049 - val_loss: 0.0413
# Epoch 83/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0048 - val_loss: 0.0435
# Epoch 84/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0048 - val_loss: 0.0453
# Epoch 85/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0047 - val_loss: 0.0441
# Epoch 86/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0046 - val_loss: 0.0422
# Epoch 87/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0048 - val_loss: 0.0424
# Epoch 88/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0046 - val_loss: 0.0411
# Epoch 89/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0046 - val_loss: 0.0430
# Epoch 90/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0045 - val_loss: 0.0454
# Epoch 91/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0045 - val_loss: 0.0459
# Epoch 92/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0045 - val_loss: 0.0448
# Epoch 93/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0044 - val_loss: 0.0449
# Epoch 94/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0044 - val_loss: 0.0445
# Epoch 95/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0044 - val_loss: 0.0440
# Epoch 96/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0044 - val_loss: 0.0445
# Epoch 97/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0044 - val_loss: 0.0464
# Epoch 98/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0043 - val_loss: 0.0481
# Epoch 99/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0043 - val_loss: 0.0475
# Epoch 100/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0044 - val_loss: 0.0476
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 199ms/step
# Error Cuadrático Medio: 19764.94090732613
# Error Absoluto Medio: 136.39460734049473
# 1/1 [==============================] - 0s 24ms/step
# Predicciones para valores futuros de prod_gas: [366.08643 335.60275 336.23807 333.9058  331.73877 329.72482 328.00806
#  326.32318]

# %%
import matplotlib.pyplot as plt

# Filtrar los datos de prueba para los valores de date_numeric 121, 122 y 123
test_data = filtered_data_one_id[filtered_data_one_id['date_numeric'].isin([121, 122, 123])]

# Extraer la columna de 'prod_gas' para los valores de date_numeric 121, 122 y 123
real_values = test_data['prod_gas'].values

# Obtener las predicciones para los valores de date_numeric 121, 122 y 123
# Aquí 'predictions' se supone que contiene las predicciones de los valores futuros
predicted_values = predictions[:3].flatten()

# Imprimir los valores reales de prod_gas para date_numeric 121, 122 y 123
print("Valores reales de prod_gas para date_numeric 121, 122 y 123:", real_values)

# Imprimir los valores predichos de prod_gas para date_numeric 121, 122 y 123
print("Valores predichos de prod_gas para date_numeric 121, 122 y 123:", predicted_values)

# Graficar los valores reales vs los valores predichos
plt.figure(figsize=(10, 5))
plt.plot([121, 122, 123], real_values, label='Actual', marker='o')
plt.plot([121, 122, 123], predicted_values, label='Predicho', marker='x')
plt.xlabel('date_numeric')
plt.ylabel('prod_gas')
plt.title('Actual versus Predicho "prod_gas"')
plt.legend()
plt.savefig(image_save_path_three_lastmonths_mse_mae_100trials)
plt.show()
# Out:
# Valores reales de prod_gas para date_numeric 121, 122 y 123: [480.8  520.66 453.15]
# Valores predichos de prod_gas para date_numeric 121, 122 y 123: [366.08643 335.60275 336.23807]

# %%
# Load the existing CSV file

csv_results_file_path = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_MSE_MAE_100_trials.csv"
df = pd.read_csv(csv_results_file_path)

# Determine the current maximum index in the DataFrame
#max_index = df.index.max()

# Create a DataFrame with the new data, ensuring the indices are sequential from the current maximum index
#new_indices = [max_index + 1, max_index + 2, max_index + 3]

# Create a DataFrame with the new data
new_data = {
    'fecha': ['2024-01-01', '2024-02-01', '2024-03-01'],
    'idpozo': [idpozo, idpozo, idpozo],
    'prod_gas':predicted_values
}

new_df = pd.DataFrame(new_data)
combined_df = pd.concat([df, new_df], ignore_index=True)
combined_df.to_csv(csv_results_file_path, index=False)

#new_df = pd.DataFrame(new_data, index=new_indices)
#combined_df = pd.concat([df, new_df])
#combined_df.to_csv(csv_results_file_path, index=True, index_label='')

print(f'Nuevo valor agregado al csv {csv_results_file_path}')
# Out:
# Nuevo valor agregado al csv /content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_MSE_MAE_100_trials.csv

# %%
# Con 100 Trials - mse only

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'prom_prod_gas', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_gas']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
#X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)
# Calcular el índice de corte para los últimos 3 valores (121, 122 y 123)
test_size = 3
split_index = len(X_sequences) - test_size

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test = X_sequences[:split_index], X_sequences[split_index:]
y_train, y_test = y_adjusted[:split_index], y_adjusted[split_index:]


# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, el error cuadrático medio)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    return mse

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=50, trials=trials)

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

model.save(model_save_path_100trials)

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_gas')
plt.title('Actual versus Predicho "prod_gas"')
plt.legend()
plt.savefig(image_save_path_100trials)
plt.show()

# Predecir "prod_gas" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [121, 122, 123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'prom_prod_gas': [filtered_data_one_id['prom_prod_gas'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_gas:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 190ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 193ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 400ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 202ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 213ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 265ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 200ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 211ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 210ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 255ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 199ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 207ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 190ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 294ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 253ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 199ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 201ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 316ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 294ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 225ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 199ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 202ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 296ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 4s 4s/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 244ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 198ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 277ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 203ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 258ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 296ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 201ms/step
#
# 100%|██████████| 50/50 [10:44<00:00, 12.89s/trial, best loss: 15503.080049974415]
# Mejor tamaño de lote: 64
# Mejor cantidad de épocas: 100
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1586 - val_loss: 0.0665
# Epoch 2/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1502 - val_loss: 0.0585
# Epoch 3/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1421 - val_loss: 0.0511
# Epoch 4/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1344 - val_loss: 0.0443
# Epoch 5/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1270 - val_loss: 0.0380
# Epoch 6/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1200 - val_loss: 0.0323
# Epoch 7/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1132 - val_loss: 0.0271
# Epoch 8/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1068 - val_loss: 0.0224
# Epoch 9/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1008 - val_loss: 0.0181
# Epoch 10/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0952 - val_loss: 0.0143
# Epoch 11/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0900 - val_loss: 0.0110
# Epoch 12/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0851 - val_loss: 0.0083
# Epoch 13/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0807 - val_loss: 0.0061
# Epoch 14/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0767 - val_loss: 0.0044
# Epoch 15/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0730 - val_loss: 0.0033
# Epoch 16/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0697 - val_loss: 0.0025
# Epoch 17/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0668 - val_loss: 0.0022
# Epoch 18/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0644 - val_loss: 0.0021
# Epoch 19/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0622 - val_loss: 0.0023
# Epoch 20/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0603 - val_loss: 0.0026
# Epoch 21/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0587 - val_loss: 0.0030
# Epoch 22/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0573 - val_loss: 0.0033
# Epoch 23/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0561 - val_loss: 0.0036
# Epoch 24/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0549 - val_loss: 0.0038
# Epoch 25/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0538 - val_loss: 0.0039
# Epoch 26/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0527 - val_loss: 0.0038
# Epoch 27/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0517 - val_loss: 0.0036
# Epoch 28/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0505 - val_loss: 0.0033
# Epoch 29/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0493 - val_loss: 0.0029
# Epoch 30/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0480 - val_loss: 0.0026
# Epoch 31/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0467 - val_loss: 0.0023
# Epoch 32/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0452 - val_loss: 0.0021
# Epoch 33/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0437 - val_loss: 0.0022
# Epoch 34/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0422 - val_loss: 0.0025
# Epoch 35/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0406 - val_loss: 0.0030
# Epoch 36/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0391 - val_loss: 0.0039
# Epoch 37/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0376 - val_loss: 0.0051
# Epoch 38/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0361 - val_loss: 0.0067
# Epoch 39/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0347 - val_loss: 0.0085
# Epoch 40/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0335 - val_loss: 0.0107
# Epoch 41/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0323 - val_loss: 0.0131
# Epoch 42/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0312 - val_loss: 0.0158
# Epoch 43/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0302 - val_loss: 0.0186
# Epoch 44/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0293 - val_loss: 0.0215
# Epoch 45/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0285 - val_loss: 0.0246
# Epoch 46/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0277 - val_loss: 0.0276
# Epoch 47/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0269 - val_loss: 0.0306
# Epoch 48/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0261 - val_loss: 0.0335
# Epoch 49/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0253 - val_loss: 0.0363
# Epoch 50/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0246 - val_loss: 0.0389
# Epoch 51/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0239 - val_loss: 0.0414
# Epoch 52/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0232 - val_loss: 0.0436
# Epoch 53/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0226 - val_loss: 0.0458
# Epoch 54/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0220 - val_loss: 0.0478
# Epoch 55/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0215 - val_loss: 0.0498
# Epoch 56/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0211 - val_loss: 0.0517
# Epoch 57/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0208 - val_loss: 0.0538
# Epoch 58/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0205 - val_loss: 0.0560
# Epoch 59/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0203 - val_loss: 0.0583
# Epoch 60/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0201 - val_loss: 0.0609
# Epoch 61/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0199 - val_loss: 0.0637
# Epoch 62/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0198 - val_loss: 0.0666
# Epoch 63/100
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0196 - val_loss: 0.0696
# Epoch 64/100
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0194 - val_loss: 0.0724
# Epoch 65/100
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0192 - val_loss: 0.0752
# Epoch 66/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0190 - val_loss: 0.0778
# Epoch 67/100
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0188 - val_loss: 0.0800
# Epoch 68/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0187 - val_loss: 0.0817
# Epoch 69/100
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0185 - val_loss: 0.0827
# Epoch 70/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0184 - val_loss: 0.0828
# Epoch 71/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0182 - val_loss: 0.0822
# Epoch 72/100
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0180 - val_loss: 0.0810
# Epoch 73/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0178 - val_loss: 0.0792
# Epoch 74/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0176 - val_loss: 0.0772
# Epoch 75/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0173 - val_loss: 0.0751
# Epoch 76/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0171 - val_loss: 0.0728
# Epoch 77/100
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0169 - val_loss: 0.0706
# Epoch 78/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0167 - val_loss: 0.0684
# Epoch 79/100
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0164 - val_loss: 0.0665
# Epoch 80/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0162 - val_loss: 0.0649
# Epoch 81/100
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0160 - val_loss: 0.0635
# Epoch 82/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0157 - val_loss: 0.0622
# Epoch 83/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0155 - val_loss: 0.0609
# Epoch 84/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0152 - val_loss: 0.0597
# Epoch 85/100
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0150 - val_loss: 0.0584
# Epoch 86/100
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0148 - val_loss: 0.0572
# Epoch 87/100
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0146 - val_loss: 0.0559
# Epoch 88/100
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0143 - val_loss: 0.0547
# Epoch 89/100
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0141 - val_loss: 0.0535
# Epoch 90/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0138 - val_loss: 0.0524
# Epoch 91/100
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0136 - val_loss: 0.0515
# Epoch 92/100
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0134 - val_loss: 0.0507
# Epoch 93/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0131 - val_loss: 0.0501
# Epoch 94/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0129 - val_loss: 0.0498
# Epoch 95/100
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0126 - val_loss: 0.0495
# Epoch 96/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0124 - val_loss: 0.0494
# Epoch 97/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0121 - val_loss: 0.0493
# Epoch 98/100
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0119 - val_loss: 0.0492
# Epoch 99/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0116 - val_loss: 0.0490
# Epoch 100/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0114 - val_loss: 0.0486
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 191ms/step
# Error Cuadrático Medio: 20158.219945414145
# Error Absoluto Medio: 137.9491829427083
# 1/1 [==============================] - 0s 23ms/step
# Predicciones para valores futuros de prod_gas: [356.1449  356.05273 355.2779  353.5454  351.81415 350.0842  348.35553
#  346.62814]

# %%
import matplotlib.pyplot as plt

# Filtrar los datos de prueba para los valores de date_numeric 121, 122 y 123
test_data = filtered_data_one_id[filtered_data_one_id['date_numeric'].isin([121, 122, 123])]

# Extraer la columna de 'prod_gas' para los valores de date_numeric 121, 122 y 123
real_values = test_data['prod_gas'].values

# Obtener las predicciones para los valores de date_numeric 121, 122 y 123
# Aquí 'predictions' se supone que contiene las predicciones de los valores futuros
predicted_values = predictions[:3].flatten()

# Imprimir los valores reales de prod_gas para date_numeric 121, 122 y 123
print("Valores reales de prod_gas para date_numeric 121, 122 y 123:", real_values)

# Imprimir los valores predichos de prod_gas para date_numeric 121, 122 y 123
print("Valores predichos de prod_gas para date_numeric 121, 122 y 123:", predicted_values)

# Graficar los valores reales vs los valores predichos
plt.figure(figsize=(10, 5))
plt.plot([121, 122, 123], real_values, label='Actual', marker='o')
plt.plot([121, 122, 123], predicted_values, label='Predicho', marker='x')
plt.xlabel('date_numeric')
plt.ylabel('prod_gas')
plt.title('Actual versus Predicho "prod_gas"')
plt.legend()
plt.savefig(image_save_path_three_lastmonths_100trials)
plt.show()
# Out:
# Valores reales de prod_gas para date_numeric 121, 122 y 123: [480.8  520.66 453.15]
# Valores predichos de prod_gas para date_numeric 121, 122 y 123: [356.1449  356.05273 355.2779 ]

# %%
# Load the existing CSV file

csv_results_file_path = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_MSE_100_trials.csv"
df = pd.read_csv(csv_results_file_path)

# Determine the current maximum index in the DataFrame
#max_index = df.index.max()

# Create a DataFrame with the new data, ensuring the indices are sequential from the current maximum index
#new_indices = [max_index + 1, max_index + 2, max_index + 3]

# Create a DataFrame with the new data
new_data = {
    'fecha': ['2024-01-01', '2024-02-01', '2024-03-01'],
    'idpozo': [idpozo, idpozo, idpozo],
    'prod_gas':predicted_values
}

new_df = pd.DataFrame(new_data)
combined_df = pd.concat([df, new_df], ignore_index=True)
combined_df.to_csv(csv_results_file_path, index=False)

#new_df = pd.DataFrame(new_data, index=new_indices)
#combined_df = pd.concat([df, new_df])
#combined_df.to_csv(csv_results_file_path, index=True, index_label='')

print(f'Nuevo valor agregado al csv {csv_results_file_path}')
# Out:
# Nuevo valor agregado al csv /content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_MSE_100_trials.csv
