# %% [markdown]
# #Partiendo de la limpieza de datos realizada previamente, se utiliza LSTM para predecir la producción de pozos de petroleo.
#
# ###Pozos a predecir:
# 158364, 160211, 160332, 160789, 160810, 160814, 161451, 162200, 162405, 162955, 163237, 163942

# %%
import math
import itertools
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import LSTM, Dense
from keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
pd.set_option('display.max_columns', None)

idpozo = 160789
model_save_path_50trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-50trials.h5"
image_save_path_50trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-50trials.png"
image_save_path_three_lastmonths_50trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}three_lastmonths-50trials.png"


model_save_path_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-100trials.h5"
image_save_path_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-100trials.png"
image_save_path_three_lastmonths_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}three_lastmonths-100trials.png"

model_save_path_mse_mae_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-mse_mae-100trials.h5"
image_save_path_mse_mae_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-mse_mae_100-trials.png"
image_save_path_three_lastmonths_mse_mae_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}three_lastmonths_mse_mae-100trials.png"

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

dataset = pd.read_csv("/content/drive/MyDrive/Trabajo profesional/Code/data/prod_norm_2024-05-27_03:42:59.csv", index_col=0)

dataset = dataset[dataset['anio'] >= 2014]

# Seleccionar características relevantes
features = ['prod_pet', 'anio', 'mes', 'idpozo', 'prod_gas', 'prod_agua', 'tef', 'coordenadax', 'coordenaday', 'cota']

# Filtrar características
data = dataset[features]

# Creacion de una nueva columna 'date' combinando 'anio' y 'mes' para representar la fecha
data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')

data.drop(['mes', 'anio'], axis=1, inplace=True)

# Conversion de la columna 'date' a "datetime type"
data['date'] = pd.to_datetime(data['date'])

# Definicion de un dia de referencia inicial (Es la primera fecha desde la que se filtro previamente).
reference_date = pd.Timestamp('2014-01-01')

# Calculo del numero de meses desde la referencia para cada date.
data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1

data.drop(['date'], axis=1, inplace=True)

filtered_data_one_id = data[data['idpozo'] == 158364]

filtered_data_one_id.drop(['idpozo'], axis=1, inplace=True)
# Out:
# Mounted at /content/drive
# <ipython-input-1-2e09e12f7d6d>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')
# <ipython-input-1-2e09e12f7d6d>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['mes', 'anio'], axis=1, inplace=True)
# <ipython-input-1-2e09e12f7d6d>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['date'])
# <ipython-input-1-2e09e12f7d6d>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1
# <ipython-input-1-2e09e12f7d6d>:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['date'], axis=1, inplace=True)
# <ipython-input-1-2e09e12f7d6d>:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data_one_id.drop(['idpozo'], axis=1, inplace=True)

# %%
filtered_data_one_id.head()
# Out:
#        prod_pet  prod_gas  prod_agua    tef  coordenadax  coordenaday    cota  \
# 23053  1793.305    469.41     439.56  29.96   -68.717131   -38.370635  520.96
# 24036  3070.740    685.92     991.75  30.73   -68.717131   -38.370635  520.96
# 25025  4157.410    996.36    1387.16  30.00   -68.717131   -38.370635  520.96
# 26040  4339.880   1052.52     652.70  30.88   -68.717131   -38.370635  520.96
# 27070  3592.575    833.34     520.78  30.96   -68.717131   -38.370635  520.96
#
#        date_numeric
# 23053            45
# 24036            46
# 25025            47
# 26040            48
# 27070            49

# %%
# 50 Trials - mse only

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_pet']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
#X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)
# Calcular el índice de corte para los últimos 3 valores (121, 122 y 123)
test_size = 3
split_index = len(X_sequences) - test_size

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test = X_sequences[:split_index], X_sequences[split_index:]
y_train, y_test = y_adjusted[:split_index], y_adjusted[split_index:]


# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, el error cuadrático medio)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    return mse

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=50, trials=trials)

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

model.save(model_save_path_50trials)

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.savefig(image_save_path_50trials)
plt.show()

# Predecir "prod_pet" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [121, 122, 123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_pet:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 199ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 171ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
#   8%|▊         | 4/50 [00:57<09:46, 12.75s/trial, best loss: 2388.8325025115514]
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x78345ab20160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
#  10%|█         | 5/50 [01:02<07:26,  9.92s/trial, best loss: 2388.8325025115514]
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x78345b65bd00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 254ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 463ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 165ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 195ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 269ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 166ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 273ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 171ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 207ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 164ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 262ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 193ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 242ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 164ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 262ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 164ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 311ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 201ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 289ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 232ms/step
#
# 100%|██████████| 50/50 [11:01<00:00, 13.22s/trial, best loss: 1659.1509714522444]
# Mejor tamaño de lote: 16
# Mejor cantidad de épocas: 200
# Epoch 1/200
# 5/5 [==============================] - 2s 71ms/step - loss: 0.0708 - val_loss: 0.0055
# Epoch 2/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0585 - val_loss: 0.0116
# Epoch 3/200
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0510 - val_loss: 0.0159
# Epoch 4/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0438 - val_loss: 0.0159
# Epoch 5/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0382 - val_loss: 0.0120
# Epoch 6/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0334 - val_loss: 0.0070
# Epoch 7/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0292 - val_loss: 0.0023
# Epoch 8/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0251 - val_loss: 2.7894e-04
# Epoch 9/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0220 - val_loss: 1.5809e-04
# Epoch 10/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0187 - val_loss: 1.6134e-04
# Epoch 11/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0161 - val_loss: 1.6134e-04
# Epoch 12/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0137 - val_loss: 1.6134e-04
# Epoch 13/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0125 - val_loss: 1.6134e-04
# Epoch 14/200
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0111 - val_loss: 1.6134e-04
# Epoch 15/200
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0104 - val_loss: 1.6134e-04
# Epoch 16/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0097 - val_loss: 1.6134e-04
# Epoch 17/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0094 - val_loss: 1.6134e-04
# Epoch 18/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0092 - val_loss: 1.6134e-04
# Epoch 19/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0093 - val_loss: 1.6134e-04
# Epoch 20/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0091 - val_loss: 1.6134e-04
# Epoch 21/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0094 - val_loss: 1.6134e-04
# Epoch 22/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0092 - val_loss: 1.6134e-04
# Epoch 23/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0090 - val_loss: 1.6134e-04
# Epoch 24/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0087 - val_loss: 1.6134e-04
# Epoch 25/200
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0088 - val_loss: 1.6134e-04
# Epoch 26/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0094 - val_loss: 1.6134e-04
# Epoch 27/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0090 - val_loss: 1.6134e-04
# Epoch 28/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0090 - val_loss: 1.6134e-04
# Epoch 29/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0087 - val_loss: 1.6134e-04
# Epoch 30/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0085 - val_loss: 1.6134e-04
# Epoch 31/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0086 - val_loss: 1.6134e-04
# Epoch 32/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0086 - val_loss: 1.6134e-04
# Epoch 33/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0085 - val_loss: 1.6134e-04
# Epoch 34/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0084 - val_loss: 1.6134e-04
# Epoch 35/200
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0087 - val_loss: 1.6134e-04
# Epoch 36/200
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0083 - val_loss: 1.6134e-04
# Epoch 37/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0083 - val_loss: 1.6134e-04
# Epoch 38/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0084 - val_loss: 1.6134e-04
# Epoch 39/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0084 - val_loss: 1.6134e-04
# Epoch 40/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0083 - val_loss: 1.6134e-04
# Epoch 41/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0082 - val_loss: 1.6134e-04
# Epoch 42/200
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0082 - val_loss: 1.6134e-04
# Epoch 43/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0081 - val_loss: 1.6134e-04
# Epoch 44/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0081 - val_loss: 1.6134e-04
# Epoch 45/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0080 - val_loss: 1.6134e-04
# Epoch 46/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0083 - val_loss: 1.6134e-04
# Epoch 47/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0086 - val_loss: 1.6134e-04
# Epoch 48/200
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0079 - val_loss: 1.6134e-04
# Epoch 49/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0082 - val_loss: 1.6134e-04
# Epoch 50/200
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0079 - val_loss: 1.6134e-04
# Epoch 51/200
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0080 - val_loss: 1.6134e-04
# Epoch 52/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0075 - val_loss: 1.6134e-04
# Epoch 53/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0079 - val_loss: 1.6134e-04
# Epoch 54/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0076 - val_loss: 1.6134e-04
# Epoch 55/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0086 - val_loss: 1.6134e-04
# Epoch 56/200
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0079 - val_loss: 1.6134e-04
# Epoch 57/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0076 - val_loss: 1.6134e-04
# Epoch 58/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0075 - val_loss: 1.6134e-04
# Epoch 59/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0073 - val_loss: 1.6134e-04
# Epoch 60/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0073 - val_loss: 1.6134e-04
# Epoch 61/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0072 - val_loss: 1.6134e-04
# Epoch 62/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0072 - val_loss: 1.6134e-04
# Epoch 63/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0071 - val_loss: 1.6134e-04
# Epoch 64/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 1.6134e-04
# Epoch 65/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0071 - val_loss: 1.6134e-04
# Epoch 66/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0069 - val_loss: 1.6134e-04
# Epoch 67/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0068 - val_loss: 1.6134e-04
# Epoch 68/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0067 - val_loss: 1.6134e-04
# Epoch 69/200
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0067 - val_loss: 1.6134e-04
# Epoch 70/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 1.6134e-04
# Epoch 71/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0067 - val_loss: 1.6134e-04
# Epoch 72/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0067 - val_loss: 1.6134e-04
# Epoch 73/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0063 - val_loss: 1.6134e-04
# Epoch 74/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0066 - val_loss: 1.6134e-04
# Epoch 75/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0062 - val_loss: 1.6134e-04
# Epoch 76/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0065 - val_loss: 1.6134e-04
# Epoch 77/200
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0064 - val_loss: 1.6134e-04
# Epoch 78/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0063 - val_loss: 1.6134e-04
# Epoch 79/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0062 - val_loss: 1.6134e-04
# Epoch 80/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0058 - val_loss: 1.6134e-04
# Epoch 81/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0060 - val_loss: 1.6134e-04
# Epoch 82/200
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0059 - val_loss: 1.6134e-04
# Epoch 83/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 1.6134e-04
# Epoch 84/200
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0055 - val_loss: 1.6134e-04
# Epoch 85/200
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0057 - val_loss: 1.6134e-04
# Epoch 86/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0052 - val_loss: 1.6134e-04
# Epoch 87/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 1.6134e-04
# Epoch 88/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 1.6134e-04
# Epoch 89/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0050 - val_loss: 1.6134e-04
# Epoch 90/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0048 - val_loss: 1.6134e-04
# Epoch 91/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 1.6134e-04
# Epoch 92/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0046 - val_loss: 1.6134e-04
# Epoch 93/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0046 - val_loss: 1.6134e-04
# Epoch 94/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 1.6134e-04
# Epoch 95/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0044 - val_loss: 1.6134e-04
# Epoch 96/200
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0042 - val_loss: 1.6134e-04
# Epoch 97/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0042 - val_loss: 1.6134e-04
# Epoch 98/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0041 - val_loss: 1.6134e-04
# Epoch 99/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0039 - val_loss: 1.6134e-04
# Epoch 100/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0038 - val_loss: 1.6134e-04
# Epoch 101/200
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0037 - val_loss: 1.6134e-04
# Epoch 102/200
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 1.6134e-04
# Epoch 103/200
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 1.6134e-04
# Epoch 104/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0035 - val_loss: 1.6134e-04
# Epoch 105/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0032 - val_loss: 1.6134e-04
# Epoch 106/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0031 - val_loss: 1.6134e-04
# Epoch 107/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0030 - val_loss: 1.6134e-04
# Epoch 108/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0028 - val_loss: 1.6134e-04
# Epoch 109/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0028 - val_loss: 1.6134e-04
# Epoch 110/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 1.6134e-04
# Epoch 111/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 1.6134e-04
# Epoch 112/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 1.6134e-04
# Epoch 113/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 1.6134e-04
# Epoch 114/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0023 - val_loss: 1.6134e-04
# Epoch 115/200
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0021 - val_loss: 1.6134e-04
# Epoch 116/200
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0026 - val_loss: 1.6134e-04
# Epoch 117/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0022 - val_loss: 1.6134e-04
# Epoch 118/200
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0023 - val_loss: 1.6134e-04
# Epoch 119/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0018 - val_loss: 1.2313e-04
# Epoch 120/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0019 - val_loss: 1.6134e-04
# Epoch 121/200
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0017 - val_loss: 1.6134e-04
# Epoch 122/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0017 - val_loss: 1.6134e-04
# Epoch 123/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 1.2773e-04
# Epoch 124/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 1.6134e-04
# Epoch 125/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 1.6134e-04
# Epoch 126/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0016 - val_loss: 1.1406e-04
# Epoch 127/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 1.6134e-04
# Epoch 128/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 1.0983e-04
# Epoch 129/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 8.7751e-05
# Epoch 130/200
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 1.1863e-04
# Epoch 131/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 1.0935e-04
# Epoch 132/200
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0014 - val_loss: 1.3271e-04
# Epoch 133/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0014 - val_loss: 1.0882e-04
# Epoch 134/200
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0013 - val_loss: 1.3379e-04
# Epoch 135/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 1.1096e-04
# Epoch 136/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 8.1978e-05
# Epoch 137/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 1.0504e-04
# Epoch 138/200
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0016 - val_loss: 7.5720e-05
# Epoch 139/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 1.4446e-04
# Epoch 140/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 7.6626e-05
# Epoch 141/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 7.6729e-05
# Epoch 142/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 1.3021e-04
# Epoch 143/200
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 1.1283e-04
# Epoch 144/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 8.0098e-05
# Epoch 145/200
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 1.0734e-04
# Epoch 146/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0015 - val_loss: 7.6338e-05
# Epoch 147/200
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 1.5374e-04
# Epoch 148/200
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 7.8537e-05
# Epoch 149/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0013 - val_loss: 1.2046e-04
# Epoch 150/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 8.2756e-05
# Epoch 151/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0013 - val_loss: 7.5901e-05
# Epoch 152/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 1.1860e-04
# Epoch 153/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 7.5741e-05
# Epoch 154/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 1.2222e-04
# Epoch 155/200
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 7.7519e-05
# Epoch 156/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 9.8146e-05
# Epoch 157/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 1.2127e-04
# Epoch 158/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 7.7543e-05
# Epoch 159/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0014 - val_loss: 1.1096e-04
# Epoch 160/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 1.6134e-04
# Epoch 161/200
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0014 - val_loss: 8.3730e-05
# Epoch 162/200
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 1.1169e-04
# Epoch 163/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0014 - val_loss: 1.1331e-04
# Epoch 164/200
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0013 - val_loss: 8.2582e-05
# Epoch 165/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0015 - val_loss: 1.2386e-04
# Epoch 166/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0014 - val_loss: 7.9302e-05
# Epoch 167/200
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0012 - val_loss: 1.2269e-04
# Epoch 168/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0013 - val_loss: 1.1072e-04
# Epoch 169/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 7.7477e-05
# Epoch 170/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0012 - val_loss: 7.8651e-05
# Epoch 171/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 1.2586e-04
# Epoch 172/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 1.1923e-04
# Epoch 173/200
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 9.2158e-05
# Epoch 174/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0013 - val_loss: 1.1151e-04
# Epoch 175/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0012 - val_loss: 7.7420e-05
# Epoch 176/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 1.1285e-04
# Epoch 177/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 1.3176e-04
# Epoch 178/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 8.0647e-05
# Epoch 179/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 1.1186e-04
# Epoch 180/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 1.0894e-04
# Epoch 181/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 1.1583e-04
# Epoch 182/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0012 - val_loss: 1.1176e-04
# Epoch 183/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 7.9967e-05
# Epoch 184/200
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 1.1122e-04
# Epoch 185/200
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 1.0915e-04
# Epoch 186/200
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 9.0179e-05
# Epoch 187/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0013 - val_loss: 8.9826e-05
# Epoch 188/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0012 - val_loss: 1.4046e-04
# Epoch 189/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0012 - val_loss: 1.1969e-04
# Epoch 190/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 7.9436e-05
# Epoch 191/200
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0013 - val_loss: 7.6666e-05
# Epoch 192/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0013 - val_loss: 1.3656e-04
# Epoch 193/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0014 - val_loss: 8.0296e-05
# Epoch 194/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0011 - val_loss: 1.3950e-04
# Epoch 195/200
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0013 - val_loss: 1.0572e-04
# Epoch 196/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0012 - val_loss: 1.0513e-04
# Epoch 197/200
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 1.4345e-04
# Epoch 198/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0012 - val_loss: 1.0143e-04
# Epoch 199/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0012 - val_loss: 1.1783e-04
# Epoch 200/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0012 - val_loss: 1.1245e-04
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 181ms/step
# Error Cuadrático Medio: 1771.0520409692435
# Error Absoluto Medio: 38.6709045410156
# 1/1 [==============================] - 0s 20ms/step
# Predicciones para valores futuros de prod_pet: [463.99664 479.16858 481.51633 473.5027  465.6724  458.02225 450.56805
#  443.26398]

# %%
import matplotlib.pyplot as plt

# Filtrar los datos de prueba para los valores de date_numeric 121, 122 y 123
test_data = filtered_data_one_id[filtered_data_one_id['date_numeric'].isin([121, 122, 123])]

# Extraer la columna de 'prod_pet' para los valores de date_numeric 121, 122 y 123
real_values = test_data['prod_pet'].values

# Obtener las predicciones para los valores de date_numeric 121, 122 y 123
# Aquí 'predictions' se supone que contiene las predicciones de los valores futuros
predicted_values = predictions[:3].flatten()

# Imprimir los valores reales de prod_pet para date_numeric 121, 122 y 123
print("Valores reales de prod_pet para date_numeric 121, 122 y 123:", real_values)

# Imprimir los valores predichos de prod_pet para date_numeric 121, 122 y 123
print("Valores predichos de prod_pet para date_numeric 121, 122 y 123:", predicted_values)

# Graficar los valores reales vs los valores predichos
plt.figure(figsize=(10, 5))
plt.plot([121, 122, 123], real_values, label='Actual', marker='o')
plt.plot([121, 122, 123], predicted_values, label='Predicho', marker='x')
plt.xlabel('date_numeric')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.savefig(image_save_path_three_lastmonths_50trials)
plt.show()
# Out:
# Valores reales de prod_pet para date_numeric 121, 122 y 123: [421.65 421.65 421.65]
# Valores predichos de prod_pet para date_numeric 121, 122 y 123: [463.99664 479.16858 481.51633]

# %%
# Load the existing CSV file

csv_results_file_path = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_MSE_50_trials.csv"
df = pd.read_csv(csv_results_file_path)

# Determine the current maximum index in the DataFrame
#max_index = df.index.max()

# Create a DataFrame with the new data, ensuring the indices are sequential from the current maximum index
#new_indices = [max_index + 1, max_index + 2, max_index + 3]

# Create a DataFrame with the new data
new_data = {
    'fecha': ['2024-01-01', '2024-02-01', '2024-03-01'],
    'idpozo': [idpozo, idpozo, idpozo],
    'prod_pet':predicted_values
}

new_df = pd.DataFrame(new_data)
combined_df = pd.concat([df, new_df], ignore_index=True)
combined_df.to_csv(csv_results_file_path, index=False)

#new_df = pd.DataFrame(new_data, index=new_indices)
#combined_df = pd.concat([df, new_df])
#combined_df.to_csv(csv_results_file_path, index=True, index_label='')

print(f'Nuevo valor agregado al csv {csv_results_file_path}')
# Out:
# Nuevo valor agregado al csv /content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_MSE_50_trials.csv

# %%
#Funcion objetivo mse y mae - 100 trials

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials
import tensorflow as tf

# Establecer una semilla aleatoria para reproducibilidad
np.random.seed(42)
tf.random.set_seed(42)

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_pet']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
#X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)
# Calcular el índice de corte para los últimos 3 valores (121, 122 y 123)
test_size = 3
split_index = len(X_sequences) - test_size

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test = X_sequences[:split_index], X_sequences[split_index:]
y_train, y_test = y_adjusted[:split_index], y_adjusted[split_index:]

# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, la combinación de MSE y MAE)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)

    # Calcular el MSE y MAE
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

    # Combinar MSE y MAE en una única métrica
    combined_metric = 0.5 * mse + 0.5 * mae
    return combined_metric

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=100, trials=trials)  # Aumentar max_evals

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

model.save(model_save_path_mse_mae_100trials)

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.savefig(image_save_path_mse_mae_100trials)
plt.show()

# Predecir "prod_pet" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [121, 122, 123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_pet:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 193ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 186ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 241ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 296ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 244ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 163ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 291ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 251ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 243ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 273ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 246ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 257ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 261ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 253ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 207ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 190ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 278ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 186ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 257ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 249ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 203ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 178ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 263ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 198ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 300ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 178ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 286ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 171ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 219ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 265ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 171ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 166ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 253ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 203ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 256ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 193ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 287ms/step
#
# 100%|██████████| 100/100 [22:59<00:00, 13.79s/trial, best loss: 501.20288733835594]
# Mejor tamaño de lote: 32
# Mejor cantidad de épocas: 200
# Epoch 1/200
# 3/3 [==============================] - 2s 137ms/step - loss: 0.0718 - val_loss: 0.0084
# Epoch 2/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0589 - val_loss: 0.0181
# Epoch 3/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0498 - val_loss: 0.0265
# Epoch 4/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0446 - val_loss: 0.0318
# Epoch 5/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0401 - val_loss: 0.0310
# Epoch 6/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0367 - val_loss: 0.0277
# Epoch 7/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0340 - val_loss: 0.0218
# Epoch 8/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0310 - val_loss: 0.0140
# Epoch 9/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0279 - val_loss: 0.0081
# Epoch 10/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0255 - val_loss: 0.0037
# Epoch 11/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0234 - val_loss: 0.0011
# Epoch 12/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0218 - val_loss: 1.5362e-04
# Epoch 13/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0198 - val_loss: 6.2247e-05
# Epoch 14/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0180 - val_loss: 1.3569e-04
# Epoch 15/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0162 - val_loss: 1.6134e-04
# Epoch 16/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0151 - val_loss: 1.6134e-04
# Epoch 17/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0141 - val_loss: 1.6134e-04
# Epoch 18/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0131 - val_loss: 1.6134e-04
# Epoch 19/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0125 - val_loss: 1.6134e-04
# Epoch 20/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0120 - val_loss: 1.6134e-04
# Epoch 21/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0114 - val_loss: 1.6134e-04
# Epoch 22/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0108 - val_loss: 1.6134e-04
# Epoch 23/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0103 - val_loss: 1.6134e-04
# Epoch 24/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0100 - val_loss: 1.6134e-04
# Epoch 25/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0098 - val_loss: 1.6134e-04
# Epoch 26/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0095 - val_loss: 1.6134e-04
# Epoch 27/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0093 - val_loss: 1.6134e-04
# Epoch 28/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0093 - val_loss: 1.6134e-04
# Epoch 29/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0090 - val_loss: 1.6134e-04
# Epoch 30/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0090 - val_loss: 1.6134e-04
# Epoch 31/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0088 - val_loss: 1.6134e-04
# Epoch 32/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0087 - val_loss: 1.6134e-04
# Epoch 33/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0087 - val_loss: 1.6134e-04
# Epoch 34/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0087 - val_loss: 1.6134e-04
# Epoch 35/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0086 - val_loss: 1.6134e-04
# Epoch 36/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0086 - val_loss: 1.6134e-04
# Epoch 37/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0086 - val_loss: 1.6134e-04
# Epoch 38/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0087 - val_loss: 1.6134e-04
# Epoch 39/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0085 - val_loss: 1.6134e-04
# Epoch 40/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0086 - val_loss: 1.6134e-04
# Epoch 41/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0087 - val_loss: 1.6134e-04
# Epoch 42/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0084 - val_loss: 1.6134e-04
# Epoch 43/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0084 - val_loss: 1.6134e-04
# Epoch 44/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0084 - val_loss: 1.6134e-04
# Epoch 45/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0084 - val_loss: 1.6134e-04
# Epoch 46/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0083 - val_loss: 1.6134e-04
# Epoch 47/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0084 - val_loss: 1.6134e-04
# Epoch 48/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0086 - val_loss: 1.6134e-04
# Epoch 49/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0087 - val_loss: 1.6134e-04
# Epoch 50/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0087 - val_loss: 1.6134e-04
# Epoch 51/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0087 - val_loss: 1.6134e-04
# Epoch 52/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0083 - val_loss: 1.6134e-04
# Epoch 53/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0083 - val_loss: 1.6134e-04
# Epoch 54/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0083 - val_loss: 1.6134e-04
# Epoch 55/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0082 - val_loss: 1.6134e-04
# Epoch 56/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0080 - val_loss: 1.6134e-04
# Epoch 57/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0083 - val_loss: 1.6134e-04
# Epoch 58/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0078 - val_loss: 1.6134e-04
# Epoch 59/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0084 - val_loss: 1.6134e-04
# Epoch 60/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0087 - val_loss: 1.6134e-04
# Epoch 61/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0080 - val_loss: 1.6134e-04
# Epoch 62/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0083 - val_loss: 1.6134e-04
# Epoch 63/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0083 - val_loss: 1.6134e-04
# Epoch 64/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0079 - val_loss: 1.6134e-04
# Epoch 65/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0080 - val_loss: 1.6134e-04
# Epoch 66/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0079 - val_loss: 1.6134e-04
# Epoch 67/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0078 - val_loss: 1.6134e-04
# Epoch 68/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0078 - val_loss: 1.6134e-04
# Epoch 69/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0077 - val_loss: 1.6134e-04
# Epoch 70/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0077 - val_loss: 1.6134e-04
# Epoch 71/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0077 - val_loss: 1.6134e-04
# Epoch 72/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0079 - val_loss: 1.6134e-04
# Epoch 73/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0077 - val_loss: 1.6134e-04
# Epoch 74/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0076 - val_loss: 1.6134e-04
# Epoch 75/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0083 - val_loss: 1.6134e-04
# Epoch 76/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0083 - val_loss: 1.6134e-04
# Epoch 77/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0074 - val_loss: 1.6134e-04
# Epoch 78/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0074 - val_loss: 1.6134e-04
# Epoch 79/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0074 - val_loss: 1.6134e-04
# Epoch 80/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0073 - val_loss: 1.6134e-04
# Epoch 81/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0073 - val_loss: 1.6134e-04
# Epoch 82/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0074 - val_loss: 1.6134e-04
# Epoch 83/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0071 - val_loss: 1.6134e-04
# Epoch 84/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0074 - val_loss: 1.6134e-04
# Epoch 85/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0075 - val_loss: 1.6134e-04
# Epoch 86/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0071 - val_loss: 1.6134e-04
# Epoch 87/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0070 - val_loss: 1.6134e-04
# Epoch 88/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0071 - val_loss: 1.6134e-04
# Epoch 89/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0070 - val_loss: 1.6134e-04
# Epoch 90/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.
200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 1.6134e-04
# Epoch 150/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0022 - val_loss: 1.6134e-04
# Epoch 151/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0021 - val_loss: 1.6134e-04
# Epoch 152/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0020 - val_loss: 1.6134e-04
# Epoch 153/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0020 - val_loss: 1.6134e-04
# Epoch 154/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0019 - val_loss: 1.6134e-04
# Epoch 155/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0020 - val_loss: 1.6134e-04
# Epoch 156/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0018 - val_loss: 1.1899e-04
# Epoch 157/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0019 - val_loss: 1.5367e-04
# Epoch 158/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0017 - val_loss: 1.6134e-04
# Epoch 159/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0017 - val_loss: 1.6134e-04
# Epoch 160/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0019 - val_loss: 1.6134e-04
# Epoch 161/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0017 - val_loss: 1.5736e-04
# Epoch 162/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0018 - val_loss: 1.3502e-04
# Epoch 163/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0017 - val_loss: 1.6134e-04
# Epoch 164/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0015 - val_loss: 1.6134e-04
# Epoch 165/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0017 - val_loss: 1.6134e-04
# Epoch 166/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0016 - val_loss: 1.1049e-04
# Epoch 167/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0015 - val_loss: 1.0384e-04
# Epoch 168/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0014 - val_loss: 1.6094e-04
# Epoch 169/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0014 - val_loss: 1.6134e-04
# Epoch 170/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0014 - val_loss: 1.6134e-04
# Epoch 171/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0015 - val_loss: 1.6134e-04
# Epoch 172/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0015 - val_loss: 1.5937e-04
# Epoch 173/200
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0013 - val_loss: 1.5728e-04
# Epoch 174/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0015 - val_loss: 1.4565e-04
# Epoch 175/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0017 - val_loss: 6.6156e-05
# Epoch 176/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0015 - val_loss: 5.9103e-05
# Epoch 177/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0014 - val_loss: 9.3371e-05
# Epoch 178/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0013 - val_loss: 1.5496e-04
# Epoch 179/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0014 - val_loss: 1.6134e-04
# Epoch 180/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0013 - val_loss: 1.5605e-04
# Epoch 181/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0013 - val_loss: 1.1869e-04
# Epoch 182/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0013 - val_loss: 8.9425e-05
# Epoch 183/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0012 - val_loss: 1.2316e-04
# Epoch 184/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0013 - val_loss: 1.1395e-04
# Epoch 185/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0013 - val_loss: 6.2757e-05
# Epoch 186/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0013 - val_loss: 7.8119e-05
# Epoch 187/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0015 - val_loss: 6.3505e-05
# Epoch 188/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0014 - val_loss: 1.5720e-04
# Epoch 189/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0013 - val_loss: 1.6134e-04
# Epoch 190/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0013 - val_loss: 1.1942e-04
# Epoch 191/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0012 - val_loss: 6.1722e-05
# Epoch 192/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0013 - val_loss: 5.9589e-05
# Epoch 193/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0014 - val_loss: 6.7206e-05
# Epoch 194/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0013 - val_loss: 8.0597e-05
# Epoch 195/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0012 - val_loss: 1.4358e-04
# Epoch 196/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0013 - val_loss: 1.6134e-04
# Epoch 197/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0013 - val_loss: 1.6134e-04
# Epoch 198/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0013 - val_loss: 1.1477e-04
# Epoch 199/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0012 - val_loss: 8.1606e-05
# Epoch 200/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0013 - val_loss: 8.3384e-05
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 172ms/step
# Error Cuadrático Medio: 1313.3146394294115
# Error Absoluto Medio: 30.481329345703102
# 1/1 [==============================] - 0s 20ms/step
# Predicciones para valores futuros de prod_pet: [464.54446 477.11417 479.55423 472.12054 464.75778 457.5279  450.4797
#  443.60654]

# %%
import matplotlib.pyplot as plt

# Filtrar los datos de prueba para los valores de date_numeric 121, 122 y 123
test_data = filtered_data_one_id[filtered_data_one_id['date_numeric'].isin([121, 122, 123])]

# Extraer la columna de 'prod_pet' para los valores de date_numeric 121, 122 y 123
real_values = test_data['prod_pet'].values

# Obtener las predicciones para los valores de date_numeric 121, 122 y 123
# Aquí 'predictions' se supone que contiene las predicciones de los valores futuros
predicted_values = predictions[:3].flatten()

# Imprimir los valores reales de prod_pet para date_numeric 121, 122 y 123
print("Valores reales de prod_pet para date_numeric 121, 122 y 123:", real_values)

# Imprimir los valores predichos de prod_pet para date_numeric 121, 122 y 123
print("Valores predichos de prod_pet para date_numeric 121, 122 y 123:", predicted_values)

# Graficar los valores reales vs los valores predichos
plt.figure(figsize=(10, 5))
plt.plot([121, 122, 123], real_values, label='Actual', marker='o')
plt.plot([121, 122, 123], predicted_values, label='Predicho', marker='x')
plt.xlabel('date_numeric')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.savefig(image_save_path_three_lastmonths_mse_mae_100trials)
plt.show()
# Out:
# Valores reales de prod_pet para date_numeric 121, 122 y 123: [421.65 421.65 421.65]
# Valores predichos de prod_pet para date_numeric 121, 122 y 123: [464.54446 477.11417 479.55423]

# %%
# Load the existing CSV file

csv_results_file_path = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_MSE_MAE_100_trials.csv"
df = pd.read_csv(csv_results_file_path)

# Determine the current maximum index in the DataFrame
#max_index = df.index.max()

# Create a DataFrame with the new data, ensuring the indices are sequential from the current maximum index
#new_indices = [max_index + 1, max_index + 2, max_index + 3]

# Create a DataFrame with the new data
new_data = {
    'fecha': ['2024-01-01', '2024-02-01', '2024-03-01'],
    'idpozo': [idpozo, idpozo, idpozo],
    'prod_pet':predicted_values
}

new_df = pd.DataFrame(new_data)
combined_df = pd.concat([df, new_df], ignore_index=True)
combined_df.to_csv(csv_results_file_path, index=False)

#new_df = pd.DataFrame(new_data, index=new_indices)
#combined_df = pd.concat([df, new_df])
#combined_df.to_csv(csv_results_file_path, index=True, index_label='')

print(f'Nuevo valor agregado al csv {csv_results_file_path}')
# Out:
# Nuevo valor agregado al csv /content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_MSE_MAE_100_trials.csv

# %%
# Con 100 Trials - mse only

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_pet']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
#X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)
# Calcular el índice de corte para los últimos 3 valores (121, 122 y 123)
test_size = 3
split_index = len(X_sequences) - test_size

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test = X_sequences[:split_index], X_sequences[split_index:]
y_train, y_test = y_adjusted[:split_index], y_adjusted[split_index:]


# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, el error cuadrático medio)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    return mse

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=50, trials=trials)

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

model.save(model_save_path_100trials)

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.savefig(image_save_path_100trials)
plt.show()

# Predecir "prod_pet" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [121, 122, 123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_pet:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 279ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 171ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 257ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 241ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 166ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 312ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 252ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 194ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 276ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 239ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 201ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 284ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 254ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 165ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 260ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 165ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 242ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 244ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 201ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 251ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 178ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 100%|██████████| 50/50 [12:49<00:00, 15.39s/trial, best loss: 1050.1736871462679]
# Mejor tamaño de lote: 32
# Mejor cantidad de épocas: 200
# Epoch 1/200
# 3/3 [==============================] - 2s 134ms/step - loss: 0.0660 - val_loss: 0.0021
# Epoch 2/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0536 - val_loss: 0.0066
# Epoch 3/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0444 - val_loss: 0.0120
# Epoch 4/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0388 - val_loss: 0.0167
# Epoch 5/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0343 - val_loss: 0.0183
# Epoch 6/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0313 - val_loss: 0.0173
# Epoch 7/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0292 - val_loss: 0.0137
# Epoch 8/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0266 - val_loss: 0.0083
# Epoch 9/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0240 - val_loss: 0.0039
# Epoch 10/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0218 - val_loss: 9.6144e-04
# Epoch 11/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0199 - val_loss: 6.5829e-05
# Epoch 12/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0186 - val_loss: 1.6134e-04
# Epoch 13/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0172 - val_loss: 1.6134e-04
# Epoch 14/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0158 - val_loss: 1.6134e-04
# Epoch 15/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0143 - val_loss: 1.6134e-04
# Epoch 16/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0135 - val_loss: 1.6134e-04
# Epoch 17/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0130 - val_loss: 1.6134e-04
# Epoch 18/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0121 - val_loss: 1.6134e-04
# Epoch 19/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0114 - val_loss: 1.6134e-04
# Epoch 20/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0111 - val_loss: 1.6134e-04
# Epoch 21/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0109 - val_loss: 1.6134e-04
# Epoch 22/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0105 - val_loss: 1.6134e-04
# Epoch 23/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0100 - val_loss: 1.6134e-04
# Epoch 24/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0097 - val_loss: 1.6134e-04
# Epoch 25/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0096 - val_loss: 1.6134e-04
# Epoch 26/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0093 - val_loss: 1.6134e-04
# Epoch 27/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0091 - val_loss: 1.6134e-04
# Epoch 28/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0092 - val_loss: 1.6134e-04
# Epoch 29/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0089 - val_loss: 1.6134e-04
# Epoch 30/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0089 - val_loss: 1.6134e-04
# Epoch 31/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0088 - val_loss: 1.6134e-04
# Epoch 32/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0087 - val_loss: 1.6134e-04
# Epoch 33/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0086 - val_loss: 1.6134e-04
# Epoch 34/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0087 - val_loss: 1.6134e-04
# Epoch 35/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0086 - val_loss: 1.6134e-04
# Epoch 36/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0086 - val_loss: 1.6134e-04
# Epoch 37/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0086 - val_loss: 1.6134e-04
# Epoch 38/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0088 - val_loss: 1.6134e-04
# Epoch 39/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0086 - val_loss: 1.6134e-04
# Epoch 40/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0086 - val_loss: 1.6134e-04
# Epoch 41/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0087 - val_loss: 1.6134e-04
# Epoch 42/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0085 - val_loss: 1.6134e-04
# Epoch 43/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0085 - val_loss: 1.6134e-04
# Epoch 44/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0085 - val_loss: 1.6134e-04
# Epoch 45/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0085 - val_loss: 1.6134e-04
# Epoch 46/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0084 - val_loss: 1.6134e-04
# Epoch 47/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0084 - val_loss: 1.6134e-04
# Epoch 48/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0087 - val_loss: 1.6134e-04
# Epoch 49/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0087 - val_loss: 1.6134e-04
# Epoch 50/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0086 - val_loss: 1.6134e-04
# Epoch 51/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0088 - val_loss: 1.6134e-04
# Epoch 52/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0084 - val_loss: 1.6134e-04
# Epoch 53/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0084 - val_loss: 1.6134e-04
# Epoch 54/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0084 - val_loss: 1.6134e-04
# Epoch 55/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0083 - val_loss: 1.6134e-04
# Epoch 56/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0081 - val_loss: 1.6134e-04
# Epoch 57/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0084 - val_loss: 1.6134e-04
# Epoch 58/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0080 - val_loss: 1.6134e-04
# Epoch 59/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0083 - val_loss: 1.6134e-04
# Epoch 60/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0085 - val_loss: 1.6134e-04
# Epoch 61/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0081 - val_loss: 1.6134e-04
# Epoch 62/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0083 - val_loss: 1.6134e-04
# Epoch 63/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0082 - val_loss: 1.6134e-04
# Epoch 64/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0079 - val_loss: 1.6134e-04
# Epoch 65/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0080 - val_loss: 1.6134e-04
# Epoch 66/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0080 - val_loss: 1.6134e-04
# Epoch 67/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0080 - val_loss: 1.6134e-04
# Epoch 68/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0079 - val_loss: 1.6134e-04
# Epoch 69/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0078 - val_loss: 1.6134e-04
# Epoch 70/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.
200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0013 - val_loss: 1.6134e-04
# Epoch 185/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0014 - val_loss: 1.2279e-04
# Epoch 186/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0013 - val_loss: 8.4345e-05
# Epoch 187/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0015 - val_loss: 9.0105e-05
# Epoch 188/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0015 - val_loss: 1.6134e-04
# Epoch 189/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0013 - val_loss: 1.6134e-04
# Epoch 190/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0013 - val_loss: 1.6134e-04
# Epoch 191/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0013 - val_loss: 1.3050e-04
# Epoch 192/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0013 - val_loss: 8.7530e-05
# Epoch 193/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0014 - val_loss: 1.1208e-04
# Epoch 194/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0013 - val_loss: 1.3098e-04
# Epoch 195/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0012 - val_loss: 1.6134e-04
# Epoch 196/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0012 - val_loss: 1.6134e-04
# Epoch 197/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0013 - val_loss: 1.6134e-04
# Epoch 198/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0013 - val_loss: 1.6134e-04
# Epoch 199/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0012 - val_loss: 1.6134e-04
# Epoch 200/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0013 - val_loss: 1.6134e-04
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 169ms/step
# Error Cuadrático Medio: 2541.1690845704056
# Error Absoluto Medio: 50.41000976562498
# 1/1 [==============================] - 0s 20ms/step
# Predicciones para valores futuros de prod_pet: [428.63107 446.1787  446.6798  436.73734 427.09564 417.5913  408.22272
#  399.0657 ]

# %%
import matplotlib.pyplot as plt

# Filtrar los datos de prueba para los valores de date_numeric 121, 122 y 123
test_data = filtered_data_one_id[filtered_data_one_id['date_numeric'].isin([121, 122, 123])]

# Extraer la columna de 'prod_pet' para los valores de date_numeric 121, 122 y 123
real_values = test_data['prod_pet'].values

# Obtener las predicciones para los valores de date_numeric 121, 122 y 123
# Aquí 'predictions' se supone que contiene las predicciones de los valores futuros
predicted_values = predictions[:3].flatten()

# Imprimir los valores reales de prod_pet para date_numeric 121, 122 y 123
print("Valores reales de prod_pet para date_numeric 121, 122 y 123:", real_values)

# Imprimir los valores predichos de prod_pet para date_numeric 121, 122 y 123
print("Valores predichos de prod_pet para date_numeric 121, 122 y 123:", predicted_values)

# Graficar los valores reales vs los valores predichos
plt.figure(figsize=(10, 5))
plt.plot([121, 122, 123], real_values, label='Actual', marker='o')
plt.plot([121, 122, 123], predicted_values, label='Predicho', marker='x')
plt.xlabel('date_numeric')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.savefig(image_save_path_three_lastmonths_100trials)
plt.show()
# Out:
# Valores reales de prod_pet para date_numeric 121, 122 y 123: [421.65 421.65 421.65]
# Valores predichos de prod_pet para date_numeric 121, 122 y 123: [428.63107 446.1787  446.6798 ]

# %%
# Load the existing CSV file

csv_results_file_path = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_MSE_100_trials.csv"
df = pd.read_csv(csv_results_file_path)

# Determine the current maximum index in the DataFrame
#max_index = df.index.max()

# Create a DataFrame with the new data, ensuring the indices are sequential from the current maximum index
#new_indices = [max_index + 1, max_index + 2, max_index + 3]

# Create a DataFrame with the new data
new_data = {
    'fecha': ['2024-01-01', '2024-02-01', '2024-03-01'],
    'idpozo': [idpozo, idpozo, idpozo],
    'prod_pet':predicted_values
}

new_df = pd.DataFrame(new_data)
combined_df = pd.concat([df, new_df], ignore_index=True)
combined_df.to_csv(csv_results_file_path, index=False)

#new_df = pd.DataFrame(new_data, index=new_indices)
#combined_df = pd.concat([df, new_df])
#combined_df.to_csv(csv_results_file_path, index=True, index_label='')

print(f'Nuevo valor agregado al csv {csv_results_file_path}')
# Out:
# Nuevo valor agregado al csv /content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_MSE_100_trials.csv
