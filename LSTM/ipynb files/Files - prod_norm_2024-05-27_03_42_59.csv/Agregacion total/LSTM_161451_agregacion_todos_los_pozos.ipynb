# %% [markdown]
# #Partiendo de la limpieza de datos realizada previamente, se utiliza LSTM para predecir la producción de pozos de petroleo.
#
# ###Pozos a predecir:
# 158364, 160211, 160332, 160789, 160810, 160814, 161451, 162200, 162405, 162955, 163237, 163942

# %%
import math
import itertools
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import LSTM, Dense
from keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
pd.set_option('display.max_columns', None)

idpozo = 161451
model_save_path_50trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-50trials.h5"
image_save_path_50trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-50trials.png"
image_save_path_three_lastmonths_50trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}three_lastmonths-50trials.png"


model_save_path_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-100trials.h5"
image_save_path_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-100trials.png"
image_save_path_three_lastmonths_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}three_lastmonths-100trials.png"

model_save_path_mse_mae_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-mse_mae-100trials.h5"
image_save_path_mse_mae_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-mse_mae_100-trials.png"
image_save_path_three_lastmonths_mse_mae_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}three_lastmonths_mse_mae-100trials.png"

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

dataset = pd.read_csv("/content/drive/MyDrive/Trabajo profesional/Code/data/prod_norm_2024-05-27_03:42:59.csv", index_col=0)

dataset = dataset[dataset['anio'] >= 2014]

# Seleccionar características relevantes
features = ['prod_pet', 'anio', 'mes', 'idpozo', 'prod_gas', 'prod_agua', 'tef', 'coordenadax', 'coordenaday', 'cota', 'areayacimiento']

# Filtrar características
data = dataset[features]

# Creacion de una nueva columna 'date' combinando 'anio' y 'mes' para representar la fecha
data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')

data.drop(['mes', 'anio'], axis=1, inplace=True)

# Conversion de la columna 'date' a "datetime type"
data['date'] = pd.to_datetime(data['date'])

# Definicion de un dia de referencia inicial (Es la primera fecha desde la que se filtro previamente).
reference_date = pd.Timestamp('2014-01-01')

# Calculo del numero de meses desde la referencia para cada date.
data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1

data.drop(['date'], axis=1, inplace=True)

# Agrupar por 'date_numeric' para calcular el promedio de 'prod_pet'
grouped = data.groupby(['date_numeric'])['prod_pet'].mean().reset_index()

# Renombrar la columna 'prod_pet' a 'prom_prod_pet'
grouped = grouped.rename(columns={'prod_pet': 'prom_prod_pet'})

# Unir el promedio calculado con el DataFrame original
data = pd.merge(data, grouped, on=['date_numeric'])

filtered_data_one_id = data[data['idpozo'] == idpozo]

filtered_data_one_id.drop(['idpozo'], axis=1, inplace=True)
filtered_data_one_id.drop(['areayacimiento'], axis=1, inplace=True)
# Out:
# Mounted at /content/drive
# <ipython-input-2-edf360d0ca51>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')
# <ipython-input-2-edf360d0ca51>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['mes', 'anio'], axis=1, inplace=True)
# <ipython-input-2-edf360d0ca51>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['date'])
# <ipython-input-2-edf360d0ca51>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1
# <ipython-input-2-edf360d0ca51>:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['date'], axis=1, inplace=True)
# <ipython-input-2-edf360d0ca51>:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data_one_id.drop(['idpozo'], axis=1, inplace=True)
# <ipython-input-2-edf360d0ca51>:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data_one_id.drop(['areayacimiento'], axis=1, inplace=True)

# %%
filtered_data_one_id.head()
# Out:
#         prod_pet  prod_gas  prod_agua       tef  coordenadax  coordenaday  \
# 57445  4679.5660  317.8841  334.47440  30.72917   -68.401467   -38.319375
# 58872  4934.2570  301.3739  123.15320  29.00000   -68.401467   -38.319375
# 60287  4554.8980  297.0282   72.77762  30.77778   -68.401467   -38.319375
# 61714  4401.3350  279.8637  120.02260  29.97917   -68.401467   -38.319375
# 63157  4223.4535  253.7424   88.79902  30.92708   -68.401467   -38.319375
#
#          cota  date_numeric  prom_prod_pet
# 57445  696.67            73     406.932837
# 58872  696.67            74     399.539411
# 60287  696.67            75     414.448362
# 61714  696.67            76     401.178440
# 63157  696.67            77     385.136588

# %%
# 50 Trials - mse only

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'prom_prod_pet', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_pet']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
#X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)
# Calcular el índice de corte para los últimos 3 valores (121, 122 y 123)
test_size = 3
split_index = len(X_sequences) - test_size

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test = X_sequences[:split_index], X_sequences[split_index:]
y_train, y_test = y_adjusted[:split_index], y_adjusted[split_index:]


# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, el error cuadrático medio)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    return mse

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=50, trials=trials)

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

model.save(model_save_path_50trials)

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.savefig(image_save_path_50trials)
plt.show()

# Predecir "prod_pet" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [121, 122, 123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'prom_prod_pet': [filtered_data_one_id['prom_prod_pet'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_pet:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 220ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 194ms/step
#
#   8%|▊         | 4/50 [01:04<13:38, 17.80s/trial, best loss: 10616.735158528147]
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7c3663b6ce50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 301ms/step
#
#  10%|█         | 5/50 [01:24<13:51, 18.48s/trial, best loss: 10616.735158528147]
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7c3663b6f010> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 202ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 195ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 190ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 201ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 291ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 1s 685ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 291ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 230ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 206ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 190ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 192ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 257ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 317ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 195ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 296ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 193ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 190ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 293ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 208ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 192ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 194ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 193ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 203ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 190ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 210ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 304ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 200ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 341ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 208ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 212ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 200ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 319ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 100%|██████████| 50/50 [12:49<00:00, 15.38s/trial, best loss: 10616.735158528147]
# Mejor tamaño de lote: 16
# Mejor cantidad de épocas: 400
# Epoch 1/400
# 3/3 [==============================] - 2s 236ms/step - loss: 0.1345 - val_loss: 0.0045
# Epoch 2/400
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1145 - val_loss: 0.0159
# Epoch 3/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1002 - val_loss: 0.0311
# Epoch 4/400
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0894 - val_loss: 0.0453
# Epoch 5/400
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0823 - val_loss: 0.0578
# Epoch 6/400
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0751 - val_loss: 0.0657
# Epoch 7/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0680 - val_loss: 0.0675
# Epoch 8/400
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0622 - val_loss: 0.0663
# Epoch 9/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0550 - val_loss: 0.0593
# Epoch 10/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0481 - val_loss: 0.0506
# Epoch 11/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0423 - val_loss: 0.0433
# Epoch 12/400
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0367 - val_loss: 0.0381
# Epoch 13/400
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0311 - val_loss: 0.0345
# Epoch 14/400
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0260 - val_loss: 0.0326
# Epoch 15/400
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0217 - val_loss: 0.0322
# Epoch 16/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0170 - val_loss: 0.0314
# Epoch 17/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0141 - val_loss: 0.0295
# Epoch 18/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0110 - val_loss: 0.0251
# Epoch 19/400
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0095 - val_loss: 0.0206
# Epoch 20/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0082 - val_loss: 0.0133
# Epoch 21/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0072 - val_loss: 0.0078
# Epoch 22/400
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0069 - val_loss: 0.0054
# Epoch 23/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0069 - val_loss: 0.0045
# Epoch 24/400
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0068 - val_loss: 0.0038
# Epoch 25/400
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0069 - val_loss: 0.0031
# Epoch 26/400
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0069 - val_loss: 0.0021
# Epoch 27/400
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0067 - val_loss: 0.0021
# Epoch 28/400
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0066 - val_loss: 0.0026
# Epoch 29/400
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0065 - val_loss: 0.0035
# Epoch 30/400
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0064 - val_loss: 0.0034
# Epoch 31/400
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0063 - val_loss: 0.0034
# Epoch 32/400
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0062 - val_loss: 0.0039
# Epoch 33/400
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0061 - val_loss: 0.0052
# Epoch 34/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0060 - val_loss: 0.0052
# Epoch 35/400
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0059 - val_loss: 0.0061
# Epoch 36/400
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0058 - val_loss: 0.0061
# Epoch 37/400
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0057 - val_loss: 0.0065
# Epoch 38/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0056 - val_loss: 0.0063
# Epoch 39/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0055 - val_loss: 0.0059
# Epoch 40/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0055 - val_loss: 0.0057
# Epoch 41/400
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0053 - val_loss: 0.0059
# Epoch 42/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0053 - val_loss: 0.0065
# Epoch 43/400
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0052 - val_loss: 0.0070
# Epoch 44/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0051 - val_loss: 0.0065
# Epoch 45/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0050 - val_loss: 0.0060
# Epoch 46/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 47/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0048 - val_loss: 0.0052
# Epoch 48/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0047 - val_loss: 0.0064
# Epoch 49/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0045 - val_loss: 0.0069
# Epoch 50/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0044 - val_loss: 0.0084
# Epoch 51/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0042 - val_loss: 0.0108
# Epoch 52/400
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0041 - val_loss: 0.0149
# Epoch 53/400
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0039 - val_loss: 0.0165
# Epoch 54/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0037 - val_loss: 0.0173
# Epoch 55/400
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0035 - val_loss: 0.0149
# Epoch 56/400
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0033 - val_loss: 0.0163
# Epoch 57/400
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0030 - val_loss: 0.0178
# Epoch 58/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0030 - val_loss: 0.0155
# Epoch 59/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0027 - val_loss: 0.0172
# Epoch 60/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0027 - val_loss: 0.0161
# Epoch 61/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0026 - val_loss: 0.0132
# Epoch 62/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0025 - val_loss: 0.0133
# Epoch 63/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0160
# Epoch 64/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0024 - val_loss: 0.0128
# Epoch 65/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0023 - val_loss: 0.0120
# Epoch 66/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0023 - val_loss: 0.0117
# Epoch 67/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0022 - val_loss: 0.0133
# Epoch 68/400
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0022 - val_loss: 0.0109
# Epoch 69/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0021 - val_loss: 0.0107
# Epoch 70/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0021 - val_loss: 0.0110
# Epoch 71/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0020 - val_loss: 0.0117
# Epoch 72/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0020 - val_loss: 0.0117
# Epoch 73/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0020 - val_loss: 0.0092
# Epoch 74/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0020 - val_loss: 0.0095
# Epoch 75/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0019 - val_loss: 0.0096
# Epoch 76/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0019 - val_loss: 0.0103
# Epoch 77/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0019 - val_loss: 0.0099
# Epoch 78/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0018 - val_loss: 0.0081
# Epoch 79/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0018 - val_loss: 0.0087
# Epoch 80/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0018 - val_loss: 0.0090
# Epoch 81/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0018 - val_loss: 0.0073
# Epoch 82/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0018 - val_loss: 0.0073
# Epoch 83/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0017 - val_loss: 0.0092
# Epoch 84/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0017 - val_loss: 0.0082
# Epoch 85/400
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0016 - val_loss: 0.0070
# Epoch 86/400
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0017 - val_loss: 0.0067
# Epoch 87/400
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0016 - val_loss: 0.0068
# Epoch 88/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0016 - val_loss: 0.0073
# Epoch 89/400
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0016 - val_loss: 0.0072
# Epoch 90/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0015 - val_loss: 0.0073
# Epoch 91/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0015 - val_loss: 0.0064
# Epoch 92/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0015 - val_loss: 0.0060
# Epoch 93/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0015 - val_loss: 0.0057
# Epoch 94/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0014 - val_loss: 0.0064
# Epoch 95/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0014 - val_loss: 0.0065
# Epoch 96/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0014 - val_loss: 0.0054
# Epoch 97/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0014 - val_loss: 0.0059
# Epoch 98/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0015 - val_loss: 0.0063
# Epoch 99/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0014 - val_loss: 0.0048
# Epoch 100/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0014 - val_loss: 0.0055
# Epoch 101/400
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0013 - val_loss: 0.0060
# Epoch 102/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0013 - val_loss: 0.0047
# Epoch 103/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0013 - val_loss: 0.0050
# Epoch 104/400
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0013 - val_loss: 0.0047
# Epoch 105/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0013 - val_loss: 0.0044
# Epoch 106/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0013 - val_loss: 0.0055
# Epoch 107/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0013 - val_loss: 0.0049
# Epoch 108/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0013 - val_loss: 0.0039
# Epoch 109/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0012 - val_loss: 0.0046
# Epoch 110/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0013 - val_loss: 0.0045
# Epoch 111/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0013 - val_loss: 0.0053
# Epoch 112/400
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 113/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 0.0043
# Epoch 114/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 0.0051
# Epoch 115/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 0.0046
# Epoch 116/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0012 - val_loss: 0.0035
# Epoch 117/400
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0012 - val_loss: 0.0042
# Epoch 118/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0012 - val_loss: 0.0048
# Epoch 119/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 120/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0012 - val_loss: 0.0036
# Epoch 121/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0011 - val_loss: 0.0051
# Epoch 122/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0012 - val_loss: 0.0034
# Epoch 123/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0011 - val_loss: 0.0031
# Epoch 124/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0011 - val_loss: 0.0038
# Epoch 125/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0011 - val_loss: 0.0044
# Epoch 126/400
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0011 - val_loss: 0.0035
# Epoch 127/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0011 - val_loss: 0.0031
# Epoch 128/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0011 - val_loss: 0.0036
# Epoch 129/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0011 - val_loss: 0.0034
# Epoch 130/400
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0011 - val_loss: 0.0035
# Epoch 131/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0011 - val_loss: 0.0040
# Epoch 132/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 133/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0010 - val_loss: 0.0033
# Epoch 134/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0010 - val_loss: 0.0037
# Epoch 135/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0011 - val_loss: 0.0034
# Epoch 136/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0010 - val_loss: 0.0024
# Epoch 137/400
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 138/400
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0011 - val_loss: 0.0047
# Epoch 139/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 140/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0012 - val_loss: 0.0024
# Epoch 141/400
# 3/3 [==============================] - 0s 18ms/step - loss: 9.6808e-04 - val_loss: 0.0045
# Epoch 142/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 143/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 144/400
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0010 - val_loss: 0.0043
# Epoch 145/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0010 - val_loss: 0.0032
# Epoch 146/400
# 3/3 [==============================] - 0s 19ms/step - loss: 9.7036e-04 - val_loss: 0.0021
# Epoch 147/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0010 - val_loss: 0.0031
# Epoch 148/400
# 3/3 [==============================] - 0s 25ms/step - loss: 9.5366e-04 - val_loss: 0.0041
# Epoch 149/400
# 3/3 [==============================] - 0s 20ms/step - loss: 9.9753e-04 - val_loss: 0.0029
# Epoch 150/400
# 3/3 [==============================] - 0s 20ms/step - loss: 9
400
# 3/3 [==============================] - 0s 22ms/step - loss: 4.1397e-04 - val_loss: 0.0040
# Epoch 399/400
# 3/3 [==============================] - 0s 22ms/step - loss: 4.3750e-04 - val_loss: 0.0046
# Epoch 400/400
# 3/3 [==============================] - 0s 20ms/step - loss: 4.4418e-04 - val_loss: 0.0041
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 186ms/step
# Error Cuadrático Medio: 59684.77587714964
# Error Absoluto Medio: 235.75881835937494
# 1/1 [==============================] - 0s 26ms/step
# Predicciones para valores futuros de prod_pet: [1479.4967 1482.4786 1482.1547 1465.5215 1448.9509 1433.1881 1417.9119
#  1402.8628]

# %%
import matplotlib.pyplot as plt

# Filtrar los datos de prueba para los valores de date_numeric 121, 122 y 123
test_data = filtered_data_one_id[filtered_data_one_id['date_numeric'].isin([121, 122, 123])]

# Extraer la columna de 'prod_pet' para los valores de date_numeric 121, 122 y 123
real_values = test_data['prod_pet'].values

# Obtener las predicciones para los valores de date_numeric 121, 122 y 123
# Aquí 'predictions' se supone que contiene las predicciones de los valores futuros
predicted_values = predictions[:3].flatten()

# Imprimir los valores reales de prod_pet para date_numeric 121, 122 y 123
print("Valores reales de prod_pet para date_numeric 121, 122 y 123:", real_values)

# Imprimir los valores predichos de prod_pet para date_numeric 121, 122 y 123
print("Valores predichos de prod_pet para date_numeric 121, 122 y 123:", predicted_values)

# Graficar los valores reales vs los valores predichos
plt.figure(figsize=(10, 5))
plt.plot([121, 122, 123], real_values, label='Actual', marker='o')
plt.plot([121, 122, 123], predicted_values, label='Predicho', marker='x')
plt.xlabel('date_numeric')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.savefig(image_save_path_three_lastmonths_50trials)
plt.show()
# Out:
# Valores reales de prod_pet para date_numeric 121, 122 y 123: [1285.098 1163.317 1113.675]
# Valores predichos de prod_pet para date_numeric 121, 122 y 123: [1479.4967 1482.4786 1482.1547]

# %%
# Load the existing CSV file

csv_results_file_path = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_todos_los_pozos_MSE_50_trials.csv"
df = pd.read_csv(csv_results_file_path)

# Determine the current maximum index in the DataFrame
#max_index = df.index.max()

# Create a DataFrame with the new data, ensuring the indices are sequential from the current maximum index
#new_indices = [max_index + 1, max_index + 2, max_index + 3]

# Create a DataFrame with the new data
new_data = {
    'fecha': ['2024-01-01', '2024-02-01', '2024-03-01'],
    'idpozo': [idpozo, idpozo, idpozo],
    'prod_pet':predicted_values
}

new_df = pd.DataFrame(new_data)
combined_df = pd.concat([df, new_df], ignore_index=True)
combined_df.to_csv(csv_results_file_path, index=False)

#new_df = pd.DataFrame(new_data, index=new_indices)
#combined_df = pd.concat([df, new_df])
#combined_df.to_csv(csv_results_file_path, index=True, index_label='')

print(f'Nuevo valor agregado al csv {csv_results_file_path}')
# Out:
# Nuevo valor agregado al csv /content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_todos_los_pozos_MSE_50_trials.csv

# %%
#Funcion objetivo mse y mae - 100 trials

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials
import tensorflow as tf

# Establecer una semilla aleatoria para reproducibilidad
np.random.seed(42)
tf.random.set_seed(42)

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'prom_prod_pet', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_pet']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
#X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)
# Calcular el índice de corte para los últimos 3 valores (121, 122 y 123)
test_size = 3
split_index = len(X_sequences) - test_size

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test = X_sequences[:split_index], X_sequences[split_index:]
y_train, y_test = y_adjusted[:split_index], y_adjusted[split_index:]

# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, la combinación de MSE y MAE)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)

    # Calcular el MSE y MAE
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

    # Combinar MSE y MAE en una única métrica
    combined_metric = 0.5 * mse + 0.5 * mae
    return combined_metric

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=100, trials=trials)  # Aumentar max_evals

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

model.save(model_save_path_mse_mae_100trials)

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.savefig(image_save_path_mse_mae_100trials)
plt.show()

# Predecir "prod_pet" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [121, 122, 123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'prom_prod_pet': [filtered_data_one_id['prom_prod_pet'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_pet:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 210ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 199ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 221ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 192ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 186ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 210ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 200ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 202ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 202ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 195ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 203ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 190ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 222ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 198ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 196ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 196ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 196ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 200ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 206ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 310ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 193ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 276ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 198ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 310ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 194ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 220ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 234ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 227ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 192ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 204ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 201ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 213ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 196ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 203ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 190ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 195ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 201ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 195ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 213ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 192ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 190ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 310ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 272ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 193ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 213ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 198ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 307ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 227ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 193ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 194ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 288ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 211ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 278ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 197ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 270ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 209ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 196ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 307ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 296ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 194ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 194ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 190ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 215ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 202ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 310ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 381ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 205ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 202ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 214ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 278ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 199ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 195ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 399ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 186ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 196ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 192ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 197ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 197ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 316ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 194ms/step
#
# 100%|██████████| 100/100 [19:38<00:00, 11.79s/trial, best loss: 1848.5381709856053]
# Mejor tamaño de lote: 64
# Mejor cantidad de épocas: 100
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1264 - val_loss: 0.0026
# Epoch 2/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1188 - val_loss: 0.0050
# Epoch 3/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1119 - val_loss: 0.0083
# Epoch 4/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.1057 - val_loss: 0.0123
# Epoch 5/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.1001 - val_loss: 0.0167
# Epoch 6/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0950 - val_loss: 0.0214
# Epoch 7/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0905 - val_loss: 0.0262
# Epoch 8/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0863 - val_loss: 0.0311
# Epoch 9/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0826 - val_loss: 0.0358
# Epoch 10/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0791 - val_loss: 0.0402
# Epoch 11/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0758 - val_loss: 0.0443
# Epoch 12/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0728 - val_loss: 0.0478
# Epoch 13/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0699 - val_loss: 0.0509
# Epoch 14/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0672 - val_loss: 0.0533
# Epoch 15/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0645 - val_loss: 0.0551
# Epoch 16/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0618 - val_loss: 0.0564
# Epoch 17/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0592 - val_loss: 0.0572
# Epoch 18/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0567 - val_loss: 0.0576
# Epoch 19/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0541 - val_loss: 0.0575
# Epoch 20/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0516 - val_loss: 0.0569
# Epoch 21/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0491 - val_loss: 0.0558
# Epoch 22/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0467 - val_loss: 0.0542
# Epoch 23/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0442 - val_loss: 0.0521
# Epoch 24/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0418 - val_loss: 0.0497
# Epoch 25/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0394 - val_loss: 0.0471
# Epoch 26/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0371 - val_loss: 0.0442
# Epoch 27/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0348 - val_loss: 0.0413
# Epoch 28/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0326 - val_loss: 0.0383
# Epoch 29/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0305 - val_loss: 0.0353
# Epoch 30/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0285 - val_loss: 0.0325
# Epoch 31/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0266 - val_loss: 0.0299
# Epoch 32/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0248 - val_loss: 0.0274
# Epoch 33/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0231 - val_loss: 0.0252
# Epoch 34/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0214 - val_loss: 0.0233
# Epoch 35/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0198 - val_loss: 0.0216
# Epoch 36/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0183 - val_loss: 0.0202
# Epoch 37/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0168 - val_loss: 0.0191
# Epoch 38/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0154 - val_loss: 0.0181
# Epoch 39/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0141 - val_loss: 0.0173
# Epoch 40/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0129 - val_loss: 0.0166
# Epoch 41/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0118 - val_loss: 0.0159
# Epoch 42/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0108 - val_loss: 0.0152
# Epoch 43/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0100 - val_loss: 0.0144
# Epoch 44/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0092 - val_loss: 0.0134
# Epoch 45/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0086 - val_loss: 0.0121
# Epoch 46/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0081 - val_loss: 0.0107
# Epoch 47/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0077 - val_loss: 0.0090
# Epoch 48/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0073 - val_loss: 0.0073
# Epoch 49/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0070 - val_loss: 0.0056
# Epoch 50/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0067 - val_loss: 0.0041
# Epoch 51/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0065 - val_loss: 0.0028
# Epoch 52/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0064 - val_loss: 0.0018
# Epoch 53/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0063 - val_loss: 0.0011
# Epoch 54/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0063 - val_loss: 6.4150e-04
# Epoch 55/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0063 - val_loss: 4.0817e-04
# Epoch 56/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0063 - val_loss: 3.2193e-04
# Epoch 57/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0063 - val_loss: 3.2016e-04
# Epoch 58/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0063 - val_loss: 3.5912e-04
# Epoch 59/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0064 - val_loss: 4.1010e-04
# Epoch 60/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0064 - val_loss: 4.5565e-04
# Epoch 61/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0063 - val_loss: 4.8603e-04
# Epoch 62/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0063 - val_loss: 4.9802e-04
# Epoch 63/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0063 - val_loss: 4.9391e-04
# Epoch 64/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0063 - val_loss: 4.7941e-04
# Epoch 65/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0063 - val_loss: 4.5943e-04
# Epoch 66/100
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0062 - val_loss: 4.3792e-04
# Epoch 67/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0062 - val_loss: 4.1731e-04
# Epoch 68/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0062 - val_loss: 3.9895e-04
# Epoch 69/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0061 - val_loss: 3.8269e-04
# Epoch 70/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0061 - val_loss: 3.6743e-04
# Epoch 71/100
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0060 - val_loss: 3.4858e-04
# Epoch 72/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0060 - val_loss: 3.2876e-04
# Epoch 73/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0059 - val_loss: 3.1102e-04
# Epoch 74/100
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0059 - val_loss: 2.9872e-04
# Epoch 75/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0058 - val_loss: 2.9474e-04
# Epoch 76/100
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0057 - val_loss: 3.0625e-04
# Epoch 77/100
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0057 - val_loss: 3.3762e-04
# Epoch 78/100
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0056 - val_loss: 3.8888e-04
# Epoch 79/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0056 - val_loss: 4.6416e-04
# Epoch 80/100
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0055 - val_loss: 5.5918e-04
# Epoch 81/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0055 - val_loss: 6.6364e-04
# Epoch 82/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0054 - val_loss: 7.6442e-04
# Epoch 83/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0054 - val_loss: 8.5018e-04
# Epoch 84/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0053 - val_loss: 9.1310e-04
# Epoch 85/100
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0053 - val_loss: 9.5067e-04
# Epoch 86/100
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0053 - val_loss: 9.8786e-04
# Epoch 87/100
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0052 - val_loss: 0.0010
# Epoch 88/100
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0052 - val_loss: 0.0011
# Epoch 89/100
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0052 - val_loss: 0.0011
# Epoch 90/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0051 - val_loss: 0.0012
# Epoch 91/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0051 - val_loss: 0.0013
# Epoch 92/100
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0050 - val_loss: 0.0014
# Epoch 93/100
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0050 - val_loss: 0.0015
# Epoch 94/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0049 - val_loss: 0.0016
# Epoch 95/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0049 - val_loss: 0.0017
# Epoch 96/100
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0049 - val_loss: 0.0019
# Epoch 97/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0048 - val_loss: 0.0020
# Epoch 98/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0048 - val_loss: 0.0021
# Epoch 99/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0047 - val_loss: 0.0022
# Epoch 100/100
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0046 - val_loss: 0.0022
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 199ms/step
# Error Cuadrático Medio: 32733.614297978154
# Error Absoluto Medio: 168.91685872395828
# 1/1 [==============================] - 0s 22ms/step
# Predicciones para valores futuros de prod_pet: [1391.6312 1528.0237 1529.9604 1506.834  1485.5609 1465.239  1445.1617
#  1425.1849]

# %%
import matplotlib.pyplot as plt

# Filtrar los datos de prueba para los valores de date_numeric 121, 122 y 123
test_data = filtered_data_one_id[filtered_data_one_id['date_numeric'].isin([121, 122, 123])]

# Extraer la columna de 'prod_pet' para los valores de date_numeric 121, 122 y 123
real_values = test_data['prod_pet'].values

# Obtener las predicciones para los valores de date_numeric 121, 122 y 123
# Aquí 'predictions' se supone que contiene las predicciones de los valores futuros
predicted_values = predictions[:3].flatten()

# Imprimir los valores reales de prod_pet para date_numeric 121, 122 y 123
print("Valores reales de prod_pet para date_numeric 121, 122 y 123:", real_values)

# Imprimir los valores predichos de prod_pet para date_numeric 121, 122 y 123
print("Valores predichos de prod_pet para date_numeric 121, 122 y 123:", predicted_values)

# Graficar los valores reales vs los valores predichos
plt.figure(figsize=(10, 5))
plt.plot([121, 122, 123], real_values, label='Actual', marker='o')
plt.plot([121, 122, 123], predicted_values, label='Predicho', marker='x')
plt.xlabel('date_numeric')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.savefig(image_save_path_three_lastmonths_mse_mae_100trials)
plt.show()
# Out:
# Valores reales de prod_pet para date_numeric 121, 122 y 123: [1285.098 1163.317 1113.675]
# Valores predichos de prod_pet para date_numeric 121, 122 y 123: [1391.6312 1528.0237 1529.9604]

# %%
# Load the existing CSV file

csv_results_file_path = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_todos_los_pozos_MSE_MAE_100_trials.csv"
df = pd.read_csv(csv_results_file_path)

# Determine the current maximum index in the DataFrame
#max_index = df.index.max()

# Create a DataFrame with the new data, ensuring the indices are sequential from the current maximum index
#new_indices = [max_index + 1, max_index + 2, max_index + 3]

# Create a DataFrame with the new data
new_data = {
    'fecha': ['2024-01-01', '2024-02-01', '2024-03-01'],
    'idpozo': [idpozo, idpozo, idpozo],
    'prod_pet':predicted_values
}

new_df = pd.DataFrame(new_data)
combined_df = pd.concat([df, new_df], ignore_index=True)
combined_df.to_csv(csv_results_file_path, index=False)

#new_df = pd.DataFrame(new_data, index=new_indices)
#combined_df = pd.concat([df, new_df])
#combined_df.to_csv(csv_results_file_path, index=True, index_label='')

print(f'Nuevo valor agregado al csv {csv_results_file_path}')
# Out:
# Nuevo valor agregado al csv /content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_todos_los_pozos_MSE_MAE_100_trials.csv

# %%
# Con 100 Trials - mse only

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'prom_prod_pet', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_pet']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
#X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)
# Calcular el índice de corte para los últimos 3 valores (121, 122 y 123)
test_size = 3
split_index = len(X_sequences) - test_size

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test = X_sequences[:split_index], X_sequences[split_index:]
y_train, y_test = y_adjusted[:split_index], y_adjusted[split_index:]


# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, el error cuadrático medio)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    return mse

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=50, trials=trials)


###########################################################################
#from tensorflow.keras.models import load_model
#model = load_model(model_save_path_100trials)

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

model.save(model_save_path_100trials)
###########################################################################

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.savefig(image_save_path_100trials)
plt.show()

# Predecir "prod_pet" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [121, 122, 123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'prom_prod_pet': [filtered_data_one_id['prom_prod_pet'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_pet:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 304ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 194ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 192ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 192ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 220ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 309ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 196ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 211ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 217ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 186ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 312ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 275ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 208ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 294ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 200ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 210ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 204ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 201ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 265ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 195ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 299ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 330ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 201ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 305ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 190ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 186ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 316ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 208ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 197ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 220ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 210ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 205ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 202ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 192ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 207ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 193ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 197ms/step
#
# 100%|██████████| 50/50 [09:32<00:00, 11.44s/trial, best loss: 3280.429620732242]
# Mejor tamaño de lote: 128
# Mejor cantidad de épocas: 100
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1467 - val_loss: 7.2733e-04
# Epoch 2/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1415 - val_loss: 3.5369e-04
# Epoch 3/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1342 - val_loss: 3.5636e-04
# Epoch 4/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1271 - val_loss: 0.0011
# Epoch 5/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.1204 - val_loss: 0.0027
# Epoch 6/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1142 - val_loss: 0.0050
# Epoch 7/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1086 - val_loss: 0.0080
# Epoch 8/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1036 - val_loss: 0.0114
# Epoch 9/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0991 - val_loss: 0.0151
# Epoch 10/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0951 - val_loss: 0.0191
# Epoch 11/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0914 - val_loss: 0.0232
# Epoch 12/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0881 - val_loss: 0.0272
# Epoch 13/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0851 - val_loss: 0.0310
# Epoch 14/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0823 - val_loss: 0.0347
# Epoch 15/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0797 - val_loss: 0.0380
# Epoch 16/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0771 - val_loss: 0.0410
# Epoch 17/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0746 - val_loss: 0.0436
# Epoch 18/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0721 - val_loss: 0.0460
# Epoch 19/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0696 - val_loss: 0.0478
# Epoch 20/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0671 - val_loss: 0.0491
# Epoch 21/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0647 - val_loss: 0.0497
# Epoch 22/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0622 - val_loss: 0.0498
# Epoch 23/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0597 - val_loss: 0.0493
# Epoch 24/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0572 - val_loss: 0.0483
# Epoch 25/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0547 - val_loss: 0.0468
# Epoch 26/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0522 - val_loss: 0.0450
# Epoch 27/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0497 - val_loss: 0.0429
# Epoch 28/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0473 - val_loss: 0.0406
# Epoch 29/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0449 - val_loss: 0.0382
# Epoch 30/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0425 - val_loss: 0.0358
# Epoch 31/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0403 - val_loss: 0.0333
# Epoch 32/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0380 - val_loss: 0.0309
# Epoch 33/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0359 - val_loss: 0.0287
# Epoch 34/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0338 - val_loss: 0.0265
# Epoch 35/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0318 - val_loss: 0.0246
# Epoch 36/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0298 - val_loss: 0.0228
# Epoch 37/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0279 - val_loss: 0.0212
# Epoch 38/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0260 - val_loss: 0.0198
# Epoch 39/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0241 - val_loss: 0.0186
# Epoch 40/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0223 - val_loss: 0.0176
# Epoch 41/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0205 - val_loss: 0.0167
# Epoch 42/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0188 - val_loss: 0.0160
# Epoch 43/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0172 - val_loss: 0.0154
# Epoch 44/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0157 - val_loss: 0.0148
# Epoch 45/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0143 - val_loss: 0.0142
# Epoch 46/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0130 - val_loss: 0.0137
# Epoch 47/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0119 - val_loss: 0.0130
# Epoch 48/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0109 - val_loss: 0.0123
# Epoch 49/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0100 - val_loss: 0.0115
# Epoch 50/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0093 - val_loss: 0.0104
# Epoch 51/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0087 - val_loss: 0.0093
# Epoch 52/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0082 - val_loss: 0.0080
# Epoch 53/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0078 - val_loss: 0.0066
# Epoch 54/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0073 - val_loss: 0.0051
# Epoch 55/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0069 - val_loss: 0.0037
# Epoch 56/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0066 - val_loss: 0.0025
# Epoch 57/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0064 - val_loss: 0.0016
# Epoch 58/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0062 - val_loss: 9.5396e-04
# Epoch 59/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0061 - val_loss: 5.6425e-04
# Epoch 60/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0061 - val_loss: 3.7334e-04
# Epoch 61/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0060 - val_loss: 3.2984e-04
# Epoch 62/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0060 - val_loss: 3.8431e-04
# Epoch 63/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0061 - val_loss: 4.8890e-04
# Epoch 64/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0060 - val_loss: 6.1721e-04
# Epoch 65/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0060 - val_loss: 7.1523e-04
# Epoch 66/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0060 - val_loss: 7.2733e-04
# Epoch 67/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0060 - val_loss: 7.2733e-04
# Epoch 68/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0060 - val_loss: 7.2733e-04
# Epoch 69/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0060 - val_loss: 7.2733e-04
# Epoch 70/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0060 - val_loss: 7.2733e-04
# Epoch 71/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0060 - val_loss: 7.2733e-04
# Epoch 72/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0059 - val_loss: 7.2733e-04
# Epoch 73/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0059 - val_loss: 7.2733e-04
# Epoch 74/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0059 - val_loss: 7.2733e-04
# Epoch 75/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0058 - val_loss: 7.0740e-04
# Epoch 76/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0058 - val_loss: 6.7134e-04
# Epoch 77/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0057 - val_loss: 6.3507e-04
# Epoch 78/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0057 - val_loss: 5.9834e-04
# Epoch 79/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0056 - val_loss: 5.6173e-04
# Epoch 80/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0056 - val_loss: 5.2567e-04
# Epoch 81/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0055 - val_loss: 4.8250e-04
# Epoch 82/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0055 - val_loss: 4.3004e-04
# Epoch 83/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0054 - val_loss: 3.7789e-04
# Epoch 84/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0054 - val_loss: 3.2785e-04
# Epoch 85/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0053 - val_loss: 2.8728e-04
# Epoch 86/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0052 - val_loss: 2.6075e-04
# Epoch 87/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0052 - val_loss: 2.4897e-04
# Epoch 88/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0051 - val_loss: 2.5375e-04
# Epoch 89/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0051 - val_loss: 2.7276e-04
# Epoch 90/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0050 - val_loss: 3.0152e-04
# Epoch 91/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0049 - val_loss: 3.3434e-04
# Epoch 92/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0049 - val_loss: 3.6608e-04
# Epoch 93/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0048 - val_loss: 3.9314e-04
# Epoch 94/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0048 - val_loss: 4.2194e-04
# Epoch 95/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0047 - val_loss: 4.5261e-04
# Epoch 96/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0047 - val_loss: 4.9064e-04
# Epoch 97/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0046 - val_loss: 5.3601e-04
# Epoch 98/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0045 - val_loss: 5.8787e-04
# Epoch 99/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0045 - val_loss: 6.4450e-04
# Epoch 100/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0044 - val_loss: 7.0374e-04
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 204ms/step
# Error Cuadrático Medio: 10272.348387645883
# Error Absoluto Medio: 84.57074869791661
# 1/1 [==============================] - 0s 21ms/step
# Predicciones para valores futuros de prod_pet: [1296.8822 1434.6365 1434.8722 1409.889  1384.9938 1360.9314 1337.6012
#  1314.3235]

# %%
import matplotlib.pyplot as plt

# Filtrar los datos de prueba para los valores de date_numeric 121, 122 y 123
test_data = filtered_data_one_id[filtered_data_one_id['date_numeric'].isin([121, 122, 123])]

# Extraer la columna de 'prod_pet' para los valores de date_numeric 121, 122 y 123
real_values = test_data['prod_pet'].values

# Obtener las predicciones para los valores de date_numeric 121, 122 y 123
# Aquí 'predictions' se supone que contiene las predicciones de los valores futuros
predicted_values = predictions[:3].flatten()

# Imprimir los valores reales de prod_pet para date_numeric 121, 122 y 123
print("Valores reales de prod_pet para date_numeric 121, 122 y 123:", real_values)

# Imprimir los valores predichos de prod_pet para date_numeric 121, 122 y 123
print("Valores predichos de prod_pet para date_numeric 121, 122 y 123:", predicted_values)

# Graficar los valores reales vs los valores predichos
plt.figure(figsize=(10, 5))
plt.plot([121, 122, 123], real_values, label='Actual', marker='o')
plt.plot([121, 122, 123], predicted_values, label='Predicho', marker='x')
plt.xlabel('date_numeric')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.savefig(image_save_path_three_lastmonths_100trials)
plt.show()
# Out:
# Valores reales de prod_pet para date_numeric 121, 122 y 123: [1285.098 1163.317 1113.675]
# Valores predichos de prod_pet para date_numeric 121, 122 y 123: [1296.8822 1434.6365 1434.8722]

# %%
# Load the existing CSV file

csv_results_file_path = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_todos_los_pozos_MSE_100_trials.csv"
df = pd.read_csv(csv_results_file_path)

# Determine the current maximum index in the DataFrame
#max_index = df.index.max()

# Create a DataFrame with the new data, ensuring the indices are sequential from the current maximum index
#new_indices = [max_index + 1, max_index + 2, max_index + 3]

# Create a DataFrame with the new data
new_data = {
    'fecha': ['2024-01-01', '2024-02-01', '2024-03-01'],
    'idpozo': [idpozo, idpozo, idpozo],
    'prod_pet':predicted_values
}

new_df = pd.DataFrame(new_data)
combined_df = pd.concat([df, new_df], ignore_index=True)
combined_df.to_csv(csv_results_file_path, index=False)

#new_df = pd.DataFrame(new_data, index=new_indices)
#combined_df = pd.concat([df, new_df])
#combined_df.to_csv(csv_results_file_path, index=True, index_label='')

print(f'Nuevo valor agregado al csv {csv_results_file_path}')
# Out:
# Nuevo valor agregado al csv /content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_todos_los_pozos_MSE_100_trials.csv
