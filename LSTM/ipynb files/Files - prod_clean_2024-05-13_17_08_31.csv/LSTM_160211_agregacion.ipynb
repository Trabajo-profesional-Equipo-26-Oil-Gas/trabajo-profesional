# %% [markdown]
# #Partiendo de la limpieza de datos realizada previamente, se utiliza LSTM para predecir la producción de pozos de petroleo.
#
# ###Pozos a predecir:
# 158364, 160211, 160332, 160789, 160810, 160814, 161451, 162200, 162405, 162955, 163237, 163942

# %%
import math
import itertools
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import LSTM, Dense
from keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
pd.set_option('display.max_columns', None)

idpozo = 160211
model_save_path_50trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-50trials.h5"
image_save_path_50trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-50trials.png"
image_save_path_three_lastmonths_50trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}three_lastmonths-50trials.png"


model_save_path_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-100trials.h5"
image_save_path_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-100trials.png"
image_save_path_three_lastmonths_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}three_lastmonths-100trials.png"

model_save_path_mse_mae_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-mse_mae-100trials.h5"
image_save_path_mse_mae_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}-mse_mae_100-trials.png"
image_save_path_three_lastmonths_mse_mae_100trials = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/{idpozo}/best_lstm_model_{idpozo}three_lastmonths_mse_mae-100trials.png"

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

#dataset = pd.read_csv("/content/drive/MyDrive/Trabajo profesional/Code/data/prod_norm_2024-05-27_03:42:59.csv", index_col=0)
dataset = pd.read_csv("/content/drive/MyDrive/Trabajo profesional/Code/data/prod_clean_2024-05-13_17:08:31.csv", index_col=0)

dataset = dataset[dataset['anio'] >= 2014]

# Seleccionar características relevantes
features = ['prod_pet', 'anio', 'mes', 'idpozo', 'prod_gas', 'prod_agua', 'tef', 'coordenadax', 'coordenaday', 'cota', 'pet_inicial', 'gas_inicial', 'agua_inicial', 'areayacimiento']

# Filtrar características
data = dataset[features]

# Creacion de una nueva columna 'date' combinando 'anio' y 'mes' para representar la fecha
data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')

data.drop(['mes', 'anio'], axis=1, inplace=True)

# Conversion de la columna 'date' a "datetime type"
data['date'] = pd.to_datetime(data['date'])

# Definicion de un dia de referencia inicial (Es la primera fecha desde la que se filtro previamente).
reference_date = pd.Timestamp('2014-01-01')

# Calculo del numero de meses desde la referencia para cada date.
data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1

data.drop(['date'], axis=1, inplace=True)

# Agrupar por 'areayacimiento' y 'date_numeric' para calcular el promedio de 'prod_pet'
grouped = data.groupby(['areayacimiento', 'date_numeric'])['prod_pet'].mean().reset_index()

# Renombrar la columna 'prod_pet' a 'prom_prod_pet'
grouped = grouped.rename(columns={'prod_pet': 'prom_prod_pet'})

# Unir el promedio calculado con el DataFrame original
data = pd.merge(data, grouped, on=['areayacimiento', 'date_numeric'])

filtered_data_one_id = data[data['idpozo'] == idpozo]

filtered_data_one_id.drop(['idpozo'], axis=1, inplace=True)
filtered_data_one_id.drop(['areayacimiento'], axis=1, inplace=True)
# Out:
# Mounted at /content/drive
# <ipython-input-2-45dd8fe82312>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')
# <ipython-input-2-45dd8fe82312>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['mes', 'anio'], axis=1, inplace=True)
# <ipython-input-2-45dd8fe82312>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['date'])
# <ipython-input-2-45dd8fe82312>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1
# <ipython-input-2-45dd8fe82312>:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['date'], axis=1, inplace=True)
# <ipython-input-2-45dd8fe82312>:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data_one_id.drop(['idpozo'], axis=1, inplace=True)
# <ipython-input-2-45dd8fe82312>:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data_one_id.drop(['areayacimiento'], axis=1, inplace=True)

# %%
filtered_data_one_id.head()
# Out:
#        prod_pet  prod_gas  prod_agua     tef  coordenadax  coordenaday   cota  \
# 75546  2157.877   268.840   5463.537  31.000   -68.676031   -38.225002  353.6
# 77438  6824.254   756.849   3520.812  30.000   -68.676031   -38.225002  353.6
# 79382  6080.412   748.773   1707.176  30.990   -68.676031   -38.225002  353.6
# 81343  4931.726   588.129   1153.977  29.996   -68.676031   -38.225002  353.6
# 83326  4714.398   541.169    741.911  30.854   -68.676031   -38.225002  353.6
#
#        pet_inicial  gas_inicial  agua_inicial  date_numeric  prom_prod_pet
# 75546          0.0          0.0           0.0            63    1505.137000
# 77438          0.0          0.0           0.0            64    5153.377000
# 79382          0.0          0.0           0.0            65    4371.904400
# 81343          0.0          0.0           0.0            66    3432.117800
# 83326          0.0          0.0           0.0            67    2327.754778

# %%
# 50 Trials - mse only

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'pet_inicial', 'gas_inicial', 'agua_inicial', 'prom_prod_pet', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_pet']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
#X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)
# Calcular el índice de corte para los últimos 3 valores (121, 122 y 123)
test_size = 3
split_index = len(X_sequences) - test_size

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test = X_sequences[:split_index], X_sequences[split_index:]
y_train, y_test = y_adjusted[:split_index], y_adjusted[split_index:]


# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, el error cuadrático medio)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    return mse

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=50, trials=trials)

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

model.save(model_save_path_50trials)

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.savefig(image_save_path_50trials)
plt.show()

# Predecir "prod_pet" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [121, 122, 123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'pet_inicial': [filtered_data_one_id['pet_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'gas_inicial': [filtered_data_one_id['gas_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'agua_inicial': [filtered_data_one_id['agua_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'prom_prod_pet': [filtered_data_one_id['prom_prod_pet'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_pet:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 211ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 207ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 204ms/step
#
#   8%|▊         | 4/50 [01:07<11:59, 15.65s/trial, best loss: 21833.641198190562]
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x79d90a363910> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
#  10%|█         | 5/50 [01:18<10:17, 13.71s/trial, best loss: 11958.897401521814]
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x79d90ae5fa30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 171ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 190ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 293ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 255ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 225ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 215ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 261ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 271ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 192ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 211ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 171ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 240ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 269ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 252ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 203ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 210ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 192ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 257ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 302ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 265ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 294ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 238ms/step
#
# 100%|██████████| 50/50 [10:16<00:00, 12.32s/trial, best loss: 1912.4312269126028]
# Mejor tamaño de lote: 16
# Mejor cantidad de épocas: 100
# Epoch 1/100
# 4/4 [==============================] - 2s 149ms/step - loss: 0.0655 - val_loss: 0.0030
# Epoch 2/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0426 - val_loss: 0.0170
# Epoch 3/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0341 - val_loss: 0.0315
# Epoch 4/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0296 - val_loss: 0.0322
# Epoch 5/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0269 - val_loss: 0.0235
# Epoch 6/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0226 - val_loss: 0.0130
# Epoch 7/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0187 - val_loss: 0.0065
# Epoch 8/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0157 - val_loss: 0.0024
# Epoch 9/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0135 - val_loss: 6.3099e-04
# Epoch 10/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0121 - val_loss: 1.7442e-04
# Epoch 11/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0105 - val_loss: 3.7700e-06
# Epoch 12/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0096 - val_loss: 3.2825e-04
# Epoch 13/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0093 - val_loss: 0.0010
# Epoch 14/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0091 - val_loss: 0.0020
# Epoch 15/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0087 - val_loss: 9.0633e-04
# Epoch 16/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0083 - val_loss: 2.6939e-04
# Epoch 17/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0080 - val_loss: 7.1016e-05
# Epoch 18/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0078 - val_loss: 3.6856e-06
# Epoch 19/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0075 - val_loss: 2.5102e-05
# Epoch 20/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0073 - val_loss: 3.4204e-05
# Epoch 21/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0071 - val_loss: 1.1077e-06
# Epoch 22/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0069 - val_loss: 2.1967e-05
# Epoch 23/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0067 - val_loss: 2.4535e-04
# Epoch 24/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0066 - val_loss: 3.0656e-04
# Epoch 25/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0066 - val_loss: 8.0225e-06
# Epoch 26/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0064 - val_loss: 5.4939e-05
# Epoch 27/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0063 - val_loss: 3.5415e-04
# Epoch 28/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0062 - val_loss: 0.0013
# Epoch 29/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0060 - val_loss: 1.9361e-04
# Epoch 30/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0058 - val_loss: 2.9483e-04
# Epoch 31/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0056 - val_loss: 9.3867e-04
# Epoch 32/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 4.0034e-04
# Epoch 33/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0055 - val_loss: 3.1768e-05
# Epoch 34/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 2.5078e-04
# Epoch 35/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 4.8549e-04
# Epoch 36/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 1.5386e-04
# Epoch 37/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0052 - val_loss: 5.1555e-04
# Epoch 38/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0049 - val_loss: 5.9159e-04
# Epoch 39/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0051 - val_loss: 6.5937e-04
# Epoch 40/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0051 - val_loss: 0.0013
# Epoch 41/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 1.1440e-04
# Epoch 42/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 1.8306e-04
# Epoch 43/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 9.3142e-04
# Epoch 44/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0047 - val_loss: 1.4090e-04
# Epoch 45/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0045 - val_loss: 2.9038e-05
# Epoch 46/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 4.5377e-04
# Epoch 47/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 0.0016
# Epoch 48/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 5.3893e-05
# Epoch 49/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0042 - val_loss: 1.9849e-04
# Epoch 50/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 5.3179e-04
# Epoch 51/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0043 - val_loss: 5.9277e-05
# Epoch 52/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0041 - val_loss: 1.3581e-04
# Epoch 53/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0040 - val_loss: 6.0782e-04
# Epoch 54/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0040 - val_loss: 0.0012
# Epoch 55/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0040 - val_loss: 2.2491e-04
# Epoch 56/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0040 - val_loss: 5.7506e-04
# Epoch 57/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0040 - val_loss: 7.3603e-04
# Epoch 58/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0038 - val_loss: 1.0508e-05
# Epoch 59/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0040 - val_loss: 4.7606e-05
# Epoch 60/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 3.2659e-05
# Epoch 61/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0037 - val_loss: 5.6523e-04
# Epoch 62/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 6.5042e-04
# Epoch 63/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0035 - val_loss: 6.7569e-05
# Epoch 64/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0035 - val_loss: 6.5471e-05
# Epoch 65/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0035 - val_loss: 1.3600e-04
# Epoch 66/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0035 - val_loss: 1.4245e-04
# Epoch 67/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 8.6786e-05
# Epoch 68/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0033 - val_loss: 2.2378e-04
# Epoch 69/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0033 - val_loss: 1.7553e-04
# Epoch 70/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0036 - val_loss: 1.5782e-04
# Epoch 71/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0036 - val_loss: 9.9344e-04
# Epoch 72/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0033 - val_loss: 2.4589e-05
# Epoch 73/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0032 - val_loss: 1.6106e-04
# Epoch 74/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0033 - val_loss: 3.4201e-04
# Epoch 75/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0031 - val_loss: 2.2659e-04
# Epoch 76/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0032 - val_loss: 9.9716e-05
# Epoch 77/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0032 - val_loss: 7.7321e-05
# Epoch 78/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 5.1658e-04
# Epoch 79/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0029 - val_loss: 4.9961e-05
# Epoch 80/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0033 - val_loss: 3.4492e-04
# Epoch 81/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 82/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 8.8605e-05
# Epoch 83/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0030 - val_loss: 3.3077e-05
# Epoch 84/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 6.0240e-04
# Epoch 85/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0029 - val_loss: 1.0297e-04
# Epoch 86/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0028 - val_loss: 4.9191e-05
# Epoch 87/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0027 - val_loss: 4.4525e-04
# Epoch 88/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0027 - val_loss: 1.6426e-04
# Epoch 89/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0027 - val_loss: 2.7096e-04
# Epoch 90/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0026 - val_loss: 5.0508e-05
# Epoch 91/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0026 - val_loss: 9.1604e-05
# Epoch 92/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0025 - val_loss: 1.3376e-04
# Epoch 93/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0025 - val_loss: 2.5382e-04
# Epoch 94/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0026 - val_loss: 2.2001e-04
# Epoch 95/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0025 - val_loss: 4.8773e-05
# Epoch 96/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0026 - val_loss: 4.0745e-04
# Epoch 97/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0025 - val_loss: 1.8716e-04
# Epoch 98/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0027 - val_loss: 6.9298e-05
# Epoch 99/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0023 - val_loss: 9.8248e-04
# Epoch 100/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 1.0942e-04
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 177ms/step
# Error Cuadrático Medio: 5095.81606640974
# Error Absoluto Medio: 63.210955240885404
# 1/1 [==============================] - 0s 24ms/step
# Predicciones para valores futuros de prod_pet: [785.1349  740.0951  712.0615  711.915   712.61053 713.9793  715.4984
#  716.9574 ]

# %%
import matplotlib.pyplot as plt

# Filtrar los datos de prueba para los valores de date_numeric 121, 122 y 123
test_data = filtered_data_one_id[filtered_data_one_id['date_numeric'].isin([121, 122, 123])]

# Extraer la columna de 'prod_pet' para los valores de date_numeric 121, 122 y 123
real_values = test_data['prod_pet'].values

# Obtener las predicciones para los valores de date_numeric 121, 122 y 123
# Aquí 'predictions' se supone que contiene las predicciones de los valores futuros
predicted_values = predictions[:3].flatten()

# Imprimir los valores reales de prod_pet para date_numeric 121, 122 y 123
print("Valores reales de prod_pet para date_numeric 121, 122 y 123:", real_values)

# Imprimir los valores predichos de prod_pet para date_numeric 121, 122 y 123
print("Valores predichos de prod_pet para date_numeric 121, 122 y 123:", predicted_values)

# Graficar los valores reales vs los valores predichos
plt.figure(figsize=(10, 5))
plt.plot([121, 122, 123], real_values, label='Actual', marker='o')
plt.plot([121, 122, 123], predicted_values, label='Predicho', marker='x')
plt.xlabel('date_numeric')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.savefig(image_save_path_three_lastmonths_50trials)
plt.show()
# Out:
# Valores reales de prod_pet para date_numeric 121, 122 y 123: [710.09  647.923 637.125]
# Valores predichos de prod_pet para date_numeric 121, 122 y 123: [785.1349 740.0951 712.0615]

# %%
# Load the existing CSV file

csv_results_file_path = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_MSE_50_trials.csv"
df = pd.read_csv(csv_results_file_path)

# Determine the current maximum index in the DataFrame
#max_index = df.index.max()

# Create a DataFrame with the new data, ensuring the indices are sequential from the current maximum index
#new_indices = [max_index + 1, max_index + 2, max_index + 3]

# Create a DataFrame with the new data
new_data = {
    'fecha': ['2024-01-01', '2024-02-01', '2024-03-01'],
    'idpozo': [idpozo, idpozo, idpozo],
    'prod_pet':predicted_values
}

new_df = pd.DataFrame(new_data)
combined_df = pd.concat([df, new_df], ignore_index=True)
combined_df.to_csv(csv_results_file_path, index=False)

#new_df = pd.DataFrame(new_data, index=new_indices)
#combined_df = pd.concat([df, new_df])
#combined_df.to_csv(csv_results_file_path, index=True, index_label='')

print(f'Nuevo valor agregado al csv {csv_results_file_path}')
# Out:
# Nuevo valor agregado al csv /content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_MSE_50_trials.csv

# %%
#Funcion objetivo mse y mae - 100 trials

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials
import tensorflow as tf

# Establecer una semilla aleatoria para reproducibilidad
np.random.seed(42)
tf.random.set_seed(42)

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'pet_inicial', 'gas_inicial', 'agua_inicial', 'prom_prod_pet', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_pet']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
#X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)
# Calcular el índice de corte para los últimos 3 valores (121, 122 y 123)
test_size = 3
split_index = len(X_sequences) - test_size

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test = X_sequences[:split_index], X_sequences[split_index:]
y_train, y_test = y_adjusted[:split_index], y_adjusted[split_index:]

# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, la combinación de MSE y MAE)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)

    # Calcular el MSE y MAE
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

    # Combinar MSE y MAE en una única métrica
    combined_metric = 0.5 * mse + 0.5 * mae
    return combined_metric

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=100, trials=trials)  # Aumentar max_evals

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

model.save(model_save_path_mse_mae_100trials)

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.savefig(image_save_path_mse_mae_100trials)
plt.show()

# Predecir "prod_pet" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [121, 122, 123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'pet_inicial': [filtered_data_one_id['pet_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'gas_inicial': [filtered_data_one_id['gas_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'agua_inicial': [filtered_data_one_id['agua_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'prom_prod_pet': [filtered_data_one_id['prom_prod_pet'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_pet:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 194ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 281ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 249ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 198ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 199ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 186ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 216ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 240ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 264ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 283ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 249ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 211ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 279ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 250ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 359ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 210ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 203ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 295ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 229ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 268ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 186ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 202ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 253ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 201ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 273ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 194ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 229ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 208ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 258ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 197ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 199ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 310ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 280ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 209ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 262ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 270ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 265ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 261ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 233ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 269ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 289ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 196ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 201ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 3s 3s/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 232ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 201ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 199ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 296ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 211ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 275ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 199ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 203ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 186ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 288ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 197ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 255ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 207ms/step
#
# 100%|██████████| 100/100 [24:05<00:00, 14.46s/trial, best loss: 1358.1043636693187]
# Mejor tamaño de lote: 16
# Mejor cantidad de épocas: 100
# Epoch 1/100
# 4/4 [==============================] - 2s 104ms/step - loss: 0.0586 - val_loss: 8.3703e-05
# Epoch 2/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0385 - val_loss: 0.0055
# Epoch 3/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0284 - val_loss: 0.0169
# Epoch 4/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0255 - val_loss: 0.0221
# Epoch 5/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0239 - val_loss: 0.0195
# Epoch 6/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0213 - val_loss: 0.0114
# Epoch 7/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0178 - val_loss: 0.0041
# Epoch 8/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0152 - val_loss: 5.6060e-04
# Epoch 9/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0135 - val_loss: 1.5592e-05
# Epoch 10/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0122 - val_loss: 1.9391e-04
# Epoch 11/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0106 - val_loss: 2.2036e-04
# Epoch 12/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0098 - val_loss: 3.9913e-04
# Epoch 13/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0093 - val_loss: 0.0016
# Epoch 14/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0089 - val_loss: 0.0027
# Epoch 15/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0087 - val_loss: 0.0028
# Epoch 16/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0084 - val_loss: 0.0013
# Epoch 17/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0082 - val_loss: 7.0859e-04
# Epoch 18/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0079 - val_loss: 8.8676e-04
# Epoch 19/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0077 - val_loss: 8.5809e-04
# Epoch 20/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0075 - val_loss: 1.6555e-04
# Epoch 21/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0074 - val_loss: 2.5255e-06
# Epoch 22/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0070 - val_loss: 2.1992e-04
# Epoch 23/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0066 - val_loss: 1.9350e-04
# Epoch 24/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0065 - val_loss: 1.3742e-05
# Epoch 25/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 9.2327e-05
# Epoch 26/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0059 - val_loss: 4.9748e-06
# Epoch 27/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0059 - val_loss: 5.4410e-05
# Epoch 28/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 1.5105e-04
# Epoch 29/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 5.3365e-06
# Epoch 30/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0052 - val_loss: 9.6039e-06
# Epoch 31/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 1.2810e-04
# Epoch 32/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0050 - val_loss: 3.9371e-05
# Epoch 33/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0049 - val_loss: 4.6110e-05
# Epoch 34/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0047 - val_loss: 4.0601e-04
# Epoch 35/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 1.4130e-05
# Epoch 36/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0045 - val_loss: 2.0868e-04
# Epoch 37/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0043 - val_loss: 2.0526e-05
# Epoch 38/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0043 - val_loss: 1.1345e-04
# Epoch 39/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0042 - val_loss: 7.8252e-04
# Epoch 40/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0041 - val_loss: 1.0523e-04
# Epoch 41/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0040 - val_loss: 3.0320e-05
# Epoch 42/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0040 - val_loss: 6.9590e-05
# Epoch 43/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0039 - val_loss: 2.1829e-04
# Epoch 44/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0039 - val_loss: 4.9496e-04
# Epoch 45/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0039 - val_loss: 5.0992e-05
# Epoch 46/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 9.5913e-04
# Epoch 47/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 3.0138e-05
# Epoch 48/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 3.6661e-04
# Epoch 49/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0036 - val_loss: 2.0798e-04
# Epoch 50/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0035 - val_loss: 2.0917e-04
# Epoch 51/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0035 - val_loss: 6.4445e-05
# Epoch 52/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0036 - val_loss: 3.4956e-04
# Epoch 53/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0040 - val_loss: 1.5701e-04
# Epoch 54/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 9.8133e-05
# Epoch 55/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0036 - val_loss: 5.8924e-04
# Epoch 56/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0034 - val_loss: 1.2766e-04
# Epoch 57/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0034 - val_loss: 0.0011
# Epoch 58/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0035 - val_loss: 1.6876e-04
# Epoch 59/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0033 - val_loss: 6.5493e-05
# Epoch 60/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0032 - val_loss: 5.7283e-04
# Epoch 61/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0033 - val_loss: 3.8088e-05
# Epoch 62/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0032 - val_loss: 5.3661e-05
# Epoch 63/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0031 - val_loss: 3.9614e-04
# Epoch 64/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0032 - val_loss: 3.7641e-04
# Epoch 65/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0031 - val_loss: 9.5623e-05
# Epoch 66/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0030 - val_loss: 3.6660e-04
# Epoch 67/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0030 - val_loss: 1.8835e-04
# Epoch 68/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0030 - val_loss: 3.5881e-04
# Epoch 69/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0029 - val_loss: 2.3529e-04
# Epoch 70/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 2.9055e-04
# Epoch 71/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0029 - val_loss: 9.8574e-04
# Epoch 72/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0031 - val_loss: 9.0433e-05
# Epoch 73/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0033 - val_loss: 1.7235e-04
# Epoch 74/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0029 - val_loss: 9.3227e-04
# Epoch 75/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0030 - val_loss: 5.0413e-05
# Epoch 76/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0027 - val_loss: 3.8171e-04
# Epoch 77/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0032 - val_loss: 5.2728e-05
# Epoch 78/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0028 - val_loss: 7.2805e-05
# Epoch 79/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0026 - val_loss: 0.0019
# Epoch 80/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0029 - val_loss: 5.2758e-05
# Epoch 81/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 1.2932e-04
# Epoch 82/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 7.4977e-04
# Epoch 83/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0027 - val_loss: 2.9418e-04
# Epoch 84/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0024 - val_loss: 6.6813e-05
# Epoch 85/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0024 - val_loss: 8.7060e-05
# Epoch 86/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0025 - val_loss: 3.9841e-04
# Epoch 87/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0027 - val_loss: 3.4459e-04
# Epoch 88/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0023 - val_loss: 2.5436e-04
# Epoch 89/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0025 - val_loss: 0.0015
# Epoch 90/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0023 - val_loss: 3.5181e-04
# Epoch 91/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0028 - val_loss: 5.6910e-04
# Epoch 92/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 93/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0024 - val_loss: 2.2133e-04
# Epoch 94/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0024 - val_loss: 3.4890e-04
# Epoch 95/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0023 - val_loss: 4.1833e-04
# Epoch 96/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0024 - val_loss: 8.9870e-05
# Epoch 97/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 98/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0021 - val_loss: 1.7190e-04
# Epoch 99/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0020 - val_loss: 3.0289e-04
# Epoch 100/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0022 - val_loss: 2.8205e-04
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 204ms/step
# Error Cuadrático Medio: 13135.408435385509
# Error Absoluto Medio: 99.2600302734375
# 1/1 [==============================] - 0s 26ms/step
# Predicciones para valores futuros de prod_pet: [894.8057  834.1419  781.8036  790.1408  800.0962  810.52075 821.6857
#  833.39197]

# %%
import matplotlib.pyplot as plt

# Filtrar los datos de prueba para los valores de date_numeric 121, 122 y 123
test_data = filtered_data_one_id[filtered_data_one_id['date_numeric'].isin([121, 122, 123])]

# Extraer la columna de 'prod_pet' para los valores de date_numeric 121, 122 y 123
real_values = test_data['prod_pet'].values

# Obtener las predicciones para los valores de date_numeric 121, 122 y 123
# Aquí 'predictions' se supone que contiene las predicciones de los valores futuros
predicted_values = predictions[:3].flatten()

# Imprimir los valores reales de prod_pet para date_numeric 121, 122 y 123
print("Valores reales de prod_pet para date_numeric 121, 122 y 123:", real_values)

# Imprimir los valores predichos de prod_pet para date_numeric 121, 122 y 123
print("Valores predichos de prod_pet para date_numeric 121, 122 y 123:", predicted_values)

# Graficar los valores reales vs los valores predichos
plt.figure(figsize=(10, 5))
plt.plot([121, 122, 123], real_values, label='Actual', marker='o')
plt.plot([121, 122, 123], predicted_values, label='Predicho', marker='x')
plt.xlabel('date_numeric')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.savefig(image_save_path_three_lastmonths_mse_mae_100trials)
plt.show()
# Out:
# Valores reales de prod_pet para date_numeric 121, 122 y 123: [710.09  647.923 637.125]
# Valores predichos de prod_pet para date_numeric 121, 122 y 123: [894.8057 834.1419 781.8036]

# %%
# Load the existing CSV file

csv_results_file_path = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_MSE_MAE_100_trials.csv"
df = pd.read_csv(csv_results_file_path)

# Determine the current maximum index in the DataFrame
#max_index = df.index.max()

# Create a DataFrame with the new data, ensuring the indices are sequential from the current maximum index
#new_indices = [max_index + 1, max_index + 2, max_index + 3]

# Create a DataFrame with the new data
new_data = {
    'fecha': ['2024-01-01', '2024-02-01', '2024-03-01'],
    'idpozo': [idpozo, idpozo, idpozo],
    'prod_pet':predicted_values
}

new_df = pd.DataFrame(new_data)
combined_df = pd.concat([df, new_df], ignore_index=True)
combined_df.to_csv(csv_results_file_path, index=False)

#new_df = pd.DataFrame(new_data, index=new_indices)
#combined_df = pd.concat([df, new_df])
#combined_df.to_csv(csv_results_file_path, index=True, index_label='')

print(f'Nuevo valor agregado al csv {csv_results_file_path}')
# Out:
# Nuevo valor agregado al csv /content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_MSE_MAE_100_trials.csv

# %%
# Con 100 Trials - mse only

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'pet_inicial', 'gas_inicial', 'agua_inicial', 'prom_prod_pet', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_pet']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
#X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)
# Calcular el índice de corte para los últimos 3 valores (121, 122 y 123)
test_size = 3
split_index = len(X_sequences) - test_size

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test = X_sequences[:split_index], X_sequences[split_index:]
y_train, y_test = y_adjusted[:split_index], y_adjusted[split_index:]


# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, el error cuadrático medio)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    return mse

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=50, trials=trials)


###########################################################################
#from tensorflow.keras.models import load_model
#model = load_model(model_save_path_100trials)

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

model.save(model_save_path_100trials)
###########################################################################

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.savefig(image_save_path_100trials)
plt.show()

# Predecir "prod_pet" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [121, 122, 123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'pet_inicial': [filtered_data_one_id['pet_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'gas_inicial': [filtered_data_one_id['gas_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'agua_inicial': [filtered_data_one_id['agua_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'prom_prod_pet': [filtered_data_one_id['prom_prod_pet'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_pet:", predictions.flatten())
# Out:
# 1/1 [==============================] - 0s 338ms/step
# Error Cuadrático Medio: 6825.656436219794
# Error Absoluto Medio: 77.82165266927082
# 1/1 [==============================] - 0s 20ms/step
# Predicciones para valores futuros de prod_pet: [844.602   770.94696 716.1793  716.48474 716.95996 718.30286 719.8666
#  721.74133]

# %%
import matplotlib.pyplot as plt

# Filtrar los datos de prueba para los valores de date_numeric 121, 122 y 123
test_data = filtered_data_one_id[filtered_data_one_id['date_numeric'].isin([121, 122, 123])]

# Extraer la columna de 'prod_pet' para los valores de date_numeric 121, 122 y 123
real_values = test_data['prod_pet'].values

# Obtener las predicciones para los valores de date_numeric 121, 122 y 123
# Aquí 'predictions' se supone que contiene las predicciones de los valores futuros
predicted_values = predictions[:3].flatten()

# Imprimir los valores reales de prod_pet para date_numeric 121, 122 y 123
print("Valores reales de prod_pet para date_numeric 121, 122 y 123:", real_values)

# Imprimir los valores predichos de prod_pet para date_numeric 121, 122 y 123
print("Valores predichos de prod_pet para date_numeric 121, 122 y 123:", predicted_values)

# Graficar los valores reales vs los valores predichos
plt.figure(figsize=(10, 5))
plt.plot([121, 122, 123], real_values, label='Actual', marker='o')
plt.plot([121, 122, 123], predicted_values, label='Predicho', marker='x')
plt.xlabel('date_numeric')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.savefig(image_save_path_three_lastmonths_100trials)
plt.show()
# Out:
# Valores reales de prod_pet para date_numeric 121, 122 y 123: [710.09  647.923 637.125]
# Valores predichos de prod_pet para date_numeric 121, 122 y 123: [844.602   770.94696 716.1793 ]

# %%
# Load the existing CSV file

csv_results_file_path = f"/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_MSE_100_trials.csv"
df = pd.read_csv(csv_results_file_path)

# Determine the current maximum index in the DataFrame
#max_index = df.index.max()

# Create a DataFrame with the new data, ensuring the indices are sequential from the current maximum index
#new_indices = [max_index + 1, max_index + 2, max_index + 3]

# Create a DataFrame with the new data
new_data = {
    'fecha': ['2024-01-01', '2024-02-01', '2024-03-01'],
    'idpozo': [idpozo, idpozo, idpozo],
    'prod_pet':predicted_values
}

new_df = pd.DataFrame(new_data)
combined_df = pd.concat([df, new_df], ignore_index=True)
combined_df.to_csv(csv_results_file_path, index=False)

#new_df = pd.DataFrame(new_data, index=new_indices)
#combined_df = pd.concat([df, new_df])
#combined_df.to_csv(csv_results_file_path, index=True, index_label='')

print(f'Nuevo valor agregado al csv {csv_results_file_path}')
# Out:
# Nuevo valor agregado al csv /content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/predictions_agregacion_MSE_100_trials.csv
