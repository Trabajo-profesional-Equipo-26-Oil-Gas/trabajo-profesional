# %% [markdown]
# #Partiendo de la limpieza de datos realizada previamente, se utiliza LSTM para predecir la producción de pozos de petroleo.
#
# ###Pozos a predecir:
# 158364, 160211, 160332, 160789, 160810, 160814, 161451, 162200, 162405, 162955, 163237, 163942

# %%
import math
import itertools
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import LSTM, Dense
from keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
pd.set_option('display.max_columns', None)

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

#dataset = pd.read_csv("/content/drive/MyDrive/Trabajo profesional/Code/data/prod_norm_2024-05-27_03:42:59.csv", index_col=0)
dataset = pd.read_csv("/content/drive/MyDrive/Trabajo profesional/Code/data/prod_clean_2024-05-13_17:08:31.csv", index_col=0)

dataset = dataset[dataset['anio'] >= 2014]

# Seleccionar características relevantes
features = ['prod_pet', 'anio', 'mes', 'idpozo', 'prod_gas', 'prod_agua', 'tef', 'coordenadax', 'coordenaday', 'cota', 'pet_inicial', 'gas_inicial', 'agua_inicial']

# Filtrar características
data = dataset[features]

# Creacion de una nueva columna 'date' combinando 'anio' y 'mes' para representar la fecha
data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')

data.drop(['mes', 'anio'], axis=1, inplace=True)

# Conversion de la columna 'date' a "datetime type"
data['date'] = pd.to_datetime(data['date'])

# Definicion de un dia de referencia inicial (Es la primera fecha desde la que se filtro previamente).
reference_date = pd.Timestamp('2014-01-01')

# Calculo del numero de meses desde la referencia para cada date.
data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1

data.drop(['date'], axis=1, inplace=True)

filtered_data_one_id = data[data['idpozo'] == 160332]

filtered_data_one_id.drop(['idpozo'], axis=1, inplace=True)
# Out:
# Mounted at /content/drive
# <ipython-input-1-b74a8a2c8d55>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')
# <ipython-input-1-b74a8a2c8d55>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['mes', 'anio'], axis=1, inplace=True)
# <ipython-input-1-b74a8a2c8d55>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['date'])
# <ipython-input-1-b74a8a2c8d55>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1
# <ipython-input-1-b74a8a2c8d55>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['date'], axis=1, inplace=True)
# <ipython-input-1-b74a8a2c8d55>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data_one_id.drop(['idpozo'], axis=1, inplace=True)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'pet_inicial', 'gas_inicial', 'agua_inicial', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_pet']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)

# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, el error cuadrático medio)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    return mse

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=10, trials=trials)

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.show()

# Predecir "prod_pet" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'pet_inicial': [filtered_data_one_id['pet_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'gas_inicial': [filtered_data_one_id['gas_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'agua_inicial': [filtered_data_one_id['agua_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_pet:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 224ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 297ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 320ms/step
#
#  40%|████      | 4/10 [00:48<01:23, 13.92s/trial, best loss: 35193.39027414922]
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f4c7c486dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 264ms/step
#
#  50%|█████     | 5/10 [00:58<01:02, 12.56s/trial, best loss: 35193.39027414922]
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f4c7c347b50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 285ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 196ms/step
#
# 100%|██████████| 10/10 [01:53<00:00, 11.36s/trial, best loss: 4890.9582797821395]
# Mejor tamaño de lote: 64
# Mejor cantidad de épocas: 100
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.1931 - val_loss: 0.0131
# Epoch 2/100
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1814 - val_loss: 0.0093
# Epoch 3/100
# 1/1 [==============================] - 0s 90ms/step - loss: 0.1702 - val_loss: 0.0061
# Epoch 4/100
# 1/1 [==============================] - 0s 92ms/step - loss: 0.1595 - val_loss: 0.0036
# Epoch 5/100
# 1/1 [==============================] - 0s 91ms/step - loss: 0.1494 - val_loss: 0.0018
# Epoch 6/100
# 1/1 [==============================] - 0s 75ms/step - loss: 0.1398 - val_loss: 7.0101e-04
# Epoch 7/100
# 1/1 [==============================] - 0s 81ms/step - loss: 0.1306 - val_loss: 3.1243e-04
# Epoch 8/100
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1220 - val_loss: 6.8144e-04
# Epoch 9/100
# 1/1 [==============================] - 0s 92ms/step - loss: 0.1139 - val_loss: 0.0019
# Epoch 10/100
# 1/1 [==============================] - 0s 83ms/step - loss: 0.1063 - val_loss: 0.0039
# Epoch 11/100
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0992 - val_loss: 0.0068
# Epoch 12/100
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0927 - val_loss: 0.0106
# Epoch 13/100
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0868 - val_loss: 0.0153
# Epoch 14/100
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0814 - val_loss: 0.0209
# Epoch 15/100
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0767 - val_loss: 0.0274
# Epoch 16/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0726 - val_loss: 0.0345
# Epoch 17/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0691 - val_loss: 0.0422
# Epoch 18/100
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0662 - val_loss: 0.0503
# Epoch 19/100
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0640 - val_loss: 0.0584
# Epoch 20/100
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0623 - val_loss: 0.0664
# Epoch 21/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0611 - val_loss: 0.0740
# Epoch 22/100
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0603 - val_loss: 0.0809
# Epoch 23/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0598 - val_loss: 0.0868
# Epoch 24/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0595 - val_loss: 0.0915
# Epoch 25/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0592 - val_loss: 0.0948
# Epoch 26/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0590 - val_loss: 0.0968
# Epoch 27/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0587 - val_loss: 0.0973
# Epoch 28/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0583 - val_loss: 0.0965
# Epoch 29/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0577 - val_loss: 0.0945
# Epoch 30/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0569 - val_loss: 0.0915
# Epoch 31/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0560 - val_loss: 0.0877
# Epoch 32/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0549 - val_loss: 0.0833
# Epoch 33/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0538 - val_loss: 0.0785
# Epoch 34/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0527 - val_loss: 0.0734
# Epoch 35/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0515 - val_loss: 0.0683
# Epoch 36/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0504 - val_loss: 0.0633
# Epoch 37/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0494 - val_loss: 0.0584
# Epoch 38/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0484 - val_loss: 0.0539
# Epoch 39/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0476 - val_loss: 0.0496
# Epoch 40/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0468 - val_loss: 0.0457
# Epoch 41/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0461 - val_loss: 0.0422
# Epoch 42/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0454 - val_loss: 0.0391
# Epoch 43/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0448 - val_loss: 0.0364
# Epoch 44/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0442 - val_loss: 0.0340
# Epoch 45/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0437 - val_loss: 0.0320
# Epoch 46/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0431 - val_loss: 0.0302
# Epoch 47/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0425 - val_loss: 0.0288
# Epoch 48/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0419 - val_loss: 0.0275
# Epoch 49/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0412 - val_loss: 0.0265
# Epoch 50/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0406 - val_loss: 0.0257
# Epoch 51/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0399 - val_loss: 0.0250
# Epoch 52/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0392 - val_loss: 0.0245
# Epoch 53/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0385 - val_loss: 0.0240
# Epoch 54/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0378 - val_loss: 0.0236
# Epoch 55/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0371 - val_loss: 0.0233
# Epoch 56/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0364 - val_loss: 0.0229
# Epoch 57/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0357 - val_loss: 0.0226
# Epoch 58/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0350 - val_loss: 0.0222
# Epoch 59/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0343 - val_loss: 0.0217
# Epoch 60/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0337 - val_loss: 0.0211
# Epoch 61/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0330 - val_loss: 0.0204
# Epoch 62/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0324 - val_loss: 0.0197
# Epoch 63/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0318 - val_loss: 0.0188
# Epoch 64/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0311 - val_loss: 0.0178
# Epoch 65/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0304 - val_loss: 0.0167
# Epoch 66/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0298 - val_loss: 0.0156
# Epoch 67/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0291 - val_loss: 0.0144
# Epoch 68/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0284 - val_loss: 0.0133
# Epoch 69/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0277 - val_loss: 0.0121
# Epoch 70/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0270 - val_loss: 0.0109
# Epoch 71/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0263 - val_loss: 0.0098
# Epoch 72/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0257 - val_loss: 0.0088
# Epoch 73/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0250 - val_loss: 0.0078
# Epoch 74/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0243 - val_loss: 0.0069
# Epoch 75/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0236 - val_loss: 0.0061
# Epoch 76/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0230 - val_loss: 0.0053
# Epoch 77/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0223 - val_loss: 0.0046
# Epoch 78/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0217 - val_loss: 0.0040
# Epoch 79/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0210 - val_loss: 0.0035
# Epoch 80/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0203 - val_loss: 0.0030
# Epoch 81/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0197 - val_loss: 0.0025
# Epoch 82/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0190 - val_loss: 0.0022
# Epoch 83/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0184 - val_loss: 0.0018
# Epoch 84/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0178 - val_loss: 0.0015
# Epoch 85/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0172 - val_loss: 0.0012
# Epoch 86/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0166 - val_loss: 0.0010
# Epoch 87/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0160 - val_loss: 8.2047e-04
# Epoch 88/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0154 - val_loss: 6.6546e-04
# Epoch 89/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0149 - val_loss: 5.5280e-04
# Epoch 90/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0143 - val_loss: 4.8679e-04
# Epoch 91/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0138 - val_loss: 4.7238e-04
# Epoch 92/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0133 - val_loss: 5.1487e-04
# Epoch 93/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0128 - val_loss: 6.1861e-04
# Epoch 94/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0123 - val_loss: 7.8748e-04
# Epoch 95/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0119 - val_loss: 0.0010
# Epoch 96/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0114 - val_loss: 0.0013
# Epoch 97/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0110 - val_loss: 0.0017
# Epoch 98/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0106 - val_loss: 0.0021
# Epoch 99/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0102 - val_loss: 0.0026
# Epoch 100/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0099 - val_loss: 0.0031
# 1/1 [==============================] - 0s 234ms/step
# Error Cuadrático Medio: 36672.84699868157
# Error Absoluto Medio: 173.03213938395183
# 1/1 [==============================] - 0s 29ms/step
# Predicciones para valores futuros de prod_pet: [475.28143 493.44595 481.3212  462.31177 443.98135 426.45395]

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials
import tensorflow as tf

# Establecer una semilla aleatoria para reproducibilidad
np.random.seed(42)
tf.random.set_seed(42)

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_pet']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)

# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, la combinación de MSE y MAE)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)

    # Calcular el MSE y MAE
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

    # Combinar MSE y MAE en una única métrica
    combined_metric = 0.5 * mse + 0.5 * mae
    return combined_metric

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=50, trials=trials)  # Aumentar max_evals

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.show()

# Predecir "prod_pet" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_pet:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 193ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 277ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 346ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 258ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 171ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 163ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 247ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 224ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 195ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 166ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 204ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 190ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 194ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 249ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 199ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 196ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 230ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 212ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 212ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 197ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 196ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 166ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 212ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 250ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 210ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 166ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 263ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 204ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 280ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 227ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 192ms/step
#
# 100%|██████████| 50/50 [11:13<00:00, 13.47s/trial, best loss: 2828.1126938375537]
# Mejor tamaño de lote: 64
# Mejor cantidad de épocas: 100
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 2/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 3/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 4/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 5/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 6/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 7/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 8/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 9/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 10/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 11/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 12/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 13/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 14/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 15/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 16/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 17/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 18/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 19/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 20/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 21/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 22/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 23/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 24/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 25/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 26/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 27/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 28/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 29/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 30/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 31/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 32/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 33/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 34/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 35/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 36/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 37/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 38/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 39/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 40/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 41/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 42/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 43/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 44/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 45/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 46/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 47/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 48/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 49/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 50/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 51/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 52/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 53/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 54/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 55/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 56/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 57/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 58/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 59/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 60/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 61/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 62/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 63/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 64/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 65/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 66/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 67/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 68/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 69/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 70/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 71/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 72/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 73/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 74/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 75/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 76/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 77/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 78/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 79/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 80/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 81/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 82/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 83/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 84/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 85/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 86/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 87/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 88/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 89/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 90/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 91/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 92/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 93/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 94/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 95/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 96/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 97/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 98/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 99/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.2488 - val_loss: 0.0462
# Epoch 100/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2488 - val_loss: 0.0462
# 1/1 [==============================] - 0s 204ms/step
# Error Cuadrático Medio: 546068.1089333333
# Error Absoluto Medio: 736.0866666666666
# 1/1 [==============================] - 0s 23ms/step
# Predicciones para valores futuros de prod_pet: [13. 13. 13. 13. 13. 13.]
