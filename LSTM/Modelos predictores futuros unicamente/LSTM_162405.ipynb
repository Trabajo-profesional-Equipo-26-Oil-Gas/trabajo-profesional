# %% [markdown]
# #Partiendo de la limpieza de datos realizada previamente, se utiliza LSTM para predecir la producción de pozos de petroleo.
#
# ###Pozos a predecir:
# 158364, 160211, 160332, 160789, 160810, 160814, 161451, 162200, 162405, 162955, 163237, 163942

# %%
import math
import itertools
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import LSTM, Dense
from keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
pd.set_option('display.max_columns', None)

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

#dataset = pd.read_csv("/content/drive/MyDrive/Trabajo profesional/Code/data/prod_norm_2024-05-27_03:42:59.csv", index_col=0)
dataset = pd.read_csv("/content/drive/MyDrive/Trabajo profesional/Code/data/prod_clean_2024-05-13_17:08:31.csv", index_col=0)

dataset = dataset[dataset['anio'] >= 2014]

# Seleccionar características relevantes
features = ['prod_pet', 'anio', 'mes', 'idpozo', 'prod_gas', 'prod_agua', 'tef', 'coordenadax', 'coordenaday', 'cota', 'pet_inicial', 'gas_inicial', 'agua_inicial']

# Filtrar características
data = dataset[features]

# Creacion de una nueva columna 'date' combinando 'anio' y 'mes' para representar la fecha
data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')

# Encontrar la fecha más reciente
last_date = data['date'].max()

print("La fecha más reciente es:", last_date)

# Conversion de la columna 'date' a "datetime type"
data['date'] = pd.to_datetime(data['date'])

# Definicion de un dia de referencia inicial (Es la primera fecha desde la que se filtro previamente).
reference_date = pd.Timestamp('2014-01-01')

# Calculo del numero de meses desde la referencia para cada date.
data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1

# Filtrar por un id específico
filtered_data_one_id = data[data['idpozo'] == 162405]

# Eliminar las columnas que no necesitas
filtered_data_one_id.drop(['mes', 'anio', 'idpozo'], axis=1, inplace=True)

# Encontrar el valor de date_numeric correspondiente a la última fecha
last_date_numeric = filtered_data_one_id.loc[filtered_data_one_id['date'] == last_date, 'date_numeric'].values[0]

print("El valor de date_numeric correspondiente a la fecha más reciente es:", last_date_numeric)
# Out:
# Mounted at /content/drive
# La fecha más reciente es: 2024-03-01 00:00:00
# El valor de date_numeric correspondiente a la fecha más reciente es: 123
# <ipython-input-9-01dce3f7e141>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')
# <ipython-input-9-01dce3f7e141>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['date'])
# <ipython-input-9-01dce3f7e141>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1
# <ipython-input-9-01dce3f7e141>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data_one_id.drop(['mes', 'anio', 'idpozo'], axis=1, inplace=True)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'pet_inicial', 'gas_inicial', 'agua_inicial', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_pet']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)

# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, el error cuadrático medio)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    return mse

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=10, trials=trials)

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

model.save("/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/best_lstm_model_162405.h5")

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.show()

# Predecir "prod_pet" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [124, 125, 126, 127, 128, 129]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'pet_inicial': [filtered_data_one_id['pet_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'gas_inicial': [filtered_data_one_id['gas_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'agua_inicial': [filtered_data_one_id['agua_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_pet:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 196ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 262ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 198ms/step
#
# 100%|██████████| 10/10 [02:17<00:00, 13.72s/trial, best loss: 35645.520839428704]
# Mejor tamaño de lote: 64
# Mejor cantidad de épocas: 200
# Epoch 1/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.1302 - val_loss: 4.8076e-04
# Epoch 2/200
# 1/1 [==============================] - 0s 74ms/step - loss: 0.1244 - val_loss: 3.9511e-04
# Epoch 3/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.1190 - val_loss: 8.8389e-04
# Epoch 4/200
# 1/1 [==============================] - 0s 75ms/step - loss: 0.1140 - val_loss: 0.0019
# Epoch 5/200
# 1/1 [==============================] - 0s 75ms/step - loss: 0.1094 - val_loss: 0.0035
# Epoch 6/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1052 - val_loss: 0.0054
# Epoch 7/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1013 - val_loss: 0.0078
# Epoch 8/200
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0979 - val_loss: 0.0104
# Epoch 9/200
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0947 - val_loss: 0.0131
# Epoch 10/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0919 - val_loss: 0.0160
# Epoch 11/200
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0893 - val_loss: 0.0188
# Epoch 12/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0871 - val_loss: 0.0215
# Epoch 13/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0850 - val_loss: 0.0241
# Epoch 14/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0831 - val_loss: 0.0264
# Epoch 15/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0814 - val_loss: 0.0285
# Epoch 16/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0798 - val_loss: 0.0303
# Epoch 17/200
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0783 - val_loss: 0.0318
# Epoch 18/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0769 - val_loss: 0.0329
# Epoch 19/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0756 - val_loss: 0.0337
# Epoch 20/200
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0743 - val_loss: 0.0341
# Epoch 21/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0731 - val_loss: 0.0342
# Epoch 22/200
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0718 - val_loss: 0.0339
# Epoch 23/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0706 - val_loss: 0.0332
# Epoch 24/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0694 - val_loss: 0.0323
# Epoch 25/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0682 - val_loss: 0.0310
# Epoch 26/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0669 - val_loss: 0.0296
# Epoch 27/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0656 - val_loss: 0.0279
# Epoch 28/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0642 - val_loss: 0.0260
# Epoch 29/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0629 - val_loss: 0.0240
# Epoch 30/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0615 - val_loss: 0.0220
# Epoch 31/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0601 - val_loss: 0.0199
# Epoch 32/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0588 - val_loss: 0.0178
# Epoch 33/200
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0575 - val_loss: 0.0158
# Epoch 34/200
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0563 - val_loss: 0.0139
# Epoch 35/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0550 - val_loss: 0.0122
# Epoch 36/200
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0538 - val_loss: 0.0106
# Epoch 37/200
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0526 - val_loss: 0.0092
# Epoch 38/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0514 - val_loss: 0.0079
# Epoch 39/200
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0502 - val_loss: 0.0068
# Epoch 40/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0491 - val_loss: 0.0059
# Epoch 41/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0480 - val_loss: 0.0050
# Epoch 42/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0468 - val_loss: 0.0041
# Epoch 43/200
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0456 - val_loss: 0.0035
# Epoch 44/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0443 - val_loss: 0.0029
# Epoch 45/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0430 - val_loss: 0.0024
# Epoch 46/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0417 - val_loss: 0.0020
# Epoch 47/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0405 - val_loss: 0.0017
# Epoch 48/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0392 - val_loss: 0.0014
# Epoch 49/200
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0379 - val_loss: 0.0012
# Epoch 50/200
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0367 - val_loss: 0.0010
# Epoch 51/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0354 - val_loss: 8.9065e-04
# Epoch 52/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0342 - val_loss: 7.7997e-04
# Epoch 53/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0331 - val_loss: 7.1504e-04
# Epoch 54/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0320 - val_loss: 7.1346e-04
# Epoch 55/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0309 - val_loss: 7.9972e-04
# Epoch 56/200
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0299 - val_loss: 0.0010
# Epoch 57/200
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0289 - val_loss: 0.0013
# Epoch 58/200
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0280 - val_loss: 0.0015
# Epoch 59/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0271 - val_loss: 0.0017
# Epoch 60/200
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0262 - val_loss: 0.0019
# Epoch 61/200
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0253 - val_loss: 0.0021
# Epoch 62/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0244 - val_loss: 0.0021
# Epoch 63/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0236 - val_loss: 0.0021
# Epoch 64/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0228 - val_loss: 0.0021
# Epoch 65/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0221 - val_loss: 0.0021
# Epoch 66/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0214 - val_loss: 0.0021
# Epoch 67/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0208 - val_loss: 0.0021
# Epoch 68/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0203 - val_loss: 0.0021
# Epoch 69/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0198 - val_loss: 0.0021
# Epoch 70/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0193 - val_loss: 0.0021
# Epoch 71/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0188 - val_loss: 0.0021
# Epoch 72/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0183 - val_loss: 0.0021
# Epoch 73/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0178 - val_loss: 0.0021
# Epoch 74/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0172 - val_loss: 0.0021
# Epoch 75/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0167 - val_loss: 0.0021
# Epoch 76/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0161 - val_loss: 0.0021
# Epoch 77/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0156 - val_loss: 0.0021
# Epoch 78/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0151 - val_loss: 0.0021
# Epoch 79/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0147 - val_loss: 0.0021
# Epoch 80/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0143 - val_loss: 0.0021
# Epoch 81/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0138 - val_loss: 0.0021
# Epoch 82/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0134 - val_loss: 0.0021
# Epoch 83/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0130 - val_loss: 0.0021
# Epoch 84/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0127 - val_loss: 0.0021
# Epoch 85/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0124 - val_loss: 0.0021
# Epoch 86/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0121 - val_loss: 0.0021
# Epoch 87/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0119 - val_loss: 0.0021
# Epoch 88/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0116 - val_loss: 0.0021
# Epoch 89/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0114 - val_loss: 0.0021
# Epoch 90/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0112 - val_loss: 0.0021
# Epoch 91/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0110 - val_loss: 0.0021
# Epoch 92/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0108 - val_loss: 0.0021
# Epoch 93/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0106 - val_loss: 0.0021
# Epoch 94/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0105 - val_loss: 0.0021
# Epoch 95/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0103 - val_loss: 0.0021
# Epoch 96/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0102 - val_loss: 0.0021
# Epoch 97/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0100 - val_loss: 0.0021
# Epoch 98/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0099 - val_loss: 0.0021
# Epoch 99/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0098 - val_loss: 0.0021
# Epoch 100/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0097 - val_loss: 0.0021
# Epoch 101/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0096 - val_loss: 0.0021
# Epoch 102/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0094 - val_loss: 0.0021
# Epoch 103/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0093 - val_loss: 0.0021
# Epoch 104/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0092 - val_loss: 0.0021
# Epoch 105/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0091 - val_loss: 0.0021
# Epoch 106/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0090 - val_loss: 0.0021
# Epoch 107/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0089 - val_loss: 0.0021
# Epoch 108/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0087 - val_loss: 0.0021
# Epoch 109/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0086 - val_loss: 0.0021
# Epoch 110/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0085 - val_loss: 0.0021
# Epoch 111/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0084 - val_loss: 0.0021
# Epoch 112/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0083 - val_loss: 0.0021
# Epoch 113/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0082 - val_loss: 0.0021
# Epoch 114/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0082 - val_loss: 0.0021
# Epoch 115/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0081 - val_loss: 0.0021
# Epoch 116/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0080 - val_loss: 0.0021
# Epoch 117/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0079 - val_loss: 0.0021
# Epoch 118/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0078 - val_loss: 0.0021
# Epoch 119/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0078 - val_loss: 0.0021
# Epoch 120/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0077 - val_loss: 0.0021
# Epoch 121/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0076 - val_loss: 0.0021
# Epoch 122/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0076 - val_loss: 0.0021
# Epoch 123/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0075 - val_loss: 0.0021
# Epoch 124/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0075 - val_loss: 0.0021
# Epoch 125/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0074 - val_loss: 0.0021
# Epoch 126/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0074 - val_loss: 0.0021
# Epoch 127/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0073 - val_loss: 0.0021
# Epoch 128/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0072 - val_loss: 0.0021
# Epoch 129/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0072 - val_loss: 0.0021
# Epoch 130/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0071 - val_loss: 0.0021
# Epoch 131/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0071 - val_loss: 0.0021
# Epoch 132/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0071 - val_loss: 0.0021
# Epoch 133/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0070 - val_loss: 0.0021
# Epoch 134/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0070 - val_loss: 0.0021
# Epoch 135/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0069 - val_loss: 0.0021
# Epoch 136/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0069 - val_loss: 0.0021
# Epoch 137/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0068 - val_loss: 0.0021
# Epoch 138/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0068 - val_loss: 0.0021
# Epoch 139/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0068 - val_loss: 0.0021
# Epoch 140/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0067 - val_loss: 0.0021
# Epoch 141/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0067 - val_loss: 0.0021
# Epoch 142/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0066 - val_loss: 0.0021
# Epoch 143/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0066 - val_loss: 0.0021
# Epoch 144/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0066 - val_loss: 0.0021
# Epoch 145/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0065 - val_loss: 0.0021
# Epoch 146/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0065 - val_loss: 0.0021
# Epoch 147/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0065 - val_loss: 0.0021
# Epoch 148/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0064 - val_loss: 0.0021
# Epoch 149/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0064 - val_loss: 0.0021
# Epoch 150/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0064 - val_loss: 0.0021
# Epoch 151/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0063 - val_loss: 0.0021
# Epoch 152/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0063 - val_loss: 0.0021
# Epoch 153/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0063 - val_loss: 0.0021
# Epoch 154/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0063 - val_loss: 0.0021
# Epoch 155/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0062 - val_loss: 0.0021
# Epoch 156/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0062 - val_loss: 0.0021
# Epoch 157/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0062 - val_loss: 0.0021
# Epoch 158/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0062 - val_loss: 0.0021
# Epoch 159/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0061 - val_loss: 0.0021
# Epoch 160/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0061 - val_loss: 0.0021
# Epoch 161/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0061 - val_loss: 0.0021
# Epoch 162/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0061 - val_loss: 0.0021
# Epoch 163/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0060 - val_loss: 0.0021
# Epoch 164/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0060 - val_loss: 0.0021
# Epoch 165/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0060 - val_loss: 0.0021
# Epoch 166/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0060 - val_loss: 0.0021
# Epoch 167/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0059 - val_loss: 0.0021
# Epoch 168/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0059 - val_loss: 0.0021
# Epoch 169/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0059 - val_loss: 0.0021
# Epoch 170/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0059 - val_loss: 0.0021
# Epoch 171/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0059 - val_loss: 0.0021
# Epoch 172/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 173/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 174/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 175/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 176/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 177/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0057 - val_loss: 0.0021
# Epoch 178/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0057 - val_loss: 0.0021
# Epoch 179/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0057 - val_loss: 0.0021
# Epoch 180/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0057 - val_loss: 0.0021
# Epoch 181/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0056 - val_loss: 0.0021
# Epoch 182/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0056 - val_loss: 0.0021
# Epoch 183/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0056 - val_loss: 0.0021
# Epoch 184/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0056 - val_loss: 0.0021
# Epoch 185/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0056 - val_loss: 0.0021
# Epoch 186/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0055 - val_loss: 0.0021
# Epoch 187/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0055 - val_loss: 0.0021
# Epoch 188/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0055 - val_loss: 0.0021
# Epoch 189/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0055 - val_loss: 0.0021
# Epoch 190/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0055 - val_loss: 0.0021
# Epoch 191/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0054 - val_loss: 0.0021
# Epoch 192/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0054 - val_loss: 0.0021
# Epoch 193/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0054 - val_loss: 0.0021
# Epoch 194/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0054 - val_loss: 0.0021
# Epoch 195/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0054 - val_loss: 0.0021
# Epoch 196/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0053 - val_loss: 0.0021
# Epoch 197/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0053 - val_loss: 0.0021
# Epoch 198/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0053 - val_loss: 0.0021
# Epoch 199/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0053 - val_loss: 0.0021
# Epoch 200/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0053 - val_loss: 0.0021
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 177ms/step
# Error Cuadrático Medio: 35645.520839428704
# Error Absoluto Medio: 162.43571550641738
# 1/1 [==============================] - 0s 19ms/step
# Predicciones para valores futuros de prod_pet: [385.28 385.28 385.28 385.28 385.28 385.28]

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials
import tensorflow as tf

# Establecer una semilla aleatoria para reproducibilidad
np.random.seed(42)
tf.random.set_seed(42)

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_pet']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)

# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, la combinación de MSE y MAE)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)

    # Calcular el MSE y MAE
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

    # Combinar MSE y MAE en una única métrica
    combined_metric = 0.5 * mse + 0.5 * mae
    return combined_metric

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=50, trials=trials)  # Aumentar max_evals

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
#history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

model.save("/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/best_lstm_model_mse_mae_162405.h5")

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.show()

# Predecir "prod_pet" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_pet:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 207ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 241ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 203ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 195ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 195ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 195ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 207ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 192ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 186ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 190ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 267ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 194ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 298ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 200ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 232ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 211ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 216ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 215ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 195ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 199ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 271ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 339ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 288ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 260ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 315ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 351ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 325ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 289ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 226ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 215ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 206ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 204ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 307ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 203ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 202ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 214ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 281ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 284ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 202ms/step
#
# 100%|██████████| 50/50 [12:11<00:00, 14.62s/trial, best loss: 16569.972540974948]
# Mejor tamaño de lote: 32
# Mejor cantidad de épocas: 300
# Epoch 1/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.1312 - val_loss: 4.8695e-04
# Epoch 2/300
# 1/1 [==============================] - 0s 79ms/step - loss: 0.1253 - val_loss: 8.2103e-04
# Epoch 3/300
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1198 - val_loss: 0.0017
# Epoch 4/300
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1147 - val_loss: 0.0030
# Epoch 5/300
# 1/1 [==============================] - 0s 80ms/step - loss: 0.1100 - val_loss: 0.0048
# Epoch 6/300
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1056 - val_loss: 0.0071
# Epoch 7/300
# 1/1 [==============================] - 0s 74ms/step - loss: 0.1015 - val_loss: 0.0097
# Epoch 8/300
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0979 - val_loss: 0.0126
# Epoch 9/300
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0945 - val_loss: 0.0157
# Epoch 10/300
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0915 - val_loss: 0.0189
# Epoch 11/300
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0889 - val_loss: 0.0220
# Epoch 12/300
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0865 - val_loss: 0.0251
# Epoch 13/300
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0844 - val_loss: 0.0280
# Epoch 14/300
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0825 - val_loss: 0.0307
# Epoch 15/300
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0807 - val_loss: 0.0332
# Epoch 16/300
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0791 - val_loss: 0.0354
# Epoch 17/300
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0777 - val_loss: 0.0374
# Epoch 18/300
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0764 - val_loss: 0.0390
# Epoch 19/300
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0752 - val_loss: 0.0402
# Epoch 20/300
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0741 - val_loss: 0.0410
# Epoch 21/300
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0730 - val_loss: 0.0415
# Epoch 22/300
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0720 - val_loss: 0.0417
# Epoch 23/300
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0710 - val_loss: 0.0414
# Epoch 24/300
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0700 - val_loss: 0.0407
# Epoch 25/300
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0690 - val_loss: 0.0397
# Epoch 26/300
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0680 - val_loss: 0.0383
# Epoch 27/300
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0669 - val_loss: 0.0367
# Epoch 28/300
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0659 - val_loss: 0.0348
# Epoch 29/300
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0648 - val_loss: 0.0328
# Epoch 30/300
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0637 - val_loss: 0.0306
# Epoch 31/300
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0626 - val_loss: 0.0283
# Epoch 32/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0615 - val_loss: 0.0261
# Epoch 33/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0604 - val_loss: 0.0238
# Epoch 34/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0592 - val_loss: 0.0216
# Epoch 35/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0581 - val_loss: 0.0194
# Epoch 36/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0571 - val_loss: 0.0174
# Epoch 37/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0560 - val_loss: 0.0155
# Epoch 38/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0550 - val_loss: 0.0137
# Epoch 39/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0539 - val_loss: 0.0121
# Epoch 40/300
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0529 - val_loss: 0.0106
# Epoch 41/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0519 - val_loss: 0.0094
# Epoch 42/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0509 - val_loss: 0.0082
# Epoch 43/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0498 - val_loss: 0.0072
# Epoch 44/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0487 - val_loss: 0.0063
# Epoch 45/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0476 - val_loss: 0.0056
# Epoch 46/300
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0464 - val_loss: 0.0049
# Epoch 47/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0452 - val_loss: 0.0044
# Epoch 48/300
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0440 - val_loss: 0.0039
# Epoch 49/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0428 - val_loss: 0.0035
# Epoch 50/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0416 - val_loss: 0.0031
# Epoch 51/300
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0404 - val_loss: 0.0027
# Epoch 52/300
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0392 - val_loss: 0.0023
# Epoch 53/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0380 - val_loss: 0.0020
# Epoch 54/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0369 - val_loss: 0.0016
# Epoch 55/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0357 - val_loss: 0.0013
# Epoch 56/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0346 - val_loss: 0.0011
# Epoch 57/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0335 - val_loss: 8.8656e-04
# Epoch 58/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0324 - val_loss: 7.4090e-04
# Epoch 59/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0313 - val_loss: 6.6995e-04
# Epoch 60/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0303 - val_loss: 6.9089e-04
# Epoch 61/300
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0293 - val_loss: 8.1986e-04
# Epoch 62/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0283 - val_loss: 0.0011
# Epoch 63/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0273 - val_loss: 0.0014
# Epoch 64/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0264 - val_loss: 0.0016
# Epoch 65/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0256 - val_loss: 0.0018
# Epoch 66/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0247 - val_loss: 0.0019
# Epoch 67/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0239 - val_loss: 0.0021
# Epoch 68/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0231 - val_loss: 0.0021
# Epoch 69/300
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0223 - val_loss: 0.0021
# Epoch 70/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0215 - val_loss: 0.0021
# Epoch 71/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0208 - val_loss: 0.0021
# Epoch 72/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0200 - val_loss: 0.0021
# Epoch 73/300
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0194 - val_loss: 0.0021
# Epoch 74/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0188 - val_loss: 0.0021
# Epoch 75/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0182 - val_loss: 0.0021
# Epoch 76/300
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0177 - val_loss: 0.0021
# Epoch 77/300
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0171 - val_loss: 0.0021
# Epoch 78/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0166 - val_loss: 0.0021
# Epoch 79/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0160 - val_loss: 0.0021
# Epoch 80/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0154 - val_loss: 0.0021
# Epoch 81/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0148 - val_loss: 0.0021
# Epoch 82/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0142 - val_loss: 0.0021
# Epoch 83/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0136 - val_loss: 0.0021
# Epoch 84/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0130 - val_loss: 0.0021
# Epoch 85/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0125 - val_loss: 0.0021
# Epoch 86/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0120 - val_loss: 0.0021
# Epoch 87/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0115 - val_loss: 0.0021
# Epoch 88/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0110 - val_loss: 0.0021
# Epoch 89/300
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0105 - val_loss: 0.0021
# Epoch 90/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0101 - val_loss: 0.0021
# Epoch 91/300
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0097 - val_loss: 0.0021
# Epoch 92/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0093 - val_loss: 0.0021
# Epoch 93/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0090 - val_loss: 0.0021
# Epoch 94/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0087 - val_loss: 0.0021
# Epoch 95/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0084 - val_loss: 0.0021
# Epoch 96/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0081 - val_loss: 0.0021
# Epoch 97/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0079 - val_loss: 0.0021
# Epoch 98/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0077 - val_loss: 0.0021
# Epoch 99/300
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0075 - val_loss: 0.0021
# Epoch 100/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0073 - val_loss: 0.0021
# Epoch 101/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0072 - val_loss: 0.0021
# Epoch 102/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0070 - val_loss: 0.0021
# Epoch 103/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0070 - val_loss: 0.0021
# Epoch 104/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0069 - val_loss: 0.0021
# Epoch 105/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0068 - val_loss: 0.0021
# Epoch 106/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0067 - val_loss: 0.0021
# Epoch 107/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0067 - val_loss: 0.0021
# Epoch 108/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0066 - val_loss: 0.0021
# Epoch 109/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0066 - val_loss: 0.0021
# Epoch 110/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0065 - val_loss: 0.0021
# Epoch 111/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0065 - val_loss: 0.0021
# Epoch 112/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0064 - val_loss: 0.0021
# Epoch 113/300
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0064 - val_loss: 0.0021
# Epoch 114/300
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0063 - val_loss: 0.0021
# Epoch 115/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0063 - val_loss: 0.0021
# Epoch 116/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0062 - val_loss: 0.0021
# Epoch 117/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0062 - val_loss: 0.0021
# Epoch 118/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0061 - val_loss: 0.0021
# Epoch 119/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0061 - val_loss: 0.0021
# Epoch 120/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0060 - val_loss: 0.0021
# Epoch 121/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0059 - val_loss: 0.0021
# Epoch 122/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0059 - val_loss: 0.0021
# Epoch 123/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 124/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 125/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0057 - val_loss: 0.0021
# Epoch 126/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0057 - val_loss: 0.0021
# Epoch 127/300
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0057 - val_loss: 0.0021
# Epoch 128/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0056 - val_loss: 0.0021
# Epoch 129/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0056 - val_loss: 0.0021
# Epoch 130/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0055 - val_loss: 0.0021
# Epoch 131/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0055 - val_loss: 0.0021
# Epoch 132/300
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0055 - val_loss: 0.0021
# Epoch 133/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0054 - val_loss: 0.0021
# Epoch 134/300
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0054 - val_loss: 0.0021
# Epoch 135/300
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0054 - val_loss: 0.0021
# Epoch 136/300
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0053 - val_loss: 0.0021
# Epoch 137/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0053 - val_loss: 0.0021
# Epoch 138/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0053 - val_loss: 0.0021
# Epoch 139/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0052 - val_loss: 0.0021
# Epoch 140/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0052 - val_loss: 0.0021
# Epoch 141/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0052 - val_loss: 0.0021
# Epoch 142/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0052 - val_loss: 0.0021
# Epoch 143/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0051 - val_loss: 0.0021
# Epoch 144/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0051 - val_loss: 0.0021
# Epoch 145/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0051 - val_loss: 0.0021
# Epoch 146/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0051 - val_loss: 0.0021
# Epoch 147/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0050 - val_loss: 0.0021
# Epoch 148/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0050 - val_loss: 0.0021
# Epoch 149/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0050 - val_loss: 0.0021
# Epoch 150/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0050 - val_loss: 0.0021
# Epoch 151/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0049 - val_loss: 0.0021
# Epoch 152/300
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0049 - val_loss: 0.0021
# Epoch 153/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0049 - val_loss: 0.0021
# Epoch 154/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0049 - val_loss: 0.0021
# Epoch 155/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0048 - val_loss: 0.0021
# Epoch 156/300
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0048 - val_loss: 0.0021
# Epoch 157/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0048 - val_loss: 0.0021
# Epoch 158/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0048 - val_loss: 0.0021
# Epoch 159/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0048 - val_loss: 0.0021
# Epoch 160/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0047 - val_loss: 0.0021
# Epoch 161/300
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0047 - val_loss: 0.0021
# Epoch 162/300
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0047 - val_loss: 0.0021
# Epoch 163/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0047 - val_loss: 0.0021
# Epoch 164/300
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0047 - val_loss: 0.0021
# Epoch 165/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0047 - val_loss: 0.0021
# Epoch 166/300
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0047 - val_loss: 0.0021
# Epoch 167/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0046 - val_loss: 0.0021
# Epoch 168/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0046 - val_loss: 0.0021
# Epoch 169/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0046 - val_loss: 0.0021
# Epoch 170/300
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0046 - val_loss: 0.0021
# Epoch 171/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0046 - val_loss: 0.0021
# Epoch 172/300
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0046 - val_loss: 0.0021
# Epoch 173/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0046 - val_loss: 0.0021
# Epoch 174/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0046 - val_loss: 0.0021
# Epoch 175/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 176/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 177/300
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 178/300
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 179/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 180/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 181/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 182/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 183/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 184/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 185/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 186/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 187/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 188/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 189/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 190/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 191/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 192/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 193/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 194/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 195/300
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 196/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 197/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 198/300
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 199/300
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 200/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 201/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 202/300
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 203/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 204/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 205/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 206/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 207/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 208/300
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 209/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 210/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 211/300
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 212/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 213/300
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 214/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 215/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 216/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 217/300
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 218/300
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 219/300
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 220/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 221/300
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 222/300
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 223/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 224/300
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 225/300
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 226/300
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 227/300
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 228/300
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 229/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 230/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 231/300
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 232/300
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 233/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 234/300
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 235/300
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 236/300
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 237/300
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 238/300
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 239/300
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 240/300
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 241/300
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 242/300
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 243/300
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 244/300
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 245/300
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 246/300
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 247/300
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 248/300
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 249/300
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 250/300
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 251/300
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 252/300
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 253/300
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 254/300
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 255/300
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 256/300
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 257/300
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 258/300
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 259/300
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 260/300
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 261/300
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 262/300
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 263/300
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 264/300
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 265/300
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 266/300
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 267/300
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 268/300
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 269/300
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 270/300
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 271/300
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 272/300
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 273/300
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 274/300
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 275/300
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 276/300
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 277/300
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 278/300
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 279/300
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 280/300
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 281/300
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 282/300
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 283/300
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 284/300
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 285/300
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 286/300
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 287/300
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 288/300
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 289/300
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 290/300
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 291/300
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 292/300
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 293/300
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 294/300
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 295/300
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 296/300
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 297/300
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 298/300
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 299/300
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 300/300
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0040 - val_loss: 0.0021
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 187ms/step
# Error Cuadrático Medio: 35645.520839428704
# Error Absoluto Medio: 162.43571550641738
# 1/1 [==============================] - 0s 25ms/step
# Predicciones para valores futuros de prod_pet: [385.28 385.28 385.28 385.28 385.28 385.28]

# %%
import math
import itertools
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import LSTM, Dense, Dropout
from keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
import tensorflow as tf
from hyperopt import hp, fmin, tpe, Trials

pd.set_option('display.max_columns', None)

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Load dataset
dataset = pd.read_csv("/content/drive/MyDrive/Trabajo profesional/Code/data/prod_clean_2024-05-13_17:08:31.csv", index_col=0)
dataset = dataset[dataset['anio'] >= 2014]

# Select relevant features
features = ['prod_pet', 'anio', 'mes', 'idpozo', 'prod_gas', 'prod_agua', 'tef', 'coordenadax', 'coordenaday', 'cota', 'pet_inicial', 'gas_inicial', 'agua_inicial']
data = dataset[features]

# Create a new 'date' column combining 'anio' and 'mes'
data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')

# Find the most recent date
last_date = data['date'].max()
print("La fecha más reciente es:", last_date)

# Conversion of 'date' to datetime type
data['date'] = pd.to_datetime(data['date'])

# Define a reference date
reference_date = pd.Timestamp('2014-01-01')

# Calculate 'date_numeric'
data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1

# Drop unnecessary columns
data.drop(['mes', 'anio'], axis=1, inplace=True)

# Filter data for one specific idpozo
filtered_data_one_id = data[data['idpozo'] == 162405]
filtered_data_one_id.drop(['idpozo'], axis=1, inplace=True)

# Scale the features and target variable
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'pet_inicial', 'gas_inicial', 'agua_inicial', 'date_numeric']]
y = filtered_data_one_id['prod_pet']

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Create sequences for LSTM
seq_length = 3

def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

X_sequences = create_sequences(X_scaled, seq_length)
y_adjusted = y_scaled[seq_length - 1:]

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)

# Define hyperparameter search space
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Objective function for hyperparameter tuning
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dropout(0.2),  # Added dropout for regularization
        Dense(1),
        Activation('relu')
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)
    combined_metric = 0.5 * mse + 0.5 * mae  # Combined metric
    return combined_metric

# Hyperparameter tuning using hyperopt
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=50, trials=trials)

# Retrieve the best hyperparameters
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Build the final model with the best hyperparameters
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dropout(0.2),  # Added dropout for regularization
    Dense(1),
    Activation('relu')
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

# Save the model
model.save('/content/drive/MyDrive/Trabajo profesional/Code/lstm_model.h5')

# Load the model
from keras.models import load_model
loaded_model = load_model('/content/drive/MyDrive/Trabajo profesional/Code/lstm_model.h5')

# Predict on the test set
y_pred_scaled = loaded_model.predict(X_test)
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculate error metrics
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Plot the predicted vs actual values
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.show()

# Predict "prod_pet" for future values of "date_numeric"
future_date_numeric_values = [123, 124, 125, 126, 127, 128]

# Create a DataFrame with future values and placeholders for other features
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'pet_inicial': [filtered_data_one_id['pet_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'gas_inicial': [filtered_data_one_id['gas_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'agua_inicial': [filtered_data_one_id['agua_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Scale the future data
scaled_future_data = scaler_X.transform(future_data)

# Create sequences for LSTM using the future scaled data
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Predict future values (scaled)
predictions_scaled = loaded_model.predict(future_sequences)

# Inverse scale to get the real predictions
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_pet:", predictions.flatten())
# Out:
# Mounted at /content/drive
# La fecha más reciente es: 2024-03-01 00:00:00
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# <ipython-input-13-fa11c4bb8919>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')
# <ipython-input-13-fa11c4bb8919>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['date'])
# <ipython-input-13-fa11c4bb8919>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1
# <ipython-input-13-fa11c4bb8919>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['mes', 'anio'], axis=1, inplace=True)
# <ipython-input-13-fa11c4bb8919>:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data_one_id.drop(['idpozo'], axis=1, inplace=True)
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 186ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 199ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 186ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 195ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 186ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 256ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 171ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 198ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 225ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 201ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 273ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 282ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 201ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 204ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 178ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 252ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 194ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 190ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 164ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 263ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 192ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 196ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 265ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 180ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 171ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 308ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 100%|██████████| 50/50 [12:48<00:00, 15.37s/trial, best loss: 2654.5065295833515]
# Mejor tamaño de lote: 16
# Mejor cantidad de épocas: 400
# Epoch 1/400
# 2/2 [==============================] - 2s 272ms/step - loss: 0.1328 - val_loss: 0.0011
# Epoch 2/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1146 - val_loss: 0.0043
# Epoch 3/400
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1084 - val_loss: 0.0100
# Epoch 4/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1047 - val_loss: 0.0173
# Epoch 5/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0937 - val_loss: 0.0243
# Epoch 6/400
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0897 - val_loss: 0.0300
# Epoch 7/400
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0872 - val_loss: 0.0346
# Epoch 8/400
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0836 - val_loss: 0.0372
# Epoch 9/400
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0873 - val_loss: 0.0391
# Epoch 10/400
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0785 - val_loss: 0.0399
# Epoch 11/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0740 - val_loss: 0.0393
# Epoch 12/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0810 - val_loss: 0.0375
# Epoch 13/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0681 - val_loss: 0.0341
# Epoch 14/400
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0657 - val_loss: 0.0305
# Epoch 15/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0702 - val_loss: 0.0263
# Epoch 16/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0654 - val_loss: 0.0229
# Epoch 17/400
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0627 - val_loss: 0.0190
# Epoch 18/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0602 - val_loss: 0.0160
# Epoch 19/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0620 - val_loss: 0.0134
# Epoch 20/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0580 - val_loss: 0.0107
# Epoch 21/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0532 - val_loss: 0.0088
# Epoch 22/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0534 - val_loss: 0.0074
# Epoch 23/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0514 - val_loss: 0.0062
# Epoch 24/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0521 - val_loss: 0.0052
# Epoch 25/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0490 - val_loss: 0.0041
# Epoch 26/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0457 - val_loss: 0.0033
# Epoch 27/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0430 - val_loss: 0.0024
# Epoch 28/400
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0387 - val_loss: 0.0016
# Epoch 29/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0390 - val_loss: 0.0011
# Epoch 30/400
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0411 - val_loss: 7.4638e-04
# Epoch 31/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0366 - val_loss: 6.6137e-04
# Epoch 32/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0317 - val_loss: 8.4277e-04
# Epoch 33/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0309 - val_loss: 0.0014
# Epoch 34/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0306 - val_loss: 0.0018
# Epoch 35/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0302 - val_loss: 0.0020
# Epoch 36/400
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0286 - val_loss: 0.0021
# Epoch 37/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0268 - val_loss: 0.0021
# Epoch 38/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0218 - val_loss: 0.0021
# Epoch 39/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0227 - val_loss: 0.0021
# Epoch 40/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0206 - val_loss: 0.0021
# Epoch 41/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0221 - val_loss: 0.0021
# Epoch 42/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0255 - val_loss: 0.0021
# Epoch 43/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0216 - val_loss: 0.0021
# Epoch 44/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0194 - val_loss: 0.0021
# Epoch 45/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0186 - val_loss: 0.0021
# Epoch 46/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0179 - val_loss: 0.0021
# Epoch 47/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0174 - val_loss: 0.0021
# Epoch 48/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0150 - val_loss: 0.0021
# Epoch 49/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0145 - val_loss: 0.0021
# Epoch 50/400
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0161 - val_loss: 0.0021
# Epoch 51/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0156 - val_loss: 0.0021
# Epoch 52/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0147 - val_loss: 0.0021
# Epoch 53/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0114 - val_loss: 0.0021
# Epoch 54/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0154 - val_loss: 0.0021
# Epoch 55/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0119 - val_loss: 0.0021
# Epoch 56/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0117 - val_loss: 0.0021
# Epoch 57/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0144 - val_loss: 0.0021
# Epoch 58/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0095 - val_loss: 0.0021
# Epoch 59/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0099 - val_loss: 0.0021
# Epoch 60/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0141 - val_loss: 0.0021
# Epoch 61/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0135 - val_loss: 0.0021
# Epoch 62/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0125 - val_loss: 0.0021
# Epoch 63/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0099 - val_loss: 0.0021
# Epoch 64/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0102 - val_loss: 0.0021
# Epoch 65/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0132 - val_loss: 0.0021
# Epoch 66/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0089 - val_loss: 0.0021
# Epoch 67/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0082 - val_loss: 0.0021
# Epoch 68/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0068 - val_loss: 0.0021
# Epoch 69/400
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0137 - val_loss: 0.0021
# Epoch 70/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0094 - val_loss: 0.0021
# Epoch 71/400
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0106 - val_loss: 0.0021
# Epoch 72/400
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0088 - val_loss: 0.0021
# Epoch 73/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0132 - val_loss: 0.0021
# Epoch 74/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0106 - val_loss: 0.0021
# Epoch 75/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0088 - val_loss: 0.0021
# Epoch 76/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0082 - val_loss: 0.0021
# Epoch 77/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0111 - val_loss: 0.0021
# Epoch 78/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0115 - val_loss: 0.0021
# Epoch 79/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0093 - val_loss: 0.0021
# Epoch 80/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0120 - val_loss: 0.0021
# Epoch 81/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0097 - val_loss: 0.0021
# Epoch 82/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 83/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0102 - val_loss: 0.0021
# Epoch 84/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0089 - val_loss: 0.0021
# Epoch 85/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0100 - val_loss: 0.0021
# Epoch 86/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0064 - val_loss: 0.0021
# Epoch 87/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0101 - val_loss: 0.0021
# Epoch 88/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0071 - val_loss: 0.0021
# Epoch 89/400
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0071 - val_loss: 0.0021
# Epoch 90/400
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0069 - val_loss: 0.0021
# Epoch 91/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0103 - val_loss: 0.0021
# Epoch 92/400
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0094 - val_loss: 0.0021
# Epoch 93/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0117 - val_loss: 0.0021
# Epoch 94/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0088 - val_loss: 0.0021
# Epoch 95/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0130 - val_loss: 0.0021
# Epoch 96/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0112 - val_loss: 0.0021
# Epoch 97/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0102 - val_loss: 0.0021
# Epoch 98/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0127 - val_loss: 0.0021
# Epoch 99/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0116 - val_loss: 0.0021
# Epoch 100/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0127 - val_loss: 0.0021
# Epoch 101/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0071 - val_loss: 0.0021
# Epoch 102/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0103 - val_loss: 0.0021
# Epoch 103/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0073 - val_loss: 0.0021
# Epoch 104/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0082 - val_loss: 0.0021
# Epoch 105/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0071 - val_loss: 0.0021
# Epoch 106/400
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0078 - val_loss: 0.0021
# Epoch 107/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0063 - val_loss: 0.0021
# Epoch 108/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0076 - val_loss: 0.0021
# Epoch 109/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0080 - val_loss: 0.0021
# Epoch 110/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0060 - val_loss: 0.0021
# Epoch 111/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0051 - val_loss: 0.0021
# Epoch 112/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0083 - val_loss: 0.0021
# Epoch 113/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0077 - val_loss: 0.0021
# Epoch 114/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0086 - val_loss: 0.0021
# Epoch 115/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0095 - val_loss: 0.0021
# Epoch 116/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0115 - val_loss: 0.0021
# Epoch 117/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0065 - val_loss: 0.0021
# Epoch 118/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0075 - val_loss: 0.0021
# Epoch 119/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0047 - val_loss: 0.0021
# Epoch 120/400
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0072 - val_loss: 0.0021
# Epoch 121/400
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0068 - val_loss: 0.0021
# Epoch 122/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0086 - val_loss: 0.0021
# Epoch 123/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0091 - val_loss: 0.0021
# Epoch 124/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0092 - val_loss: 0.0021
# Epoch 125/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0049 - val_loss: 0.0021
# Epoch 126/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0061 - val_loss: 0.0021
# Epoch 127/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0060 - val_loss: 0.0021
# Epoch 128/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0098 - val_loss: 0.0021
# Epoch 129/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0090 - val_loss: 0.0021
# Epoch 130/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0053 - val_loss: 0.0021
# Epoch 131/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0059 - val_loss: 0.0021
# Epoch 132/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0075 - val_loss: 0.0021
# Epoch 133/400
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0078 - val_loss: 0.0021
# Epoch 134/400
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 135/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0074 - val_loss: 0.0021
# Epoch 136/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0057 - val_loss: 0.0021
# Epoch 137/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0074 - val_loss: 0.0021
# Epoch 138/400
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0073 - val_loss: 0.0021
# Epoch 139/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0054 - val_loss: 0.0021
# Epoch 140/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 141/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0057 - val_loss: 0.0021
# Epoch 142/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0054 - val_loss: 0.0021
# Epoch 143/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0066 - val_loss: 0.0021
# Epoch 144/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0059 - val_loss: 0.0021
# Epoch 145/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0067 - val_loss: 0.0021
# Epoch 146/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0068 - val_loss: 0.0021
# Epoch 147/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 148/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0062 - val_loss: 0.0021
# Epoch 149/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0073 - val_loss: 0.0021
# Epoch 150/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0063 - val_loss: 0.0021
# Epoch 151/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0079 - val_loss: 0.0021
# Epoch 152/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0082 - val_loss: 0.0021
# Epoch 153/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0057 - val_loss: 0.0021
# Epoch 154/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0069 - val_loss: 0.0021
# Epoch 155/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 156/400
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0053 - val_loss: 0.0021
# Epoch 157/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 158/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 159/400
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 160/400
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0047 - val_loss: 0.0021
# Epoch 161/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0070 - val_loss: 0.0021
# Epoch 162/400
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0051 - val_loss: 0.0021
# Epoch 163/400
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0081 - val_loss: 0.0021
# Epoch 164/400
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0080 - val_loss: 0.0021
# Epoch 165/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0063 - val_loss: 0.0021
# Epoch 166/400
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0059 - val_loss: 0.0021
# Epoch 167/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0065 - val_loss: 0.0021
# Epoch 168/400
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0065 - val_loss: 0.0021
# Epoch 169/400
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0061 - val_loss: 0.0021
# Epoch 170/400
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0091 - val_loss: 0.0021
# Epoch 171/400
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 172/400
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0063 - val_loss: 0.0021
# Epoch 173/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0085 - val_loss: 0.0021
# Epoch 174/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0070 - val_loss: 0.0021
# Epoch 175/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0063 - val_loss: 0.0021
# Epoch 176/400
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0059 - val_loss: 0.0021
# Epoch 177/400
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 178/400
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0056 - val_loss: 0.0021
# Epoch 179/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0053 - val_loss: 0.0021
# Epoch 180/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0048 - val_loss: 0.0021
# Epoch 181/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0061 - val_loss: 0.0021
# Epoch 182/400
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0049 - val_loss: 0.0021
# Epoch 183/400
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 184/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0062 - val_loss: 0.0021
# Epoch 185/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0048 - val_loss: 0.0021
# Epoch 186/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0067 - val_loss: 0.0021
# Epoch 187/400
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 188/400
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0059 - val_loss: 0.0021
# Epoch 189/400
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0057 - val_loss: 0.0021
# Epoch 190/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0071 - val_loss: 0.0021
# Epoch 191/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0051 - val_loss: 0.0021
# Epoch 192/400
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0049 - val_loss: 0.0021
# Epoch 193/400
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0052 - val_loss: 0.0021
# Epoch 194/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0054 - val_loss: 0.0021
# Epoch 195/400
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0052 - val_loss: 0.0021
# Epoch 196/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 197/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0056 - val_loss: 0.0021
# Epoch 198/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 199/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 200/400
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0049 - val_loss: 0.0021
# Epoch 201/400
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0051 - val_loss: 0.0021
# Epoch 202/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0063 - val_loss: 0.0021
# Epoch 203/400
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0055 - val_loss: 0.0021
# Epoch 204/400
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0049 - val_loss: 0.0021
# Epoch 205/400
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0050 - val_loss: 0.0021
# Epoch 206/400
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0057 - val_loss: 0.0021
# Epoch 207/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 208/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0046 - val_loss: 0.0021
# Epoch 209/400
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0049 - val_loss: 0.0021
# Epoch 210/400
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0066 - val_loss: 0.0021
# Epoch 211/400
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0066 - val_loss: 0.0021
# Epoch 212/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0047 - val_loss: 0.0021
# Epoch 213/400
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0048 - val_loss: 0.0021
# Epoch 214/400
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0050 - val_loss: 0.0021
# Epoch 215/400
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 216/400
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0060 - val_loss: 0.0021
# Epoch 217/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 218/400
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 219/400
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 220/400
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0052 - val_loss: 0.0021
# Epoch 221/400
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 222/400
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0052 - val_loss: 0.0021
# Epoch 223/400
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0051 - val_loss: 0.0021
# Epoch 224/400
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0070 - val_loss: 0.0021
# Epoch 225/400
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0057 - val_loss: 0.0021
# Epoch 226/400
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0049 - val_loss: 0.0021
# Epoch 227/400
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0037 - val_loss: 0.0021
# Epoch 228/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0031 - val_loss: 0.0021
# Epoch 229/400
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0055 - val_loss: 0.0021
# Epoch 230/400
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0054 - val_loss: 0.0021
# Epoch 231/400
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0038 - val_loss: 0.0021
# Epoch 232/400
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 233/400
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0048 - val_loss: 0.0021
# Epoch 234/400
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0037 - val_loss: 0.0021
# Epoch 235/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0050 - val_loss: 0.0021
# Epoch 236/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0057 - val_loss: 0.0021
# Epoch 237/400
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0050 - val_loss: 0.0021
# Epoch 238/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0054 - val_loss: 0.0021
# Epoch 239/400
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 240/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 241/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0049 - val_loss: 0.0021
# Epoch 242/400
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0053 - val_loss: 0.0021
# Epoch 243/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0049 - val_loss: 0.0021
# Epoch 244/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 245/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 246/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0046 - val_loss: 0.0021
# Epoch 247/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0049 - val_loss: 0.0021
# Epoch 248/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0048 - val_loss: 0.0021
# Epoch 249/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 250/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0054 - val_loss: 0.0021
# Epoch 251/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0046 - val_loss: 0.0021
# Epoch 252/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0062 - val_loss: 0.0021
# Epoch 253/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0064 - val_loss: 0.0021
# Epoch 254/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 255/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 256/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0059 - val_loss: 0.0021
# Epoch 257/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 258/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 259/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 260/400
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0073 - val_loss: 0.0021
# Epoch 261/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0049 - val_loss: 0.0021
# Epoch 262/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0046 - val_loss: 0.0021
# Epoch 263/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0047 - val_loss: 0.0021
# Epoch 264/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0052 - val_loss: 0.0021
# Epoch 265/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 266/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0045 - val_loss: 0.0021
# Epoch 267/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0028 - val_loss: 0.0021
# Epoch 268/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 269/400
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0054 - val_loss: 0.0021
# Epoch 270/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0047 - val_loss: 0.0021
# Epoch 271/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 272/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0048 - val_loss: 0.0021
# Epoch 273/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0052 - val_loss: 0.0021
# Epoch 274/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 275/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 276/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0063 - val_loss: 0.0020
# Epoch 277/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 278/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 279/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0041 - val_loss: 0.0020
# Epoch 280/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0035 - val_loss: 0.0019
# Epoch 281/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 282/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0031 - val_loss: 0.0017
# Epoch 283/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0044 - val_loss: 0.0017
# Epoch 284/400
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0038 - val_loss: 0.0017
# Epoch 285/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0046 - val_loss: 0.0017
# Epoch 286/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0057 - val_loss: 0.0017
# Epoch 287/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 288/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 289/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 290/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 291/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0035 - val_loss: 0.0012
# Epoch 292/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 293/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 294/400
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 295/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0039 - val_loss: 0.0018
# Epoch 296/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 297/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0028 - val_loss: 0.0019
# Epoch 298/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 299/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 300/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0057 - val_loss: 0.0015
# Epoch 301/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0035 - val_loss: 0.0013
# Epoch 302/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0034 - val_loss: 0.0012
# Epoch 303/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0035 - val_loss: 0.0011
# Epoch 304/400
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0038 - val_loss: 9.8259e-04
# Epoch 305/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0044 - val_loss: 8.5037e-04
# Epoch 306/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0030 - val_loss: 7.6240e-04
# Epoch 307/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0030 - val_loss: 6.8354e-04
# Epoch 308/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0022 - val_loss: 6.0854e-04
# Epoch 309/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0035 - val_loss: 5.9416e-04
# Epoch 310/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0033 - val_loss: 5.9538e-04
# Epoch 311/400
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0027 - val_loss: 6.2664e-04
# Epoch 312/400
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0042 - val_loss: 6.8723e-04
# Epoch 313/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0034 - val_loss: 7.6253e-04
# Epoch 314/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0029 - val_loss: 8.1511e-04
# Epoch 315/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0041 - val_loss: 7.9758e-04
# Epoch 316/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0030 - val_loss: 7.1813e-04
# Epoch 317/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0044 - val_loss: 6.9474e-04
# Epoch 318/400
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0027 - val_loss: 6.8324e-04
# Epoch 319/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0036 - val_loss: 6.4604e-04
# Epoch 320/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0037 - val_loss: 6.4494e-04
# Epoch 321/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0037 - val_loss: 6.6527e-04
# Epoch 322/400
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0043 - val_loss: 7.0083e-04
# Epoch 323/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0035 - val_loss: 7.1890e-04
# Epoch 324/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0045 - val_loss: 7.0133e-04
# Epoch 325/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0019 - val_loss: 6.8045e-04
# Epoch 326/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0026 - val_loss: 6.7265e-04
# Epoch 327/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0038 - val_loss: 6.8115e-04
# Epoch 328/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0033 - val_loss: 6.6327e-04
# Epoch 329/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0037 - val_loss: 6.1178e-04
# Epoch 330/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0028 - val_loss: 5.7533e-04
# Epoch 331/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0029 - val_loss: 5.6843e-04
# Epoch 332/400
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0032 - val_loss: 5.7494e-04
# Epoch 333/400
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0037 - val_loss: 5.7038e-04
# Epoch 334/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0034 - val_loss: 5.8542e-04
# Epoch 335/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0033 - val_loss: 6.5586e-04
# Epoch 336/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0035 - val_loss: 7.8235e-04
# Epoch 337/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0019 - val_loss: 8.9701e-04
# Epoch 338/400
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0036 - val_loss: 9.6713e-04
# Epoch 339/400
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0042 - val_loss: 9.8571e-04
# Epoch 340/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0027 - val_loss: 8.4849e-04
# Epoch 341/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0037 - val_loss: 7.4674e-04
# Epoch 342/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0029 - val_loss: 6.7254e-04
# Epoch 343/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0024 - val_loss: 6.3398e-04
# Epoch 344/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0035 - val_loss: 6.2259e-04
# Epoch 345/400
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0048 - val_loss: 6.5438e-04
# Epoch 346/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0052 - val_loss: 7.3051e-04
# Epoch 347/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0028 - val_loss: 7.8371e-04
# Epoch 348/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0035 - val_loss: 7.5590e-04
# Epoch 349/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0026 - val_loss: 6.8192e-04
# Epoch 350/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0033 - val_loss: 6.1583e-04
# Epoch 351/400
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0028 - val_loss: 5.7735e-04
# Epoch 352/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0026 - val_loss: 5.7113e-04
# Epoch 353/400
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0025 - val_loss: 5.7053e-04
# Epoch 354/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0023 - val_loss: 5.7112e-04
# Epoch 355/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0019 - val_loss: 5.7200e-04
# Epoch 356/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0034 - val_loss: 5.7458e-04
# Epoch 357/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0022 - val_loss: 5.7707e-04
# Epoch 358/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0022 - val_loss: 5.8254e-04
# Epoch 359/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0022 - val_loss: 5.8361e-04
# Epoch 360/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0021 - val_loss: 5.8690e-04
# Epoch 361/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0034 - val_loss: 5.8508e-04
# Epoch 362/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0037 - val_loss: 5.8767e-04
# Epoch 363/400
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0018 - val_loss: 5.8634e-04
# Epoch 364/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0021 - val_loss: 5.8549e-04
# Epoch 365/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0013 - val_loss: 5.8140e-04
# Epoch 366/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0022 - val_loss: 5.7976e-04
# Epoch 367/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0022 - val_loss: 5.8287e-04
# Epoch 368/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0034 - val_loss: 5.7802e-04
# Epoch 369/400
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0026 - val_loss: 5.7598e-04
# Epoch 370/400
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0023 - val_loss: 5.7954e-04
# Epoch 371/400
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0022 - val_loss: 5.8640e-04
# Epoch 372/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0020 - val_loss: 5.9381e-04
# Epoch 373/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0024 - val_loss: 5.9038e-04
# Epoch 374/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0024 - val_loss: 5.4555e-04
# Epoch 375/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0027 - val_loss: 4.9008e-04
# Epoch 376/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0024 - val_loss: 4.6433e-04
# Epoch 377/400
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0017 - val_loss: 4.6296e-04
# Epoch 378/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0020 - val_loss: 4.6159e-04
# Epoch 379/400
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0037 - val_loss: 4.6032e-04
# Epoch 380/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0026 - val_loss: 4.7741e-04
# Epoch 381/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0034 - val_loss: 5.0221e-04
# Epoch 382/400
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0027 - val_loss: 5.2357e-04
# Epoch 383/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0033 - val_loss: 4.9568e-04
# Epoch 384/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0031 - val_loss: 4.6449e-04
# Epoch 385/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0037 - val_loss: 4.4648e-04
# Epoch 386/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0052 - val_loss: 4.4806e-04
# Epoch 387/400
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0031 - val_loss: 4.4678e-04
# Epoch 388/400
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0027 - val_loss: 4.4741e-04
# Epoch 389/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0034 - val_loss: 4.5434e-04
# Epoch 390/400
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0017 - val_loss: 4.6926e-04
# Epoch 391/400
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0022 - val_loss: 4.7276e-04
# Epoch 392/400
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0024 - val_loss: 5.0568e-04
# Epoch 393/400
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0032 - val_loss: 5.3066e-04
# Epoch 394/400
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0024 - val_loss: 5.0727e-04
# Epoch 395/400
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0024 - val_loss: 4.5049e-04
# Epoch 396/400
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0018 - val_loss: 3.9170e-04
# Epoch 397/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0036 - val_loss: 3.8865e-04
# Epoch 398/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0027 - val_loss: 4.3049e-04
# Epoch 399/400
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0031 - val_loss: 4.6358e-04
# Epoch 400/400
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0029 - val_loss: 4.3493e-04
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 163ms/step
# Error Cuadrático Medio: 7462.873262831615
# Error Absoluto Medio: 72.29147827148438
# 1/1 [==============================] - 0s 20ms/step
# Predicciones para valores futuros de prod_pet: [555.08405 603.9045  599.1282  592.04    585.53375 579.4218 ]
