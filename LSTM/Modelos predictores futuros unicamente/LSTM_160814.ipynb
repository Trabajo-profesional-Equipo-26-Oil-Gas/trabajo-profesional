# %% [markdown]
# #Partiendo de la limpieza de datos realizada previamente, se utiliza LSTM para predecir la producción de pozos de petroleo.
#
# ###Pozos a predecir:
# 158364, 160211, 160332, 160789, 160810, 160814, 161451, 162200, 162405, 162955, 163237, 163942

# %%
import math
import itertools
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import LSTM, Dense
from keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
pd.set_option('display.max_columns', None)

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

#dataset = pd.read_csv("/content/drive/MyDrive/Trabajo profesional/Code/data/prod_norm_2024-05-27_03:42:59.csv", index_col=0)
dataset = pd.read_csv("/content/drive/MyDrive/Trabajo profesional/Code/data/prod_clean_2024-05-13_17:08:31.csv", index_col=0)

dataset = dataset[dataset['anio'] >= 2014]

# Seleccionar características relevantes
features = ['prod_pet', 'anio', 'mes', 'idpozo', 'prod_gas', 'prod_agua', 'tef', 'coordenadax', 'coordenaday', 'cota', 'pet_inicial', 'gas_inicial', 'agua_inicial']

# Filtrar características
data = dataset[features]

# Creacion de una nueva columna 'date' combinando 'anio' y 'mes' para representar la fecha
data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')

data.drop(['mes', 'anio'], axis=1, inplace=True)

# Conversion de la columna 'date' a "datetime type"
data['date'] = pd.to_datetime(data['date'])

# Definicion de un dia de referencia inicial (Es la primera fecha desde la que se filtro previamente).
reference_date = pd.Timestamp('2014-01-01')

# Calculo del numero de meses desde la referencia para cada date.
data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1

data.drop(['date'], axis=1, inplace=True)

filtered_data_one_id = data[data['idpozo'] == 160814]

filtered_data_one_id.drop(['idpozo'], axis=1, inplace=True)
# Out:
# Mounted at /content/drive
# <ipython-input-2-4370a12592ee>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')
# <ipython-input-2-4370a12592ee>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['mes', 'anio'], axis=1, inplace=True)
# <ipython-input-2-4370a12592ee>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['date'])
# <ipython-input-2-4370a12592ee>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1
# <ipython-input-2-4370a12592ee>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['date'], axis=1, inplace=True)
# <ipython-input-2-4370a12592ee>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data_one_id.drop(['idpozo'], axis=1, inplace=True)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'pet_inicial', 'gas_inicial', 'agua_inicial', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_pet']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)

# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, el error cuadrático medio)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    return mse

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=10, trials=trials)

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

model.save("/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/best_lstm_model_160814.h5")

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.show()

# Predecir "prod_pet" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'pet_inicial': [filtered_data_one_id['pet_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'gas_inicial': [filtered_data_one_id['gas_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'agua_inicial': [filtered_data_one_id['agua_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_pet:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 307ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 238ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 249ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 186ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 100%|██████████| 10/10 [02:59<00:00, 17.91s/trial, best loss: 1191.1032610186887]
# Mejor tamaño de lote: 32
# Mejor cantidad de épocas: 200
# Epoch 1/200
# 2/2 [==============================] - 2s 279ms/step - loss: 0.2209 - val_loss: 0.0161
# Epoch 2/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2017 - val_loss: 0.0095
# Epoch 3/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1808 - val_loss: 0.0048
# Epoch 4/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1609 - val_loss: 0.0021
# Epoch 5/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1438 - val_loss: 0.0014
# Epoch 6/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1272 - val_loss: 0.0026
# Epoch 7/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1128 - val_loss: 0.0059
# Epoch 8/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0994 - val_loss: 0.0113
# Epoch 9/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0895 - val_loss: 0.0188
# Epoch 10/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0800 - val_loss: 0.0280
# Epoch 11/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0719 - val_loss: 0.0387
# Epoch 12/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0661 - val_loss: 0.0510
# Epoch 13/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0620 - val_loss: 0.0635
# Epoch 14/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0588 - val_loss: 0.0750
# Epoch 15/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0570 - val_loss: 0.0844
# Epoch 16/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0558 - val_loss: 0.0913
# Epoch 17/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0551 - val_loss: 0.0956
# Epoch 18/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0546 - val_loss: 0.0972
# Epoch 19/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0539 - val_loss: 0.0967
# Epoch 20/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0532 - val_loss: 0.0939
# Epoch 21/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0523 - val_loss: 0.0888
# Epoch 22/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0510 - val_loss: 0.0829
# Epoch 23/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0498 - val_loss: 0.0760
# Epoch 24/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0483 - val_loss: 0.0694
# Epoch 25/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0471 - val_loss: 0.0623
# Epoch 26/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0460 - val_loss: 0.0554
# Epoch 27/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0450 - val_loss: 0.0500
# Epoch 28/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0441 - val_loss: 0.0460
# Epoch 29/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0431 - val_loss: 0.0427
# Epoch 30/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0421 - val_loss: 0.0395
# Epoch 31/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0411 - val_loss: 0.0370
# Epoch 32/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0401 - val_loss: 0.0351
# Epoch 33/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0389 - val_loss: 0.0334
# Epoch 34/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0378 - val_loss: 0.0318
# Epoch 35/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0367 - val_loss: 0.0303
# Epoch 36/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0356 - val_loss: 0.0285
# Epoch 37/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0345 - val_loss: 0.0266
# Epoch 38/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0332 - val_loss: 0.0244
# Epoch 39/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0322 - val_loss: 0.0223
# Epoch 40/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0311 - val_loss: 0.0198
# Epoch 41/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0299 - val_loss: 0.0174
# Epoch 42/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0289 - val_loss: 0.0153
# Epoch 43/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0279 - val_loss: 0.0133
# Epoch 44/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0269 - val_loss: 0.0117
# Epoch 45/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0260 - val_loss: 0.0102
# Epoch 46/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0249 - val_loss: 0.0090
# Epoch 47/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0239 - val_loss: 0.0083
# Epoch 48/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0231 - val_loss: 0.0073
# Epoch 49/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0220 - val_loss: 0.0062
# Epoch 50/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0211 - val_loss: 0.0053
# Epoch 51/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0203 - val_loss: 0.0044
# Epoch 52/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0194 - val_loss: 0.0036
# Epoch 53/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0187 - val_loss: 0.0029
# Epoch 54/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0179 - val_loss: 0.0022
# Epoch 55/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0173 - val_loss: 0.0017
# Epoch 56/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0166 - val_loss: 0.0012
# Epoch 57/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0160 - val_loss: 9.3313e-04
# Epoch 58/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0156 - val_loss: 8.9032e-04
# Epoch 59/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0153 - val_loss: 0.0010
# Epoch 60/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0151 - val_loss: 0.0012
# Epoch 61/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0147 - val_loss: 0.0014
# Epoch 62/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0144 - val_loss: 0.0016
# Epoch 63/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0143 - val_loss: 0.0017
# Epoch 64/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0138 - val_loss: 0.0018
# Epoch 65/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0136 - val_loss: 0.0018
# Epoch 66/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0136 - val_loss: 0.0020
# Epoch 67/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0135 - val_loss: 0.0023
# Epoch 68/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0134 - val_loss: 0.0026
# Epoch 69/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0133 - val_loss: 0.0029
# Epoch 70/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0132 - val_loss: 0.0033
# Epoch 71/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0132 - val_loss: 0.0034
# Epoch 72/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0132 - val_loss: 0.0032
# Epoch 73/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0131 - val_loss: 0.0030
# Epoch 74/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0131 - val_loss: 0.0026
# Epoch 75/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0129 - val_loss: 0.0024
# Epoch 76/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0127 - val_loss: 0.0020
# Epoch 77/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0129 - val_loss: 0.0018
# Epoch 78/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0128 - val_loss: 0.0019
# Epoch 79/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0126 - val_loss: 0.0022
# Epoch 80/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0124 - val_loss: 0.0025
# Epoch 81/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0127 - val_loss: 0.0028
# Epoch 82/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0131 - val_loss: 0.0027
# Epoch 83/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0132 - val_loss: 0.0024
# Epoch 84/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0129 - val_loss: 0.0019
# Epoch 85/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0123 - val_loss: 0.0013
# Epoch 86/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0120 - val_loss: 9.8766e-04
# Epoch 87/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0124 - val_loss: 8.9438e-04
# Epoch 88/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0125 - val_loss: 9.0004e-04
# Epoch 89/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0123 - val_loss: 9.5435e-04
# Epoch 90/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0119 - val_loss: 0.0011
# Epoch 91/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0117 - val_loss: 0.0013
# Epoch 92/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0115 - val_loss: 0.0013
# Epoch 93/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0114 - val_loss: 0.0013
# Epoch 94/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0113 - val_loss: 0.0013
# Epoch 95/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0113 - val_loss: 0.0012
# Epoch 96/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0111 - val_loss: 0.0011
# Epoch 97/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0110 - val_loss: 0.0010
# Epoch 98/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0109 - val_loss: 0.0010
# Epoch 99/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0108 - val_loss: 0.0010
# Epoch 100/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0107 - val_loss: 0.0010
# Epoch 101/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0105 - val_loss: 0.0011
# Epoch 102/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0104 - val_loss: 0.0012
# Epoch 103/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0103 - val_loss: 0.0012
# Epoch 104/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0102 - val_loss: 0.0012
# Epoch 105/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0100 - val_loss: 0.0011
# Epoch 106/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0098 - val_loss: 0.0010
# Epoch 107/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0097 - val_loss: 9.8839e-04
# Epoch 108/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0096 - val_loss: 9.6689e-04
# Epoch 109/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0095 - val_loss: 9.9633e-04
# Epoch 110/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0094 - val_loss: 0.0011
# Epoch 111/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0093 - val_loss: 0.0011
# Epoch 112/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0092 - val_loss: 0.0011
# Epoch 113/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0092 - val_loss: 0.0011
# Epoch 114/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0091 - val_loss: 0.0011
# Epoch 115/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0090 - val_loss: 0.0012
# Epoch 116/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0090 - val_loss: 0.0012
# Epoch 117/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0088 - val_loss: 0.0013
# Epoch 118/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0088 - val_loss: 0.0013
# Epoch 119/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0086 - val_loss: 0.0012
# Epoch 120/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0085 - val_loss: 0.0011
# Epoch 121/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0084 - val_loss: 0.0011
# Epoch 122/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0083 - val_loss: 0.0012
# Epoch 123/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0082 - val_loss: 0.0014
# Epoch 124/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0081 - val_loss: 0.0016
# Epoch 125/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0081 - val_loss: 0.0017
# Epoch 126/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0082 - val_loss: 0.0016
# Epoch 127/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0080 - val_loss: 0.0013
# Epoch 128/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0078 - val_loss: 0.0011
# Epoch 129/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0077 - val_loss: 9.8442e-04
# Epoch 130/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0077 - val_loss: 9.6291e-04
# Epoch 131/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0077 - val_loss: 9.6163e-04
# Epoch 132/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0075 - val_loss: 9.0699e-04
# Epoch 133/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0074 - val_loss: 8.8662e-04
# Epoch 134/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0074 - val_loss: 8.9918e-04
# Epoch 135/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0073 - val_loss: 9.7421e-04
# Epoch 136/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0072 - val_loss: 0.0011
# Epoch 137/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0071 - val_loss: 0.0011
# Epoch 138/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0071 - val_loss: 0.0012
# Epoch 139/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0073 - val_loss: 0.0011
# Epoch 140/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0071 - val_loss: 9.1922e-04
# Epoch 141/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0068 - val_loss: 7.9524e-04
# Epoch 142/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0069 - val_loss: 7.5542e-04
# Epoch 143/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0070 - val_loss: 7.5364e-04
# Epoch 144/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0069 - val_loss: 7.6964e-04
# Epoch 145/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0066 - val_loss: 8.4686e-04
# Epoch 146/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0066 - val_loss: 9.7617e-04
# Epoch 147/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0068 - val_loss: 9.7715e-04
# Epoch 148/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0067 - val_loss: 8.5456e-04
# Epoch 149/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0064 - val_loss: 7.4916e-04
# Epoch 150/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0063 - val_loss: 7.9513e-04
# Epoch 151/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0071 - val_loss: 8.6977e-04
# Epoch 152/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0073 - val_loss: 8.0868e-04
# Epoch 153/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0069 - val_loss: 7.5153e-04
# Epoch 154/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0064 - val_loss: 7.6034e-04
# Epoch 155/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0062 - val_loss: 8.6380e-04
# Epoch 156/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0061 - val_loss: 9.3320e-04
# Epoch 157/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0061 - val_loss: 9.1678e-04
# Epoch 158/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0060 - val_loss: 8.2324e-04
# Epoch 159/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0061 - val_loss: 7.6374e-04
# Epoch 160/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0060 - val_loss: 7.6528e-04
# Epoch 161/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0060 - val_loss: 7.9089e-04
# Epoch 162/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0058 - val_loss: 8.1551e-04
# Epoch 163/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0058 - val_loss: 8.3132e-04
# Epoch 164/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0058 - val_loss: 8.0758e-04
# Epoch 165/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0058 - val_loss: 7.7553e-04
# Epoch 166/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0057 - val_loss: 7.5293e-04
# Epoch 167/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0057 - val_loss: 7.3988e-04
# Epoch 168/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0056 - val_loss: 7.4519e-04
# Epoch 169/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0056 - val_loss: 7.7029e-04
# Epoch 170/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0059 - val_loss: 7.9644e-04
# Epoch 171/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0062 - val_loss: 7.6219e-04
# Epoch 172/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0058 - val_loss: 7.4031e-04
# Epoch 173/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0055 - val_loss: 7.8720e-04
# Epoch 174/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0056 - val_loss: 8.3337e-04
# Epoch 175/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0061 - val_loss: 8.1434e-04
# Epoch 176/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0060 - val_loss: 7.4667e-04
# Epoch 177/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0056 - val_loss: 7.6417e-04
# Epoch 178/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0053 - val_loss: 8.6190e-04
# Epoch 179/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0056 - val_loss: 9.7240e-04
# Epoch 180/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0056 - val_loss: 9.3780e-04
# Epoch 181/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0055 - val_loss: 8.3645e-04
# Epoch 182/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0053 - val_loss: 7.7245e-04
# Epoch 183/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0053 - val_loss: 7.4601e-04
# Epoch 184/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0054 - val_loss: 7.5379e-04
# Epoch 185/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0056 - val_loss: 7.5007e-04
# Epoch 186/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0057 - val_loss: 7.5472e-04
# Epoch 187/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0055 - val_loss: 7.8886e-04
# Epoch 188/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0054 - val_loss: 8.6703e-04
# Epoch 189/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0054 - val_loss: 9.3383e-04
# Epoch 190/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0052 - val_loss: 9.2296e-04
# Epoch 191/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0052 - val_loss: 8.7069e-04
# Epoch 192/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0052 - val_loss: 8.4511e-04
# Epoch 193/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0053 - val_loss: 8.3560e-04
# Epoch 194/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0052 - val_loss: 8.1977e-04
# Epoch 195/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0052 - val_loss: 8.2815e-04
# Epoch 196/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0052 - val_loss: 8.8545e-04
# Epoch 197/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0052 - val_loss: 9.7650e-04
# Epoch 198/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0051 - val_loss: 0.0010
# Epoch 199/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0051 - val_loss: 0.0010
# Epoch 200/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0051 - val_loss: 9.4051e-04
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 1s 971ms/step
# Error Cuadrático Medio: 1527.0724993135418
# Error Absoluto Medio: 29.928331975763502
# 1/1 [==============================] - 0s 22ms/step
# Predicciones para valores futuros de prod_pet: [147.31612 132.1879  130.72458 128.35304 125.97787 123.59899]

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials
import tensorflow as tf

# Establecer una semilla aleatoria para reproducibilidad
np.random.seed(42)
tf.random.set_seed(42)

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_pet']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)

# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, la combinación de MSE y MAE)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)

    # Calcular el MSE y MAE
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

    # Combinar MSE y MAE en una única métrica
    combined_metric = 0.5 * mse + 0.5 * mae
    return combined_metric

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=50, trials=trials)  # Aumentar max_evals

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

model.save("/content/drive/MyDrive/Trabajo profesional/Code/LSTM/Modelos/best_lstm_model_mse_mae_160814.h5")

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.show()

# Predecir "prod_pet" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_pet:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 193ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 255ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 166ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 210ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 178ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 240ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 191ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 238ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 164ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 166ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 179ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 188ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 165ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 253ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 173ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 250ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 167ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 256ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 160ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 170ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 201ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 196ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 178ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 255ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 246ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 192ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 164ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 233ms/step
#
# 100%|██████████| 50/50 [12:59<00:00, 15.60s/trial, best loss: 367.6815138826949]
# Mejor tamaño de lote: 16
# Mejor cantidad de épocas: 400
# Epoch 1/400
# 3/3 [==============================] - 2s 214ms/step - loss: 0.1815 - val_loss: 0.0018
# Epoch 2/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1596 - val_loss: 0.0035
# Epoch 3/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1400 - val_loss: 0.0088
# Epoch 4/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1222 - val_loss: 0.0183
# Epoch 5/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1053 - val_loss: 0.0325
# Epoch 6/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0913 - val_loss: 0.0515
# Epoch 7/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0807 - val_loss: 0.0751
# Epoch 8/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0748 - val_loss: 0.1013
# Epoch 9/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0700 - val_loss: 0.1243
# Epoch 10/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0683 - val_loss: 0.1404
# Epoch 11/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0670 - val_loss: 0.1451
# Epoch 12/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0660 - val_loss: 0.1404
# Epoch 13/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0641 - val_loss: 0.1296
# Epoch 14/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0618 - val_loss: 0.1163
# Epoch 15/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0593 - val_loss: 0.1020
# Epoch 16/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0576 - val_loss: 0.0894
# Epoch 17/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0557 - val_loss: 0.0803
# Epoch 18/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0541 - val_loss: 0.0740
# Epoch 19/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0524 - val_loss: 0.0690
# Epoch 20/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0510 - val_loss: 0.0665
# Epoch 21/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0491 - val_loss: 0.0636
# Epoch 22/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0470 - val_loss: 0.0598
# Epoch 23/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0449 - val_loss: 0.0540
# Epoch 24/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0429 - val_loss: 0.0491
# Epoch 25/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0411 - val_loss: 0.0451
# Epoch 26/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0391 - val_loss: 0.0407
# Epoch 27/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0373 - val_loss: 0.0377
# Epoch 28/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0355 - val_loss: 0.0342
# Epoch 29/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0331 - val_loss: 0.0285
# Epoch 30/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0310 - val_loss: 0.0225
# Epoch 31/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0290 - val_loss: 0.0180
# Epoch 32/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0271 - val_loss: 0.0158
# Epoch 33/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0254 - val_loss: 0.0130
# Epoch 34/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0237 - val_loss: 0.0103
# Epoch 35/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0217 - val_loss: 0.0071
# Epoch 36/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0203 - val_loss: 0.0049
# Epoch 37/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0189 - val_loss: 0.0032
# Epoch 38/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0178 - val_loss: 0.0023
# Epoch 39/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0166 - val_loss: 0.0016
# Epoch 40/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0157 - val_loss: 0.0010
# Epoch 41/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0149 - val_loss: 7.5385e-04
# Epoch 42/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0142 - val_loss: 8.5040e-04
# Epoch 43/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0138 - val_loss: 0.0011
# Epoch 44/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0137 - val_loss: 0.0016
# Epoch 45/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0135 - val_loss: 0.0024
# Epoch 46/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0133 - val_loss: 0.0032
# Epoch 47/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0132 - val_loss: 0.0034
# Epoch 48/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0132 - val_loss: 0.0031
# Epoch 49/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0132 - val_loss: 0.0029
# Epoch 50/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0130 - val_loss: 0.0032
# Epoch 51/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0129 - val_loss: 0.0030
# Epoch 52/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0128 - val_loss: 0.0029
# Epoch 53/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0128 - val_loss: 0.0023
# Epoch 54/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0127 - val_loss: 0.0020
# Epoch 55/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0124 - val_loss: 0.0015
# Epoch 56/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0124 - val_loss: 0.0011
# Epoch 57/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0124 - val_loss: 9.8300e-04
# Epoch 58/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0123 - val_loss: 9.7006e-04
# Epoch 59/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0122 - val_loss: 0.0010
# Epoch 60/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0120 - val_loss: 0.0012
# Epoch 61/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0120 - val_loss: 0.0013
# Epoch 62/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0120 - val_loss: 0.0012
# Epoch 63/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0120 - val_loss: 9.4941e-04
# Epoch 64/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0119 - val_loss: 8.0087e-04
# Epoch 65/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0117 - val_loss: 8.1529e-04
# Epoch 66/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0117 - val_loss: 8.3616e-04
# Epoch 67/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0115 - val_loss: 7.7600e-04
# Epoch 68/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0116 - val_loss: 7.5561e-04
# Epoch 69/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0113 - val_loss: 6.9765e-04
# Epoch 70/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0116 - val_loss: 6.8775e-04
# Epoch 71/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0115 - val_loss: 7.1749e-04
# Epoch 72/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0112 - val_loss: 8.0695e-04
# Epoch 73/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0110 - val_loss: 8.3878e-04
# Epoch 74/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0111 - val_loss: 8.8030e-04
# Epoch 75/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0109 - val_loss: 7.3247e-04
# Epoch 76/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0109 - val_loss: 6.8716e-04
# Epoch 77/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0108 - val_loss: 7.2992e-04
# Epoch 78/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0106 - val_loss: 8.5034e-04
# Epoch 79/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0109 - val_loss: 0.0010
# Epoch 80/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0104 - val_loss: 8.1551e-04
# Epoch 81/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0102 - val_loss: 7.1641e-04
# Epoch 82/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0101 - val_loss: 7.0567e-04
# Epoch 83/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0100 - val_loss: 7.2215e-04
# Epoch 84/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0098 - val_loss: 7.1298e-04
# Epoch 85/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0097 - val_loss: 7.1930e-04
# Epoch 86/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0097 - val_loss: 6.8322e-04
# Epoch 87/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0096 - val_loss: 6.5628e-04
# Epoch 88/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0094 - val_loss: 6.5499e-04
# Epoch 89/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0094 - val_loss: 6.5673e-04
# Epoch 90/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0093 - val_loss: 6.5335e-04
# Epoch 91/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0091 - val_loss: 6.7878e-04
# Epoch 92/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0090 - val_loss: 7.1786e-04
# Epoch 93/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0091 - val_loss: 7.0030e-04
# Epoch 94/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0091 - val_loss: 6.4917e-04
# Epoch 95/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0088 - val_loss: 6.4466e-04
# Epoch 96/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0087 - val_loss: 6.4428e-04
# Epoch 97/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0086 - val_loss: 6.4609e-04
# Epoch 98/400
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0086 - val_loss: 6.6368e-04
# Epoch 99/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0085 - val_loss: 6.9437e-04
# Epoch 100/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0085 - val_loss: 7.3210e-04
# Epoch 101/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0084 - val_loss: 7.8475e-04
# Epoch 102/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0084 - val_loss: 8.0513e-04
# Epoch 103/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0083 - val_loss: 7.2458e-04
# Epoch 104/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0081 - val_loss: 7.4387e-04
# Epoch 105/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0080 - val_loss: 7.9079e-04
# Epoch 106/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0080 - val_loss: 8.0290e-04
# Epoch 107/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0081 - val_loss: 7.4650e-04
# Epoch 108/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0079 - val_loss: 6.5036e-04
# Epoch 109/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0078 - val_loss: 6.2877e-04
# Epoch 110/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0078 - val_loss: 6.5165e-04
# Epoch 111/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0079 - val_loss: 6.3478e-04
# Epoch 112/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0077 - val_loss: 6.4439e-04
# Epoch 113/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0076 - val_loss: 6.5445e-04
# Epoch 114/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0075 - val_loss: 6.5628e-04
# Epoch 115/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0075 - val_loss: 6.3894e-04
# Epoch 116/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0074 - val_loss: 6.2026e-04
# Epoch 117/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0073 - val_loss: 6.1932e-04
# Epoch 118/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0073 - val_loss: 6.1864e-04
# Epoch 119/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0072 - val_loss: 6.1933e-04
# Epoch 120/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0072 - val_loss: 6.2321e-04
# Epoch 121/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0071 - val_loss: 6.1705e-04
# Epoch 122/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0070 - val_loss: 6.1717e-04
# Epoch 123/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0072 - val_loss: 6.2690e-04
# Epoch 124/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0072 - val_loss: 6.3445e-04
# Epoch 125/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0070 - val_loss: 6.5797e-04
# Epoch 126/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0069 - val_loss: 6.7400e-04
# Epoch 127/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0069 - val_loss: 6.3261e-04
# Epoch 128/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0068 - val_loss: 6.2057e-04
# Epoch 129/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0067 - val_loss: 7.4975e-04
# Epoch 130/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0068 - val_loss: 7.4469e-04
# Epoch 131/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0067 - val_loss: 6.3139e-04
# Epoch 132/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0066 - val_loss: 6.1967e-04
# Epoch 133/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0066 - val_loss: 6.3789e-04
# Epoch 134/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0065 - val_loss: 7.2260e-04
# Epoch 135/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0065 - val_loss: 8.2758e-04
# Epoch 136/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0067 - val_loss: 7.2927e-04
# Epoch 137/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0064 - val_loss: 6.0987e-04
# Epoch 138/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0067 - val_loss: 6.3568e-04
# Epoch 139/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0065 - val_loss: 6.2049e-04
# Epoch 140/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0065 - val_loss: 8.2351e-04
# Epoch 141/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0064 - val_loss: 8.4830e-04
# Epoch 142/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0064 - val_loss: 7.5191e-04
# Epoch 143/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0062 - val_loss: 7.2596e-04
# Epoch 144/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0062 - val_loss: 6.4036e-04
# Epoch 145/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0062 - val_loss: 6.3584e-04
# Epoch 146/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0062 - val_loss: 6.6120e-04
# Epoch 147/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0061 - val_loss: 7.5255e-04
# Epoch 148/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0060 - val_loss: 7.9969e-04
# Epoch 149/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0061 - val_loss: 9.8487e-04
# Epoch 150/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0062 - val_loss: 8.5437e-04
# Epoch 151/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0059 - val_loss: 8.3034e-04
# Epoch 152/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0059 - val_loss: 8.0463e-04
# Epoch 153/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0060 - val_loss: 8.0984e-04
# Epoch 154/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0059 - val_loss: 6.9609e-04
# Epoch 155/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0058 - val_loss: 6.6703e-04
# Epoch 156/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0059 - val_loss: 6.5117e-04
# Epoch 157/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0058 - val_loss: 7.0823e-04
# Epoch 158/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0059 - val_loss: 8.5813e-04
# Epoch 159/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0058 - val_loss: 8.0574e-04
# Epoch 160/400
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0058 - val_loss: 6.5357e-04
# Epoch 161/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0058 - val_loss: 6.6110e-04
# Epoch 162/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0057 - val_loss: 7.0647e-04
# Epoch 163/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0057 - val_loss: 7.2305e-04
# Epoch 164/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0057 - val_loss: 7.2396e-04
# Epoch 165/400
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0057 - val_loss: 8.8769e-04
# Epoch 166/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0056 - val_loss: 9.5307e-04
# Epoch 167/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0057 - val_loss: 0.0010
# Epoch 168/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0056 - val_loss: 9.6099e-04
# Epoch 169/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0055 - val_loss: 8.7754e-04
# Epoch 170/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0056 - val_loss: 8.0033e-04
# Epoch 171/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0056 - val_loss: 8.5521e-04
# Epoch 172/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0055 - val_loss: 9.6657e-04
# Epoch 173/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0055 - val_loss: 0.0010
# Epoch 174/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0055 - val_loss: 0.0012
# Epoch 175/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0055 - val_loss: 9.9786e-04
# Epoch 176/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0055 - val_loss: 8.5082e-04
# Epoch 177/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0055 - val_loss: 8.2496e-04
# Epoch 178/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0056 - val_loss: 9.6514e-04
# Epoch 179/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 9.3287e-04
# Epoch 180/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 9.3742e-04
# Epoch 181/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0054 - val_loss: 8.2027e-04
# Epoch 182/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0053 - val_loss: 7.4760e-04
# Epoch 183/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0054 - val_loss: 7.2793e-04
# Epoch 184/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0054 - val_loss: 8.1829e-04
# Epoch 185/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 9.5228e-04
# Epoch 186/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0053 - val_loss: 9.5849e-04
# Epoch 187/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0053 - val_loss: 9.3199e-04
# Epoch 188/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0053 - val_loss: 9.1533e-04
# Epoch 189/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0053 - val_loss: 0.0010
# Epoch 190/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0053 - val_loss: 0.0010
# Epoch 191/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0052 - val_loss: 9.8328e-04
# Epoch 192/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0052 - val_loss: 9.9451e-04
# Epoch 193/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0052 - val_loss: 0.0010
# Epoch 194/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0056 - val_loss: 0.0011
# Epoch 195/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0052 - val_loss: 8.1574e-04
# Epoch 196/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0050 - val_loss: 6.7344e-04
# Epoch 197/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0054 - val_loss: 7.0206e-04
# Epoch 198/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0055 - val_loss: 9.0824e-04
# Epoch 199/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0052 - val_loss: 0.0015
# Epoch 200/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0056 - val_loss: 0.0016
# Epoch 201/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0053 - val_loss: 0.0010
# Epoch 202/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0053 - val_loss: 6.9262e-04
# Epoch 203/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0055 - val_loss: 7.3558e-04
# Epoch 204/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0053 - val_loss: 0.0010
# Epoch 205/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0052 - val_loss: 0.0015
# Epoch 206/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0052 - val_loss: 0.0013
# Epoch 207/400
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0051 - val_loss: 0.0011
# Epoch 208/400
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0051 - val_loss: 8.1492e-04
# Epoch 209/400
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0051 - val_loss: 7.7263e-04
# Epoch 210/400
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0050 - val_loss: 7.8330e-04
# Epoch 211/400
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0050 - val_loss: 8.6073e-04
# Epoch 212/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0050 - val_loss: 9.4039e-04
# Epoch 213/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0050 - val_loss: 9.6807e-04
# Epoch 214/400
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0050 - val_loss: 9.4192e-04
# Epoch 215/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0049 - val_loss: 9.1619e-04
# Epoch 216/400
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0050 - val_loss: 8.7629e-04
# Epoch 217/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0051 - val_loss: 8.2166e-04
# Epoch 218/400
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0049 - val_loss: 9.5608e-04
# Epoch 219/400
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0049 - val_loss: 0.0011
# Epoch 220/400
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0052 - val_loss: 0.0011
# Epoch 221/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0049 - val_loss: 7.2630e-04
# Epoch 222/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0049 - val_loss: 6.3815e-04
# Epoch 223/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0052 - val_loss: 6.5637e-04
# Epoch 224/400
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0049 - val_loss: 9.0509e-04
# Epoch 225/400
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0048 - val_loss: 0.0015
# Epoch 226/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0052 - val_loss: 0.0015
# Epoch 227/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0051 - val_loss: 8.9575e-04
# Epoch 228/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0048 - val_loss: 6.6672e-04
# Epoch 229/400
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0050 - val_loss: 6.3057e-04
# Epoch 230/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0050 - val_loss: 6.6675e-04
# Epoch 231/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0049 - val_loss: 7.9509e-04
# Epoch 232/400
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0048 - val_loss: 8.7315e-04
# Epoch 233/400
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0048 - val_loss: 9.1098e-04
# Epoch 234/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0048 - val_loss: 0.0010
# Epoch 235/400
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0048 - val_loss: 9.3686e-04
# Epoch 236/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0048 - val_loss: 8.7464e-04
# Epoch 237/400
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0048 - val_loss: 8.7342e-04
# Epoch 238/400
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0048 - val_loss: 0.0011
# Epoch 239/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0047 - val_loss: 0.0012
# Epoch 240/400
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0048 - val_loss: 0.0012
# Epoch 241/400
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0048 - val_loss: 8.2830e-04
# Epoch 242/400
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0048 - val_loss: 6.7653e-04
# Epoch 243/400
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0048 - val_loss: 7.2136e-04
# Epoch 244/400
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0048 - val_loss: 8.6739e-04
# Epoch 245/400
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0048 - val_loss: 9.1884e-04
# Epoch 246/400
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0048 - val_loss: 0.0011
# Epoch 247/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0048 - val_loss: 9.0586e-04
# Epoch 248/400
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0047 - val_loss: 7.3455e-04
# Epoch 249/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0047 - val_loss: 7.0538e-04
# Epoch 250/400
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0048 - val_loss: 8.5800e-04
# Epoch 251/400
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0046 - val_loss: 8.6142e-04
# Epoch 252/400
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0046 - val_loss: 8.2952e-04
# Epoch 253/400
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0048 - val_loss: 7.9323e-04
# Epoch 254/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0046 - val_loss: 9.2065e-04
# Epoch 255/400
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0046 - val_loss: 0.0011
# Epoch 256/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0048 - val_loss: 8.9266e-04
# Epoch 257/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0047 - val_loss: 8.0351e-04
# Epoch 258/400
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0047 - val_loss: 6.8997e-04
# Epoch 259/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0046 - val_loss: 6.1232e-04
# Epoch 260/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0049 - val_loss: 6.1650e-04
# Epoch 261/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0047 - val_loss: 8.3376e-04
# Epoch 262/400
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0046 - val_loss: 0.0011
# Epoch 263/400
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0046 - val_loss: 0.0011
# Epoch 264/400
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0046 - val_loss: 8.6977e-04
# Epoch 265/400
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0045 - val_loss: 7.3455e-04
# Epoch 266/400
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0047 - val_loss: 6.4586e-04
# Epoch 267/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0048 - val_loss: 7.2321e-04
# Epoch 268/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0045 - val_loss: 6.3566e-04
# Epoch 269/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0045 - val_loss: 6.4220e-04
# Epoch 270/400
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0045 - val_loss: 7.2248e-04
# Epoch 271/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0046 - val_loss: 8.4797e-04
# Epoch 272/400
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0045 - val_loss: 7.6306e-04
# Epoch 273/400
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0045 - val_loss: 7.9196e-04
# Epoch 274/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0045 - val_loss: 7.6073e-04
# Epoch 275/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0045 - val_loss: 7.3194e-04
# Epoch 276/400
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0045 - val_loss: 7.3644e-04
# Epoch 277/400
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0045 - val_loss: 7.2759e-04
# Epoch 278/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0045 - val_loss: 7.1483e-04
# Epoch 279/400
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0047 - val_loss: 6.7505e-04
# Epoch 280/400
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0044 - val_loss: 5.9938e-04
# Epoch 281/400
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0046 - val_loss: 5.9992e-04
# Epoch 282/400
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0046 - val_loss: 6.8570e-04
# Epoch 283/400
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0047 - val_loss: 0.0010
# Epoch 284/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0047 - val_loss: 7.5694e-04
# Epoch 285/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0044 - val_loss: 6.7866e-04
# Epoch 286/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 6.3818e-04
# Epoch 287/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 6.8051e-04
# Epoch 288/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 6.3299e-04
# Epoch 289/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0045 - val_loss: 6.5501e-04
# Epoch 290/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0044 - val_loss: 7.4122e-04
# Epoch 291/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0045 - val_loss: 6.3528e-04
# Epoch 292/400
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0046 - val_loss: 5.8774e-04
# Epoch 293/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0044 - val_loss: 5.8446e-04
# Epoch 294/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0044 - val_loss: 5.9444e-04
# Epoch 295/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 6.6434e-04
# Epoch 296/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0045 - val_loss: 5.9413e-04
# Epoch 297/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0043 - val_loss: 5.8909e-04
# Epoch 298/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0045 - val_loss: 6.0545e-04
# Epoch 299/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0043 - val_loss: 6.8290e-04
# Epoch 300/400
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0043 - val_loss: 6.3656e-04
# Epoch 301/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0043 - val_loss: 5.8117e-04
# Epoch 302/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0043 - val_loss: 5.7997e-04
# Epoch 303/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0044 - val_loss: 5.8200e-04
# Epoch 304/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0043 - val_loss: 6.0023e-04
# Epoch 305/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0043 - val_loss: 6.2735e-04
# Epoch 306/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0044 - val_loss: 5.8211e-04
# Epoch 307/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0043 - val_loss: 5.9310e-04
# Epoch 308/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0043 - val_loss: 5.8441e-04
# Epoch 309/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0043 - val_loss: 5.7758e-04
# Epoch 310/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0043 - val_loss: 6.0781e-04
# Epoch 311/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0044 - val_loss: 7.3170e-04
# Epoch 312/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0043 - val_loss: 6.0130e-04
# Epoch 313/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0043 - val_loss: 5.9106e-04
# Epoch 314/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0043 - val_loss: 6.7201e-04
# Epoch 315/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0043 - val_loss: 5.8898e-04
# Epoch 316/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0044 - val_loss: 6.0949e-04
# Epoch 317/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0042 - val_loss: 5.7428e-04
# Epoch 318/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0043 - val_loss: 5.6581e-04
# Epoch 319/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0042 - val_loss: 5.8050e-04
# Epoch 320/400
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0042 - val_loss: 5.7157e-04
# Epoch 321/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0042 - val_loss: 5.6399e-04
# Epoch 322/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0042 - val_loss: 5.6285e-04
# Epoch 323/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0041 - val_loss: 5.6271e-04
# Epoch 324/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0042 - val_loss: 5.6721e-04
# Epoch 325/400
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0042 - val_loss: 5.6412e-04
# Epoch 326/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0042 - val_loss: 5.6279e-04
# Epoch 327/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0042 - val_loss: 5.6141e-04
# Epoch 328/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0041 - val_loss: 5.8192e-04
# Epoch 329/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0042 - val_loss: 5.6719e-04
# Epoch 330/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0042 - val_loss: 5.8521e-04
# Epoch 331/400
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0043 - val_loss: 6.6431e-04
# Epoch 332/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0041 - val_loss: 5.4701e-04
# Epoch 333/400
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0041 - val_loss: 5.9631e-04
# Epoch 334/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0042 - val_loss: 5.5931e-04
# Epoch 335/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0041 - val_loss: 5.5138e-04
# Epoch 336/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0041 - val_loss: 6.1714e-04
# Epoch 337/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0041 - val_loss: 5.5402e-04
# Epoch 338/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0042 - val_loss: 5.5070e-04
# Epoch 339/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0042 - val_loss: 5.7468e-04
# Epoch 340/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0041 - val_loss: 6.2127e-04
# Epoch 341/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0041 - val_loss: 7.0799e-04
# Epoch 342/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0041 - val_loss: 6.0414e-04
# Epoch 343/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0040 - val_loss: 5.3907e-04
# Epoch 344/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0041 - val_loss: 5.4024e-04
# Epoch 345/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0040 - val_loss: 6.2609e-04
# Epoch 346/400
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0041 - val_loss: 6.2945e-04
# Epoch 347/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0040 - val_loss: 5.3254e-04
# Epoch 348/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0042 - val_loss: 5.3520e-04
# Epoch 349/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0040 - val_loss: 7.4715e-04
# Epoch 350/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0042 - val_loss: 7.6321e-04
# Epoch 351/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0041 - val_loss: 5.3256e-04
# Epoch 352/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0040 - val_loss: 5.3643e-04
# Epoch 353/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0040 - val_loss: 5.6261e-04
# Epoch 354/400
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0039 - val_loss: 6.2399e-04
# Epoch 355/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0041 - val_loss: 6.3572e-04
# Epoch 356/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0040 - val_loss: 5.4572e-04
# Epoch 357/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0040 - val_loss: 5.2698e-04
# Epoch 358/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0040 - val_loss: 5.9985e-04
# Epoch 359/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0039 - val_loss: 7.1471e-04
# Epoch 360/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0040 - val_loss: 7.4454e-04
# Epoch 361/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0040 - val_loss: 5.4732e-04
# Epoch 362/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0039 - val_loss: 5.8859e-04
# Epoch 363/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0039 - val_loss: 6.6381e-04
# Epoch 364/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0039 - val_loss: 7.0697e-04
# Epoch 365/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0039 - val_loss: 6.0490e-04
# Epoch 366/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0039 - val_loss: 5.2583e-04
# Epoch 367/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0040 - val_loss: 5.1933e-04
# Epoch 368/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0039 - val_loss: 5.5878e-04
# Epoch 369/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0039 - val_loss: 7.5522e-04
# Epoch 370/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0039 - val_loss: 7.5719e-04
# Epoch 371/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0039 - val_loss: 8.1205e-04
# Epoch 372/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0039 - val_loss: 6.6127e-04
# Epoch 373/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0038 - val_loss: 6.3484e-04
# Epoch 374/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0039 - val_loss: 6.4994e-04
# Epoch 375/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0038 - val_loss: 6.0804e-04
# Epoch 376/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0039 - val_loss: 6.6508e-04
# Epoch 377/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0038 - val_loss: 7.3525e-04
# Epoch 378/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0041 - val_loss: 7.7671e-04
# Epoch 379/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0037 - val_loss: 5.2493e-04
# Epoch 380/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0041 - val_loss: 5.0666e-04
# Epoch 381/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0040 - val_loss: 7.1716e-04
# Epoch 382/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0038 - val_loss: 0.0011
# Epoch 383/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0038 - val_loss: 9.1705e-04
# Epoch 384/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0038 - val_loss: 5.9062e-04
# Epoch 385/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0039 - val_loss: 5.7194e-04
# Epoch 386/400
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0037 - val_loss: 0.0010
# Epoch 387/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0039 - val_loss: 0.0012
# Epoch 388/400
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0039 - val_loss: 6.9499e-04
# Epoch 389/400
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0038 - val_loss: 6.1164e-04
# Epoch 390/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0038 - val_loss: 6.5794e-04
# Epoch 391/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0038 - val_loss: 0.0011
# Epoch 392/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0037 - val_loss: 8.8782e-04
# Epoch 393/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0037 - val_loss: 5.9642e-04
# Epoch 394/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0039 - val_loss: 5.4572e-04
# Epoch 395/400
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0039 - val_loss: 0.0011
# Epoch 396/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0038 - val_loss: 0.0013
# Epoch 397/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0039 - val_loss: 7.8582e-04
# Epoch 398/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0038 - val_loss: 7.8245e-04
# Epoch 399/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0037 - val_loss: 0.0010
# Epoch 400/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0037 - val_loss: 9.2418e-04
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 273ms/step
# Error Cuadrático Medio: 1500.5494562750216
# Error Absoluto Medio: 34.479176735617884
# 1/1 [==============================] - 0s 20ms/step
# Predicciones para valores futuros de prod_pet: [140.72357 154.53868 151.66077 145.8266  140.0251  134.32758]
