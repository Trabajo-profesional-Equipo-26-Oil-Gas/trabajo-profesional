# %% [markdown]
# #Partiendo de la limpieza de datos realizada previamente, se utiliza LSTM para predecir la producción de pozos de petroleo.
#
# ###Pozos a predecir:
# 158364, 160211, 160332, 160789, 160810, 160814, 161451, 162200, 162405, 162955, 163237, 163942

# %%
import math
import itertools
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import LSTM, Dense
from keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
pd.set_option('display.max_columns', None)

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

#dataset = pd.read_csv("/content/drive/MyDrive/Trabajo profesional/Code/data/prod_norm_2024-05-27_03:42:59.csv", index_col=0)
dataset = pd.read_csv("/content/drive/MyDrive/Trabajo profesional/Code/data/prod_clean_2024-05-13_17:08:31.csv", index_col=0)

dataset = dataset[dataset['anio'] >= 2014]

# Seleccionar características relevantes
features = ['prod_pet', 'anio', 'mes', 'idpozo', 'prod_gas', 'prod_agua', 'tef', 'coordenadax', 'coordenaday', 'cota', 'pet_inicial', 'gas_inicial', 'agua_inicial']

# Filtrar características
data = dataset[features]

# Creacion de una nueva columna 'date' combinando 'anio' y 'mes' para representar la fecha
data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')

data.drop(['mes', 'anio'], axis=1, inplace=True)

# Conversion de la columna 'date' a "datetime type"
data['date'] = pd.to_datetime(data['date'])

# Definicion de un dia de referencia inicial (Es la primera fecha desde la que se filtro previamente).
reference_date = pd.Timestamp('2014-01-01')

# Calculo del numero de meses desde la referencia para cada date.
data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1

data.drop(['date'], axis=1, inplace=True)

filtered_data_one_id = data[data['idpozo'] == 160211]

filtered_data_one_id.drop(['idpozo'], axis=1, inplace=True)
# Out:
# Mounted at /content/drive
# <ipython-input-2-526ce22ad4ad>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['anio'].astype(str) + '-' + data['mes'].astype(str), format='%Y-%m')
# <ipython-input-2-526ce22ad4ad>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['mes', 'anio'], axis=1, inplace=True)
# <ipython-input-2-526ce22ad4ad>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['date'])
# <ipython-input-2-526ce22ad4ad>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date_numeric'] = (data['date'].dt.year - reference_date.year) * 12 + data['date'].dt.month - reference_date.month + 1
# <ipython-input-2-526ce22ad4ad>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['date'], axis=1, inplace=True)
# <ipython-input-2-526ce22ad4ad>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data_one_id.drop(['idpozo'], axis=1, inplace=True)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'pet_inicial', 'gas_inicial', 'agua_inicial', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_pet']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)

# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, el error cuadrático medio)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    return mse

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=10, trials=trials)

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.show()

# Predecir "prod_pet" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'pet_inicial': [filtered_data_one_id['pet_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'gas_inicial': [filtered_data_one_id['gas_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'agua_inicial': [filtered_data_one_id['agua_inicial'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_pet:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 194ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 155ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 163ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 160ms/step
#
#  40%|████      | 4/10 [00:37<00:48,  8.03s/trial, best loss: 6109.506435226878]
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7aa30c1bc160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 246ms/step
#
#  50%|█████     | 5/10 [00:48<00:46,  9.39s/trial, best loss: 6109.506435226878]
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7aa3046052d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 249ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 160ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 158ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 157ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 100%|██████████| 10/10 [01:39<00:00,  9.99s/trial, best loss: 6109.506435226878]
# Mejor tamaño de lote: 32
# Mejor cantidad de épocas: 100
# Epoch 1/100
# 2/2 [==============================] - 1s 245ms/step - loss: 0.1044 - val_loss: 0.0114
# Epoch 2/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1035 - val_loss: 0.0072
# Epoch 3/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0963 - val_loss: 0.0035
# Epoch 4/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0848 - val_loss: 0.0010
# Epoch 5/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0746 - val_loss: 4.4599e-04
# Epoch 6/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0653 - val_loss: 0.0023
# Epoch 7/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0565 - val_loss: 0.0068
# Epoch 8/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0509 - val_loss: 0.0139
# Epoch 9/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0456 - val_loss: 0.0224
# Epoch 10/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0425 - val_loss: 0.0314
# Epoch 11/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0406 - val_loss: 0.0393
# Epoch 12/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0390 - val_loss: 0.0451
# Epoch 13/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0383 - val_loss: 0.0487
# Epoch 14/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0380 - val_loss: 0.0502
# Epoch 15/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0377 - val_loss: 0.0496
# Epoch 16/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0369 - val_loss: 0.0465
# Epoch 17/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0359 - val_loss: 0.0427
# Epoch 18/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0348 - val_loss: 0.0386
# Epoch 19/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0338 - val_loss: 0.0344
# Epoch 20/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0327 - val_loss: 0.0307
# Epoch 21/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0318 - val_loss: 0.0269
# Epoch 22/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0308 - val_loss: 0.0235
# Epoch 23/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0300 - val_loss: 0.0203
# Epoch 24/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0293 - val_loss: 0.0173
# Epoch 25/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0286 - val_loss: 0.0149
# Epoch 26/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0280 - val_loss: 0.0127
# Epoch 27/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0273 - val_loss: 0.0113
# Epoch 28/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0266 - val_loss: 0.0100
# Epoch 29/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0260 - val_loss: 0.0090
# Epoch 30/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0253 - val_loss: 0.0082
# Epoch 31/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0245 - val_loss: 0.0073
# Epoch 32/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0238 - val_loss: 0.0065
# Epoch 33/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0230 - val_loss: 0.0057
# Epoch 34/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0222 - val_loss: 0.0050
# Epoch 35/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0214 - val_loss: 0.0046
# Epoch 36/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0205 - val_loss: 0.0043
# Epoch 37/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0199 - val_loss: 0.0039
# Epoch 38/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0190 - val_loss: 0.0032
# Epoch 39/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0185 - val_loss: 0.0023
# Epoch 40/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0175 - val_loss: 0.0013
# Epoch 41/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0167 - val_loss: 6.1040e-04
# Epoch 42/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0158 - val_loss: 2.4214e-04
# Epoch 43/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0151 - val_loss: 5.5501e-05
# Epoch 44/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0144 - val_loss: 1.1733e-04
# Epoch 45/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0136 - val_loss: 5.2628e-04
# Epoch 46/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0129 - val_loss: 0.0013
# Epoch 47/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0124 - val_loss: 0.0022
# Epoch 48/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0118 - val_loss: 0.0032
# Epoch 49/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0116 - val_loss: 0.0038
# Epoch 50/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0109 - val_loss: 0.0048
# Epoch 51/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0106 - val_loss: 0.0054
# Epoch 52/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0104 - val_loss: 0.0058
# Epoch 53/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0102 - val_loss: 0.0066
# Epoch 54/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0099 - val_loss: 0.0072
# Epoch 55/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0098 - val_loss: 0.0073
# Epoch 56/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0096 - val_loss: 0.0065
# Epoch 57/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0095 - val_loss: 0.0056
# Epoch 58/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0093 - val_loss: 0.0044
# Epoch 59/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0092 - val_loss: 0.0046
# Epoch 60/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0090 - val_loss: 0.0054
# Epoch 61/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0087 - val_loss: 0.0062
# Epoch 62/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0087 - val_loss: 0.0055
# Epoch 63/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0087 - val_loss: 0.0034
# Epoch 64/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0085 - val_loss: 0.0014
# Epoch 65/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0086 - val_loss: 7.6269e-04
# Epoch 66/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0085 - val_loss: 0.0014
# Epoch 67/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0082 - val_loss: 0.0021
# Epoch 68/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0080 - val_loss: 0.0028
# Epoch 69/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0079 - val_loss: 0.0026
# Epoch 70/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0078 - val_loss: 0.0019
# Epoch 71/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0077 - val_loss: 0.0020
# Epoch 72/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0077 - val_loss: 0.0028
# Epoch 73/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0076 - val_loss: 0.0031
# Epoch 74/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0075 - val_loss: 0.0027
# Epoch 75/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0074 - val_loss: 0.0020
# Epoch 76/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0073 - val_loss: 8.0970e-04
# Epoch 77/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0072 - val_loss: 3.2593e-04
# Epoch 78/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0071 - val_loss: 5.2673e-04
# Epoch 79/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0070 - val_loss: 9.1820e-04
# Epoch 80/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0069 - val_loss: 0.0010
# Epoch 81/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0069 - val_loss: 5.8068e-04
# Epoch 82/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0067 - val_loss: 1.5776e-04
# Epoch 83/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0067 - val_loss: 1.3367e-04
# Epoch 84/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0067 - val_loss: 2.3833e-04
# Epoch 85/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0066 - val_loss: 4.8145e-04
# Epoch 86/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0065 - val_loss: 6.2279e-04
# Epoch 87/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0065 - val_loss: 0.0013
# Epoch 88/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0065 - val_loss: 0.0017
# Epoch 89/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0064 - val_loss: 6.7011e-04
# Epoch 90/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0063 - val_loss: 2.3230e-04
# Epoch 91/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0063 - val_loss: 4.3438e-04
# Epoch 92/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0061 - val_loss: 5.8181e-04
# Epoch 93/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0061 - val_loss: 5.1934e-04
# Epoch 94/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0060 - val_loss: 1.9787e-04
# Epoch 95/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0060 - val_loss: 2.9995e-04
# Epoch 96/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0060 - val_loss: 2.5870e-04
# Epoch 97/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0059 - val_loss: 2.1623e-04
# Epoch 98/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0058 - val_loss: 4.8152e-04
# Epoch 99/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0058 - val_loss: 2.8831e-04
# Epoch 100/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0058 - val_loss: 1.7083e-04
# 1/1 [==============================] - 0s 260ms/step
# Error Cuadrático Medio: 7955.495778024643
# Error Absoluto Medio: 74.63674719108072
# 1/1 [==============================] - 0s 30ms/step
# Predicciones para valores futuros de prod_pet: [928.3617  806.46783 796.8034  803.96014 811.6485  820.2298 ]

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from hyperopt import hp, fmin, tpe, Trials
import tensorflow as tf

# Establecer una semilla aleatoria para reproducibilidad
np.random.seed(42)
tf.random.set_seed(42)

# "X" contiene los features
X = filtered_data_one_id[['tef', 'coordenadax', 'coordenaday', 'cota', 'date_numeric']]

# "y" contiene la columna que es la variable objetivo a predecir.
y = filtered_data_one_id['prod_pet']

# Escalar las características entre 0 y 1
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)

# Escalar la variable objetivo entre 0 y 1
scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Longitud de la secuencia
seq_length = 3

# Función para crear secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

# Crear secuencias para LSTM
X_sequences = create_sequences(X_scaled, seq_length)

# Ajustar "y" para que coincida con las secuencias
y_adjusted = y_scaled[seq_length - 1:]

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_adjusted, test_size=0.2, random_state=42, shuffle=False)

# Definir el espacio de búsqueda de hiperparámetros
space = {
    'batch_size': hp.choice('batch_size', [16, 32, 64, 128]),
    'epochs': hp.choice('epochs', [100, 200, 300, 400])
}

# Función objetivo para minimizar (en este caso, la combinación de MSE y MAE)
def objective(params):
    model = Sequential([
        LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
        Dense(1),
        Activation('relu')  # Asegurar que las predicciones sean no negativas
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], validation_data=(X_test, y_test), verbose=0)
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)

    # Calcular el MSE y MAE
    mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
    mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

    # Combinar MSE y MAE en una única métrica
    combined_metric = 0.5 * mse + 0.5 * mae
    return combined_metric

# Ejecutar la búsqueda de hiperparámetros
trials = Trials()
best = fmin(objective, space, algo=tpe.suggest, max_evals=50, trials=trials)  # Aumentar max_evals

# Obtener los mejores hiperparámetros
best_batch_size = [16, 32, 64, 128][best['batch_size']]
best_epochs = [100, 200, 300, 400][best['epochs']]

print(f'Mejor tamaño de lote: {best_batch_size}')
print(f'Mejor cantidad de épocas: {best_epochs}')

# Construir el modelo final con los mejores hiperparámetros
model = Sequential([
    LSTM(100, activation='relu', input_shape=(seq_length, X_train.shape[2])),
    Dense(1),
    Activation('relu')  # Asegurar que las predicciones sean no negativas
])
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=best_epochs, batch_size=best_batch_size, validation_data=(X_test, y_test), verbose=1)

# Predecir en el conjunto de prueba
y_pred_scaled = model.predict(X_test)

# Inversión del escalado para obtener las predicciones reales
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# Calculo de métricas de error
mse = mean_squared_error(scaler_y.inverse_transform(y_test), y_pred)
mae = mean_absolute_error(scaler_y.inverse_transform(y_test), y_pred)

print(f'Error Cuadrático Medio: {mse}')
print(f'Error Absoluto Medio: {mae}')

# Graficar los valores predichos vs los valores reales
plt.figure(figsize=(10, 5))
plt.plot(scaler_y.inverse_transform(y_test), label='Actual')
plt.plot(y_pred, label='Predicho')
plt.xlabel('Muestra')
plt.ylabel('prod_pet')
plt.title('Actual versus Predicho "prod_pet"')
plt.legend()
plt.show()

# Predecir "prod_pet" para los siguientes valores futuros de "date_numeric"
future_date_numeric_values = [123, 124, 125, 126, 127, 128]

# Crear un DataFrame con los valores futuros y placeholders para las demás características
future_data = pd.DataFrame({
    'tef': [filtered_data_one_id['tef'].iloc[-1]] * len(future_date_numeric_values),
    'coordenadax': [filtered_data_one_id['coordenadax'].iloc[-1]] * len(future_date_numeric_values),
    'coordenaday': [filtered_data_one_id['coordenaday'].iloc[-1]] * len(future_date_numeric_values),
    'cota': [filtered_data_one_id['cota'].iloc[-1]] * len(future_date_numeric_values),
    'date_numeric': future_date_numeric_values
})

# Escalar los datos futuros
scaled_future_data = scaler_X.transform(future_data)

# Crear secuencias para LSTM usando los datos futuros escalados
last_sequence = X_scaled[-seq_length:]
future_sequences = []
for i in range(len(future_date_numeric_values)):
    new_sequence = np.append(last_sequence[1:], [scaled_future_data[i]], axis=0)
    future_sequences.append(new_sequence)
    last_sequence = new_sequence
future_sequences = np.array(future_sequences)

# Hacer predicciones (escaladas - no valores reales)
predictions_scaled = model.predict(future_sequences)

# Inversión del escalado para obtener las predicciones reales
predictions = scaler_y.inverse_transform(predictions_scaled)

print("Predicciones para valores futuros de prod_pet:", predictions.flatten())
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 266ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 261ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 182ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 176ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 165ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 262ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 242ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 199ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 247ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 187ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 199ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 255ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 262ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 266ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 193ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 184ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 193ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 189ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 177ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 185ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 253ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 172ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 174ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 175ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 216ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 317ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 183ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 277ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 192ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 178ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 301ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 190ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 168ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 181ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 194ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 252ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 169ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 203ms/step
#
# 100%|██████████| 50/50 [09:51<00:00, 11.82s/trial, best loss: 3408.684454405008]
# Mejor tamaño de lote: 16
# Mejor cantidad de épocas: 100
# Epoch 1/100
# 3/3 [==============================] - 2s 201ms/step - loss: 0.0924 - val_loss: 0.0060
# Epoch 2/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0694 - val_loss: 5.4694e-04
# Epoch 3/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0518 - val_loss: 0.0017
# Epoch 4/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0412 - val_loss: 0.0097
# Epoch 5/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0344 - val_loss: 0.0221
# Epoch 6/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0321 - val_loss: 0.0328
# Epoch 7/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0320 - val_loss: 0.0372
# Epoch 8/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0326 - val_loss: 0.0369
# Epoch 9/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0313 - val_loss: 0.0299
# Epoch 10/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0293 - val_loss: 0.0220
# Epoch 11/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0272 - val_loss: 0.0152
# Epoch 12/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0258 - val_loss: 0.0099
# Epoch 13/100
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0248 - val_loss: 0.0062
# Epoch 14/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0240 - val_loss: 0.0042
# Epoch 15/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0231 - val_loss: 0.0029
# Epoch 16/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0221 - val_loss: 0.0020
# Epoch 17/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0209 - val_loss: 0.0016
# Epoch 18/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0194 - val_loss: 9.8294e-04
# Epoch 19/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0183 - val_loss: 5.8704e-04
# Epoch 20/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0173 - val_loss: 2.5502e-04
# Epoch 21/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0161 - val_loss: 5.2958e-05
# Epoch 22/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0150 - val_loss: 2.6522e-04
# Epoch 23/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0141 - val_loss: 8.3885e-04
# Epoch 24/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0131 - val_loss: 0.0021
# Epoch 25/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0125 - val_loss: 0.0032
# Epoch 26/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0117 - val_loss: 0.0049
# Epoch 27/100
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0112 - val_loss: 0.0065
# Epoch 28/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0107 - val_loss: 0.0081
# Epoch 29/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0104 - val_loss: 0.0089
# Epoch 30/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0102 - val_loss: 0.0093
# Epoch 31/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 32/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0100 - val_loss: 0.0102
# Epoch 33/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0097 - val_loss: 0.0107
# Epoch 34/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0095 - val_loss: 0.0105
# Epoch 35/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0095 - val_loss: 0.0098
# Epoch 36/100
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0093 - val_loss: 0.0067
# Epoch 37/100
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0091 - val_loss: 0.0058
# Epoch 38/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0090 - val_loss: 0.0065
# Epoch 39/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0088 - val_loss: 0.0067
# Epoch 40/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0087 - val_loss: 0.0050
# Epoch 41/100
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0087 - val_loss: 0.0043
# Epoch 42/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0085 - val_loss: 0.0050
# Epoch 43/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0085 - val_loss: 0.0062
# Epoch 44/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0082 - val_loss: 0.0026
# Epoch 45/100
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0081 - val_loss: 0.0012
# Epoch 46/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0079 - val_loss: 0.0018
# Epoch 47/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0081 - val_loss: 0.0025
# Epoch 48/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0077 - val_loss: 7.8432e-04
# Epoch 49/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0078 - val_loss: 3.9338e-04
# Epoch 50/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0075 - val_loss: 0.0024
# Epoch 51/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0075 - val_loss: 0.0029
# Epoch 52/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0075 - val_loss: 0.0011
# Epoch 53/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0072 - val_loss: 7.8374e-04
# Epoch 54/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0073 - val_loss: 0.0015
# Epoch 55/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0070 - val_loss: 3.4669e-04
# Epoch 56/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0069 - val_loss: 1.4568e-04
# Epoch 57/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0069 - val_loss: 5.4965e-04
# Epoch 58/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0067 - val_loss: 0.0011
# Epoch 59/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0066 - val_loss: 3.6870e-04
# Epoch 60/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0065 - val_loss: 1.8373e-04
# Epoch 61/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0065 - val_loss: 4.0673e-04
# Epoch 62/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0065 - val_loss: 4.3493e-04
# Epoch 63/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0064 - val_loss: 2.8381e-04
# Epoch 64/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0063 - val_loss: 1.7672e-04
# Epoch 65/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0063 - val_loss: 1.5059e-04
# Epoch 66/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0063 - val_loss: 4.5366e-04
# Epoch 67/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0062 - val_loss: 1.9735e-04
# Epoch 68/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0061 - val_loss: 1.6775e-04
# Epoch 69/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0060 - val_loss: 1.8021e-04
# Epoch 70/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0060 - val_loss: 1.8071e-04
# Epoch 71/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0059 - val_loss: 1.9564e-04
# Epoch 72/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0059 - val_loss: 1.8341e-04
# Epoch 73/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0058 - val_loss: 1.9084e-04
# Epoch 74/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0057 - val_loss: 1.9136e-04
# Epoch 75/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0057 - val_loss: 2.3933e-04
# Epoch 76/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0056 - val_loss: 1.9618e-04
# Epoch 77/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0057 - val_loss: 2.0503e-04
# Epoch 78/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0057 - val_loss: 2.4630e-04
# Epoch 79/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0055 - val_loss: 3.2126e-04
# Epoch 80/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0055 - val_loss: 2.1978e-04
# Epoch 81/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0055 - val_loss: 6.9327e-04
# Epoch 82/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0055 - val_loss: 6.4012e-04
# Epoch 83/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0052 - val_loss: 2.6243e-04
# Epoch 84/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0053 - val_loss: 2.2350e-04
# Epoch 85/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0052 - val_loss: 2.7064e-04
# Epoch 86/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0051 - val_loss: 3.0911e-04
# Epoch 87/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0050 - val_loss: 2.3345e-04
# Epoch 88/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0051 - val_loss: 2.1748e-04
# Epoch 89/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0048 - val_loss: 3.8168e-04
# Epoch 90/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0048 - val_loss: 2.1899e-04
# Epoch 91/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0048 - val_loss: 2.9264e-04
# Epoch 92/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0049 - val_loss: 2.3533e-04
# Epoch 93/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0046 - val_loss: 2.9138e-04
# Epoch 94/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0047 - val_loss: 2.8563e-04
# Epoch 95/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0046 - val_loss: 6.7902e-04
# Epoch 96/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0044 - val_loss: 2.5041e-04
# Epoch 97/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0044 - val_loss: 2.5633e-04
# Epoch 98/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0044 - val_loss: 6.3007e-04
# Epoch 99/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0043 - val_loss: 2.6529e-04
# Epoch 100/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0041 - val_loss: 2.5949e-04
# 1/1 [==============================] - 0s 172ms/step
# Error Cuadrático Medio: 12084.79408103994
# Error Absoluto Medio: 88.86422521842447
# 1/1 [==============================] - 0s 24ms/step
# Predicciones para valores futuros de prod_pet: [985.13306 871.5187  856.5697  869.97736 884.5293  900.3041 ]
